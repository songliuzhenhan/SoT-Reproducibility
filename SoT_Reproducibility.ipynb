# %%
# !rm -rf /content/SQL-of-Thought
# !git clone https://github.com/shollercoaster/SQL-of-Thought.git
# !pip install -q openai gdown

import gdown, zipfile, os
if not os.path.exists('/content/spider'):
    gdown.download(id='1TqleXec_OykOYFREKKtschzY29dUcVAQ', output='/content/spider.zip', quiet=False)
    with zipfile.ZipFile('/content/spider.zip','r') as z:
        z.extractall('/content/')
# Out:
# Cloning into 'SQL-of-Thought'...
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 11 (delta 2), reused 3 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (11/11), 19.01 KiB | 973.00 KiB/s, done.
# Resolving deltas: 100% (2/2), done.

# %%
import os, json, shutil
os.chdir('/content/SQL-of-Thought')

# grab the error taxonomy file whatever it's called
for f in os.listdir('.'):
    if 'error_taxonomy' in f and f.endswith('.json') and f != 'error_taxonomy.json':
        shutil.copy(f, 'error_taxonomy.json')
        break

os.makedirs('ablations_actual', exist_ok=True)
if not os.path.exists('nl2sql_bugs.json'):
    json.dump([], open('nl2sql_bugs.json','w'))

# repo doesn't have this file so writing a minimal version
with open('analyze_by_subproblems.py','w') as f:
    f.write("""import json

def parse_subproblems(s):
    if isinstance(s, str):
        try: data = json.loads(s)
        except: return []
    elif isinstance(s, dict): data = s
    else: return []
    return [sp.get("clause","").strip().upper()
            for sp in data.get("subproblems",[])
            if sp.get("clause","").strip()]
""")

# patch utils.py - fix paths, missing deps, client init
with open('utils.py','r') as f:
    lines = f.readlines()

out = []
i = 0
while i < len(lines):
    ln = lines[i].replace('../../spider/', '/content/spider/')

    if ln.strip() == 'import anthropic':
        out += ['try:\n','    import anthropic\n','except ImportError:\n','    anthropic = None\n']
        i+=1; continue

    if ln.strip().startswith('openai_client = OpenAI('):
        out.append('openai_client = None\n')
        i+=1; continue

    if ln.strip() == 'import torch' and i+1<len(lines) and 'from transformers' in lines[i+1]:
        out += ['try:\n','    import torch\n',
                '    from transformers import AutoTokenizer, AutoModelForCausalLM\n',
                'except ImportError:\n','    torch = None\n',
                '    AutoTokenizer = None\n','    AutoModelForCausalLM = None\n']
        i+=2; continue

    if ln.startswith('def load_local_model('):
        out.append("""
def init_clients(use_openai=True, use_anthropic=False, use_local=False, base_url=None):
    global openai_client, client, model, tokenizer
    if use_openai:
        kw = {"api_key": OPENAI_API_KEY}
        if base_url: kw["base_url"] = base_url
        openai_client = OpenAI(**kw)
    if use_anthropic and anthropic:
        client = anthropic.Anthropic(api_key=ANTHROPIC_API_KEY)
    if use_local:
        model, tokenizer = load_local_model()

""")
        out.append(ln); i+=1; continue

    if ln.strip() == 'model, tokenizer = load_local_model()':
        out.append('model, tokenizer = None, None\n'); i+=1; continue
    if 'client = anthropic.Anthropic(' in ln:
        out.append('client = None\n'); i+=1; continue
    if 'model= "gpt-5"' in ln:
        ln = ln.replace('model= "gpt-5", # "gpt-3.5-turbo",','model=model,')
    if 'open("../../nl2sql_bugs.json")' in ln:
        ln = ln.replace('open("../../nl2sql_bugs.json")','open("nl2sql_bugs.json")')

    out.append(ln)
    i+=1

with open('utils.py','w') as f:
    f.writelines(out)

# same path fix for eval script
with open('run_eval_single_schemalink.py','r') as f:
    src = f.read()
with open('run_eval_single_schemalink.py','w') as f:
    f.write(src.replace('../../spider/','/content/spider/'))

print("done patching")
# Out:
# done patching

# %%
import os, sys, json
from getpass import getpass

os.chdir('/content/SQL-of-Thought')
os.environ["OPENAI_API_KEY"] = getpass("api key: ")

for m in ['utils','prompts','analyze_by_subproblems']:
    if m in sys.modules: del sys.modules[m]

from utils import (init_clients, load_spider, load_schema, call_agent,
                   postprocess_sql, query_execution, exec_query,
                   clean_json, clause_specific_prompts)
from prompts import (alt_schema_linking_agent_prompt, subproblem_agent_prompt,
                     query_plan_agent_prompt, sql_agent_prompt,
                     correction_plan_agent_prompt, correction_sql_agent_prompt)
from analyze_by_subproblems import parse_subproblems

init_clients(use_openai=True, base_url="https://api.deepseek.com")

# quick sanity check
print(call_agent("Say hi.", "deepseek-chat"))

N = 100
MAX_FIX = 3
MDL = "deepseek-chat"
# Out:
# api key: ··········
# Hello! 👋 It's great to meet you. How can I help you today?

# %%
def run(gen_fn, tag, correct=True):
    dev = load_spider(dev=True)
    tot = em = vs = ea = 0
    rows = []

    for i, item in enumerate(dev[:N]):
        q, gold, db = item['question'], item['query'], item['db_id']
        schema = load_schema(db)
        sql = ""
        ok = False
        print(f"\n[{i+1}/{N}] {q}")

        try:
            sql, ctx = gen_fn(q, schema, db)
            print(f"  -> {sql}")
            ok, err = query_execution(item, sql)

            if correct:
                att = 0
                while not ok and att < MAX_FIX:
                    cp = call_agent(correction_plan_agent_prompt(q, sql, ctx, err), MDL)
                    sql = postprocess_sql(call_agent(
                        correction_sql_agent_prompt(q, ctx, cp, sql), MDL))
                    print(f"  fix{att+1}: {sql}")
                    ok, err = query_execution(item, sql)
                    att += 1
        except Exception as e:
            print(f"  ERR: {e}")

        gc = postprocess_sql(gold)
        is_em = sql.strip().lower() == gc.strip().lower()
        _, ge = exec_query(f"/content/spider/database/{db}/{db}.sqlite", sql)
        is_vs = ge is None

        if is_em: em += 1
        if is_vs: vs += 1
        if ok: ea += 1
        tot += 1
        rows.append({"question":q, "db_id":db, "gold":gc, "gen":sql,
                      "em":is_em, "valid":is_vs, "exec":ok})
        print(f"  gold: {gc}")
        print(f"  EM={em}/{tot} EA={ea}/{tot} VS={vs}/{tot}")

    s = {"total":tot, "em":em, "vs":vs, "ea":ea,
         "em%":round(em/tot,4), "vs%":round(vs/tot,4), "ea%":round(ea/tot,4)}
    path = f"ablations_actual/{N}_deepseek_{tag}.json"
    json.dump({"summary":s, "results":rows}, open(path,"w"), indent=2)
    print(f"\n=== {tag} === {json.dumps(s)}")
    return s


# generation functions for each variant

def gen_sot(q, sch, db):
    cs = call_agent(alt_schema_linking_agent_prompt(q, sch), MDL)
    sj = clean_json(call_agent(subproblem_agent_prompt(q, cs), MDL))
    cl = list(set(parse_subproblems(sj)))
    clause_specific_prompts(cl)
    plan = call_agent(query_plan_agent_prompt(q, cs, sj), MDL)
    sql = postprocess_sql(call_agent(sql_agent_prompt(q, plan, cs), MDL))
    return sql, cs

def gen_nosub(q, sch, db):
    cs = call_agent(alt_schema_linking_agent_prompt(q, sch), MDL)
    plan = call_agent(query_plan_agent_prompt(q, cs, "{}"), MDL)
    sql = postprocess_sql(call_agent(sql_agent_prompt(q, plan, cs), MDL))
    return sql, cs

def gen_noschema(q, sch, db):
    sj = clean_json(call_agent(subproblem_agent_prompt(q, sch), MDL))
    cl = list(set(parse_subproblems(sj)))
    clause_specific_prompts(cl)
    plan = call_agent(query_plan_agent_prompt(q, sch, sj), MDL)
    sql = postprocess_sql(call_agent(sql_agent_prompt(q, plan, sch), MDL))
    return sql, sch

def gen_direct(q, sch, db):
    p = f"Given this schema:\n{sch}\n\nWrite a SQLite query for: {q}\n\nOutput only SQL."
    return postprocess_sql(call_agent(p, MDL)), sch

# %%
r1 = run(gen_sot, "sot_full")
# Out:
# [1/100] How many singers do we have?
#   -> select count(distinct singer.singer_id) from singer
#   gold: select count(*) from singer
#   EM=0/1 EA=1/1 VS=1/1
#
# [2/100] What is the total number of singers?
#   -> select count(*) from singer
#   gold: select count(*) from singer
#   EM=1/2 EA=2/2 VS=2/2
#
# [3/100] Show name, country, age for all singers ordered by age from the oldest to the youngest.
#   -> select name, country, age from singer order by age desc
#   gold: select name, country, age from singer order by age desc
#   EM=2/3 EA=3/3 VS=3/3
#
# [4/100] What are the names, countries, and ages for every singer in descending order of age?
#   -> select name, country, age from singer order by age desc
#   gold: select name, country, age from singer order by age desc
#   EM=3/4 EA=4/4 VS=4/4
#
# [5/100] What is the average, minimum, and maximum age of all singers from France?
#   -> select avg(singer.age), min(singer.age), max(singer.age) from singer where singer.country = 'france'
#   gold: select avg(age), min(age), max(age) from singer where country = 'france'
#   EM=3/5 EA=5/5 VS=5/5
#
# [6/100] What is the average, minimum, and maximum age for all French singers?
#   -> select avg(age), min(age), max(age) from singer where country = 'france'
#   gold: select avg(age), min(age), max(age) from singer where country = 'france'
#   EM=4/6 EA=6/6 VS=6/6
#
# [7/100] Show the name and the release year of the song by the youngest singer.
#   -> select s.name, s.song_release_year from singer s where s.age = (select min(age) from singer)
#   fix1: select name, song_release_year from singer where age = (select min(age) from singer)
#   fix2: select song_name, song_release_year from singer where age = (select min(age) from singer) order by song_release_year desc limit 1
#   gold: select song_name, song_release_year from singer order by age limit 1
#   EM=4/7 EA=7/7 VS=7/7
#
# [8/100] What are the names and release years for all the songs of the youngest singer?
#   -> select s.name, s.song_name, s.song_release_year from singer s where s.age = (select min(age) from singer)
#   fix1: select s.name, s.song_name, s.song_release_year from singer s where s.singer_id in ( select singer_id from singer where age = (select min(age) from singer) )
#   fix2: select name, song_release_year from singer where singer_id in (select singer_id from singer where age = (select min(age) from singer))
#   fix3: select song_name, song_release_year from singer where age = (select min(age) from singer)
#   gold: select song_name, song_release_year from singer order by age limit 1
#   EM=4/8 EA=8/8 VS=8/8
#
# [9/100] What are all distinct countries where singers above age 20 are from?
#   -> select distinct singer.country from singer where singer.age > 20
#   gold: select distinct country from singer where age > 20
#   EM=4/9 EA=9/9 VS=9/9
#
# [10/100] What are  the different countries with singers above age 20?
#   -> select distinct country from singer where age > 20
#   gold: select distinct country from singer where age > 20
#   EM=5/10 EA=10/10 VS=10/10
#
# [11/100] Show all countries and the number of singers in each country.
#   -> select singer.country, count(singer.singer_id) from singer group by singer.country
#   gold: select country, count(*) from singer group by country
#   EM=5/11 EA=11/11 VS=11/11
#
# [12/100] How many singers are from each country?
#   -> select singer.country, count(distinct singer.singer_id) from singer group by singer.country
#   gold: select country, count(*) from singer group by country
#   EM=5/12 EA=12/12 VS=12/12
#
# [13/100] List all song names by singers above the average age.
#   -> select distinct song.name from singer join singer_in_concert on singer.singer_id = singer_in_concert.singer_id join song on singer_in_concert.concert_id = song.concert_id where singer.age > (select avg(age) from singer)
#   fix1: select name from singer where age > (select avg(age) from singer)
#   fix2: select distinct s.song_name from singer as sg inner join singer_in_concert as sic on sg.singer_id = sic.singer_id inner join concert as c on sic.concert_id = c.concert_id inner join song as s on c.concert_id = s.concert_id where sg.age > (select avg(age) from singer)
#   fix3: select distinct s.song_name from singer as sg inner join singer_in_concert as sic on sg.singer_id = sic.singer_id inner join concert as c on sic.concert_id = c.concert_id inner join song as s on c.concert_id = s.concert_id where sg.age > (select avg(age) from singer)
#   gold: select song_name from singer where age > (select avg(age) from singer)
#   EM=5/13 EA=12/13 VS=12/13
#
# [14/100] What are all the song names by singers who are older than average?
#   -> select distinct song_name from singer where age > (select avg(age) from singer)
#   gold: select song_name from singer where age > (select avg(age) from singer)
#   EM=5/14 EA=13/14 VS=13/14
#
# [15/100] Show location and name for all stadiums with a capacity between 5000 and 10000.
#   -> select stadium.location, stadium.name from stadium where stadium.capacity between 5000 and 10000
#   gold: select location, name from stadium where capacity between 5000 and 10000
#   EM=5/15 EA=14/15 VS=14/15
#
# [16/100] What are the locations and names of all stations with capacity between 5000 and 10000?
#   -> select location, name from stadium where capacity between 5000 and 10000
#   gold: select location, name from stadium where capacity between 5000 and 10000
#   EM=6/16 EA=15/16 VS=15/16
#
# [17/100] What is the maximum capacity and the average of all stadiums ?
#   -> select max(capacity), avg(average) from stadium
#   fix1: select max(capacity), avg(capacity) from stadium
#   fix2: select max(capacity), avg(average) from stadium
#   fix3: select max(capacity), avg(capacity) from stadium
#   gold: select max(capacity), average from stadium
#   EM=6/17 EA=15/17 VS=16/17
#
# [18/100] What is the average and maximum capacities for all stadiums ?
#   -> select avg(capacity), max(capacity) from stadium
#   gold: select avg(capacity), max(capacity) from stadium
#   EM=7/18 EA=16/18 VS=17/18
#
# [19/100] What is the name and capacity for the stadium with highest average attendance?
#   -> select stadium.name, stadium.capacity from stadium join concert on stadium.stadium_id = concert.stadium_id group by stadium.stadium_id, stadium.name, stadium.capacity order by avg(concert.attendance) desc limit 1
#   fix1: select name, capacity from stadium order by average desc limit 1
#   gold: select name, capacity from stadium order by average desc limit 1
#   EM=8/19 EA=17/19 VS=18/19
#
# [20/100] What is the name and capacity for the stadium with the highest average attendance?
#   -> select stadium.name, stadium.capacity from stadium join concert on stadium.stadium_id = concert.stadium_id join singer_in_concert on concert.concert_id = singer_in_concert.concert_id group by stadium.stadium_id, stadium.name, stadium.capacity order by avg(stadium.average) desc limit 1
#   gold: select name, capacity from stadium order by average desc limit 1
#   EM=8/20 EA=18/20 VS=19/20
#
# [21/100] How many concerts are there in year 2014 or 2015?
#   -> select count(*) from concert where year in (2014, 2015)
#   gold: select count(*) from concert where year = 2014 or year = 2015
#   EM=8/21 EA=19/21 VS=20/21
#
# [22/100] How many concerts occurred in 2014 or 2015?
#   -> select count(*) from concert where year in (2014, 2015)
#   gold: select count(*) from concert where year = 2014 or year = 2015
#   EM=8/22 EA=20/22 VS=21/22
#
# [23/100] Show the stadium name and the number of concerts in each stadium.
#   -> select stadium.name, count(concert.concert_id) from stadium join concert on stadium.stadium_id = concert.stadium_id group by stadium.stadium_id, stadium.name
#   gold: select t2.name, count(*) from concert as t1 join stadium as t2 on t1.stadium_id = t2.stadium_id group by t1.stadium_id
#   EM=8/23 EA=21/23 VS=22/23
#
# [24/100] For each stadium, how many concerts play there?
#   -> select stadium.name, count(concert.concert_id) from stadium join concert on stadium.stadium_id = concert.stadium_id group by stadium.stadium_id, stadium.name
#   gold: select t2.name, count(*) from concert as t1 join stadium as t2 on t1.stadium_id = t2.stadium_id group by t1.stadium_id
#   EM=8/24 EA=22/24 VS=23/24
#
# [25/100] Show the stadium name and capacity with most number of concerts in year 2014 or after.
#   -> select s.name, s.capacity from stadium s join concert c on s.stadium_id = c.stadium_id where c.year >= 2014 group by s.stadium_id, s.name, s.capacity order by count(c.concert_id) desc limit 1
#   gold: select t2.name, t2.capacity from concert as t1 join stadium as t2 on t1.stadium_id = t2.stadium_id where t1.year >= 2014 group by t2.stadium_id order by count(*) desc limit 1
#   EM=8/25 EA=23/25 VS=24/25
#
# [26/100] What is the name and capacity of the stadium with the most concerts after 2013 ?
#   -> select stadium.name, stadium.capacity from stadium join concert on stadium.stadium_id = concert.stadium_id join singer_in_concert on concert.concert_id = singer_in_concert.concert_id where concert.year > 2013 group by stadium.stadium_id, stadium.name, stadium.capacity having count(concert.concert_id) = (select max(concert_count) from (select count(concert_id) as concert_count from concert where year > 2013 group by stadium_id) as sub)
#   fix1: select stadium.name, stadium.capacity from stadium join concert on stadium.stadium_id = concert.stadium_id where concert.year > 2013 group by stadium.stadium_id, stadium.name, stadium.capacity having count(concert.concert_id) = ( select max(concert_count) from ( select count(concert_id) as concert_count from concert where year > 2013 group by stadium_id ) as sub )
#   gold: select t2.name, t2.capacity from concert as t1 join stadium as t2 on t1.stadium_id = t2.stadium_id where t1.year > 2013 group by t2.stadium_id order by count(*) desc limit 1
#   EM=8/26 EA=24/26 VS=25/26
#
# [27/100] Which year has most number of concerts?
#   -> select concert.year, count(concert.concert_id) as concert_count from concert group by concert.year order by concert_count desc limit 1
#   fix1: select concert.year, count(*) as performance_count from concert join singer_in_concert on concert.concert_id = singer_in_concert.concert_id group by concert.year order by performance_count desc limit 1
#   fix2: select year, count(*) as concert_count from concert group by year order by concert_count desc limit 1
#   fix3: select concert.year, count(distinct concert.concert_id) as concert_count from concert inner join singer_in_concert on concert.concert_id = singer_in_concert.concert_id group by concert.year order by concert_count desc limit 1
#   gold: select year from concert group by year order by count(*) desc limit 1
#   EM=8/27 EA=24/27 VS=26/27
#
# [28/100] What is the year that had the most concerts?
#   -> select concert.year, count(concert.concert_id) as concert_count from concert group by concert.year order by concert_count desc limit 1
#   fix1: select concert.year, count(distinct concert.concert_id) as concert_count from concert join singer_in_concert on concert.concert_id = singer_in_concert.concert_id group by concert.year order by concert_count desc limit 1
#   fix2: select concert.year, count(*) as concert_count from concert group by concert.year order by concert_count desc limit 1
#   fix3: select year from concert group by year order by count(*) desc limit 1
#   gold: select year from concert group by year order by count(*) desc limit 1
#   EM=9/28 EA=25/28 VS=27/28
#
# [29/100] Show the stadium names without any concert.
#   -> select stadium.name from stadium left join concert on stadium.stadium_id = concert.stadium_id where concert.concert_id is null
#   gold: select name from stadium where stadium_id not in (select stadium_id from concert)
#   EM=9/29 EA=26/29 VS=28/29
#
# [30/100] What are the names of the stadiums without any concerts?
#   -> select stadium.name from stadium left join concert on stadium.stadium_id = concert.stadium_id where concert.concert_id is null
#   gold: select name from stadium where stadium_id not in (select stadium_id from concert)
#   EM=9/30 EA=27/30 VS=29/30
#
# [31/100] Show countries where a singer above age 40 and a singer below 30 are from.
#   -> select distinct country from singer where age > 40 intersect select distinct country from singer where age < 30
#   gold: select country from singer where age > 40 intersect select country from singer where age < 30
#   EM=9/31 EA=28/31 VS=30/31
#
# [32/100] Show names for all stadiums except for stadiums having a concert in year 2014.
#   -> select stadium.name from stadium where stadium.stadium_id not in (select concert.stadium_id from concert where concert.year = 2014)
#   gold: select name from stadium except select t2.name from concert as t1 join stadium as t2 on t1.stadium_id = t2.stadium_id where t1.year = 2014
#   EM=9/32 EA=29/32 VS=31/32
#
# [33/100] What are the names of all stadiums that did not have a concert in 2014?
#   -> select stadium.name from stadium except select stadium.name from stadium join concert on stadium.stadium_id = concert.stadium_id where concert.year = 2014
#   gold: select name from stadium except select t2.name from concert as t1 join stadium as t2 on t1.stadium_id = t2.stadium_id where t1.year = 2014
#   EM=9/33 EA=30/33 VS=32/33
#
# [34/100] Show the name and theme for all concerts and the number of singers in each concert.
#   -> select concert.concert_name, concert.theme, count(singer_in_concert.singer_id) as singer_count from concert join singer_in_concert on concert.concert_id = singer_in_concert.concert_id group by concert.concert_id, concert.concert_name, concert.theme
#   gold: select t2.concert_name, t2.theme, count(*) from singer_in_concert as t1 join concert as t2 on t1.concert_id = t2.concert_id group by t2.concert_id
#   EM=9/34 EA=31/34 VS=33/34
#
# [35/100] What are the names , themes , and number of singers for every concert ?
#   -> select concert.concert_name, concert.theme, count(singer_in_concert.singer_id) as number_of_singers from concert join singer_in_concert on concert.concert_id = singer_in_concert.concert_id group by concert.concert_id, concert.concert_name, concert.theme
#   gold: select t2.concert_name, t2.theme, count(*) from singer_in_concert as t1 join concert as t2 on t1.concert_id = t2.concert_id group by t2.concert_id
#   EM=9/35 EA=32/35 VS=34/35
#
# [36/100] List singer names and number of concerts for each singer.
#   -> select singer.name, count(singer_in_concert.concert_id) as number_of_concerts from singer join singer_in_concert on singer.singer_id = singer_in_concert.singer_id group by singer.singer_id, singer.name
#   gold: select t2.name, count(*) from singer_in_concert as t1 join singer as t2 on t1.singer_id = t2.singer_id group by t2.singer_id
#   EM=9/36 EA=33/36 VS=35/36
#
# [37/100] What are the names of the singers and number of concerts for each person?
#   -> select singer.name, count(singer_in_concert.concert_id) as number_of_concerts from singer join singer_in_concert on singer.singer_id = singer_in_concert.singer_id group by singer.singer_id, singer.name
#   gold: select t2.name, count(*) from singer_in_concert as t1 join singer as t2 on t1.singer_id = t2.singer_id group by t2.singer_id
#   EM=9/37 EA=34/37 VS=36/37
#
# [38/100] List all singer names in concerts in year 2014.
#   -> select distinct singer.name from singer join singer_in_concert on singer.singer_id = singer_in_concert.singer_id join concert on singer_in_concert.concert_id = concert.concert_id where concert.year = 2014
#   fix1: select distinct singer.name from singer join singer_in_concert on singer.singer_id = singer_in_concert.singer_id join concert on singer_in_concert.concert_id = concert.concert_id where concert.year = 2014
#   fix2: select distinct singer.name from singer join singer_in_concert on singer.singer_id = singer_in_concert.singer_id join concert on singer_in_concert.concert_id = concert.concert_id where concert.year = 2014
#   fix3: select distinct singer.name from singer join singer_in_concert on singer.singer_id = singer_in_concert.singer_id join concert on singer_in_concert.concert_id = concert.concert_id where concert.year = 2014
#   gold: select t2.name from singer_in_concert as t1 join singer as t2 on t1.singer_id = t2.singer_id join concert as t3 on t1.concert_id = t3.concert_id where t3.year = 2014
#   EM=9/38 EA=34/38 VS=37/38
#
# [39/100] What are the names of the singers who performed in a concert in 2014?
#   -> select distinct singer.name from singer_in_concert join concert on singer_in_concert.concert_id = concert.concert_id join singer on singer_in_concert.singer_id = singer.singer_id where concert.year = 2014
#   fix1: select distinct singer.singer_id, singer.name from singer_in_concert join concert on singer_in_concert.concert_id = concert.concert_id join singer on singer_in_concert.singer_id = singer.singer_id where concert.year = 2014
#   fix2: select distinct singer.name from singer_in_concert join concert on singer_in_concert.concert_id = concert.concert_id join singer on singer_in_concert.singer_id = singer.singer_id where concert.year = 2014
#   fix3: select distinct singer.name from singer_in_concert join concert on singer_in_concert.concert_id = concert.concert_id join singer on singer_in_concert.singer_id = singer.singer_id where concert.year = 2014
#   gold: select t2.name from singer_in_concert as t1 join singer as t2 on t1.singer_id = t2.singer_id join concert as t3 on t1.concert_id = t3.concert_id where t3.year = 2014
#   EM=9/39 EA=34/39 VS=38/39
#
# [40/100] what is the name and nation of the singer who have a song having 'Hey' in its name?
#   -> select singer.name, singer.country from singer where singer.song_name like '%hey%'
#   gold: select name, country from singer where song_name like '%hey%'
#   EM=9/40 EA=35/40 VS=39/40
#
# [41/100] What is the name and country of origin of every singer who has a song with the word 'Hey' in its title?
#   -> select distinct name, country from singer where song_name like '%hey%'
#   gold: select name, country from singer where song_name like '%hey%'
#   EM=9/41 EA=36/41 VS=40/41
#
# [42/100] Find the name and location of the stadiums which some concerts happened in the years of both 2014 and 2015.
#   -> select stadium.name, stadium.location from stadium join concert on stadium.stadium_id = concert.stadium_id where concert.year = 2014 intersect select stadium.name, stadium.location from stadium join concert on stadium.stadium_id = concert.stadium_id where concert.year = 2015
#   gold: select t2.name, t2.location from concert as t1 join stadium as t2 on t1.stadium_id = t2.stadium_id where t1.year = 2014 intersect select t2.name, t2.location from concert as t1 join stadium as t2 on t1.stadium_id = t2.stadium_id where t1.year = 2015
#   EM=9/42 EA=37/42 VS=41/42
#
# [43/100] What are the names and locations of the stadiums that had concerts that occurred in both 2014 and 2015?
#   -> select stadium.name, stadium.location from stadium join concert on stadium.stadium_id = concert.stadium_id where concert.year = 2014 intersect select stadium.name, stadium.location from stadium join concert on stadium.stadium_id = concert.stadium_id where concert.year = 2015
#   gold: select t2.name, t2.location from concert as t1 join stadium as t2 on t1.stadium_id = t2.stadium_id where t1.year = 2014 intersect select t2.name, t2.location from concert as t1 join stadium as t2 on t1.stadium_id = t2.stadium_id where t1.year = 2015
#   EM=9/43 EA=38/43 VS=42/43
#
# [44/100] Find the number of concerts happened in the stadium with the highest capacity .
#   -> select count(concert.concert_id) from concert join stadium on concert.stadium_id = stadium.stadium_id where stadium.capacity = (select max(capacity) from stadium)
#   gold: select count(*) from concert where stadium_id = (select stadium_id from stadium order by capacity desc limit 1)
#   EM=9/44 EA=39/44 VS=43/44
#
# [45/100] What are the number of concerts that occurred in the stadium with the largest capacity ?
#   -> select count(concert.concert_id) from stadium order by stadium.capacity desc limit 1 join concert on stadium.stadium_id = concert.stadium_id
#   fix1: select count(concert.concert_id) from concert where concert.stadium_id = ( select stadium.stadium_id from stadium order by stadium.capacity desc limit 1 )
#   gold: select count(*) from concert where stadium_id = (select stadium_id from stadium order by capacity desc limit 1)
#   EM=9/45 EA=40/45 VS=44/45
#
# [46/100] Find the number of pets whose weight is heavier than 10.
#   -> select count(*) from pets where weight > 10
#   gold: select count(*) from pets where weight > 10
#   EM=10/46 EA=41/46 VS=45/46
#
# [47/100] How many pets have a greater weight than 10?
#   -> select count(*) from pets where pets.weight > 10
#   gold: select count(*) from pets where weight > 10
#   EM=10/47 EA=42/47 VS=46/47
#
# [48/100] Find the weight of the youngest dog.
#   -> select pets.weight from pets join has_pet on pets.petid = has_pet.petid join student on has_pet.stuid = student.stuid where pets.pettype = 'dog' order by pets.pet_age asc limit 1
#   gold: select weight from pets order by pet_age limit 1
#   EM=10/48 EA=43/48 VS=47/48
#
# [49/100] How much does the youngest dog weigh?
#   -> select pets.weight from pets join has_pet on pets.petid = has_pet.petid where pets.pettype = 'dog' order by pets.pet_age asc limit 1
#   gold: select weight from pets order by pet_age limit 1
#   EM=10/49 EA=44/49 VS=48/49
#
# [50/100] Find the maximum weight for each type of pet. List the maximum weight and pet type.
#   -> select pettype, max(weight) as max_weight from pets group by pettype
#   gold: select max(weight), pettype from pets group by pettype
#   EM=10/50 EA=45/50 VS=49/50
#
# [51/100] List the maximum weight and type for each type of pet.
#   -> select pets.pettype, max(pets.weight) as max_weight from pets group by pets.pettype
#   gold: select max(weight), pettype from pets group by pettype
#   EM=10/51 EA=46/51 VS=50/51
#
# [52/100] Find number of pets owned by students who are older than 20.
#   -> select count(pets.petid) from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where student.age > 20
#   gold: select count(*) from student as t1 join has_pet as t2 on t1.stuid = t2.stuid where t1.age > 20
#   EM=10/52 EA=47/52 VS=51/52
#
# [53/100] How many pets are owned by students that have an age greater than 20?
#   -> select count(pets.petid) from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where student.age > 20
#   gold: select count(*) from student as t1 join has_pet as t2 on t1.stuid = t2.stuid where t1.age > 20
#   EM=10/53 EA=48/53 VS=52/53
#
# [54/100] Find the number of dog pets that are raised by female students (with sex F).
#   -> select count(pets.petid) from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where student.sex = 'f' and pets.pettype = 'dog'
#   gold: select count(*) from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t2.petid = t3.petid where t1.sex = 'f' and t3.pettype = 'dog'
#   EM=10/54 EA=49/54 VS=53/54
#
# [55/100] How many dog pets are raised by female students?
#   -> select count(pets.petid) from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where pets.pettype = 'dog' and student.sex = 'female'
#   gold: select count(*) from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t2.petid = t3.petid where t1.sex = 'f' and t3.pettype = 'dog'
#   EM=10/55 EA=50/55 VS=54/55
#
# [56/100] Find the number of distinct type of pets.
#   -> select count(distinct pettype) from pets
#   gold: select count(distinct pettype) from pets
#   EM=11/56 EA=51/56 VS=55/56
#
# [57/100] How many different types of pet are there?
#   -> select count(distinct pets.pettype) from pets
#   gold: select count(distinct pettype) from pets
#   EM=11/57 EA=52/57 VS=56/57
#
# [58/100] Find the first name of students who have cat or dog pet.
#   -> select student.fname from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where pets.pettype in ('cat', 'dog')
#   fix1: select s.fname from student s where s.stuid in ( select hp.stuid from has_pet hp join pets p on hp.petid = p.petid group by hp.stuid having count(*) = sum(case when p.pettype in ('cat', 'dog') then 1 else 0 end) and sum(case when p.pettype in ('cat', 'dog') then 1 else 0 end) > 0 )
#   gold: select distinct t1.fname from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'cat' or t3.pettype = 'dog'
#   EM=11/58 EA=53/58 VS=57/58
#
# [59/100] What are the first names of every student who has a cat or dog as a pet?
#   -> select distinct student.fname from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where pets.pettype in ('cat', 'dog')
#   gold: select distinct t1.fname from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'cat' or t3.pettype = 'dog'
#   EM=11/59 EA=54/59 VS=58/59
#
# [60/100] Find the first name of students who have both cat and dog pets .
#   -> select student.fname from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where pets.pettype = 'cat' intersect select student.fname from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where pets.pettype = 'dog'
#   gold: select t1.fname from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'cat' intersect select t1.fname from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'dog'
#   EM=11/60 EA=55/60 VS=59/60
#
# [61/100] What are the students' first names who have both cats and dogs as pets?
#   -> select student.fname from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where pets.pettype = 'cat' intersect select student.fname from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where pets.pettype = 'dog'
#   gold: select t1.fname from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'cat' intersect select t1.fname from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'dog'
#   EM=11/61 EA=56/61 VS=60/61
#
# [62/100] Find the major and age of students who do not have a cat pet.
#   -> select student.major, student.age from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where pets.pettype != 'cat' except select student.major, student.age from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where pets.pettype = 'cat'
#   fix1: select student.major, student.age from student where not exists (select 1 from has_pet join pets on has_pet.petid = pets.petid where has_pet.stuid = student.stuid and pets.pettype = 'cat')
#   gold: select major, age from student where stuid not in (select t1.stuid from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'cat')
#   EM=11/62 EA=57/62 VS=61/62
#
# [63/100] What major is every student who does not own a cat as a pet, and also how old are they?
#   -> select distinct student.major, student.age from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where pets.pettype != 'cat'
#   fix1: select distinct s.major, s.age from student s where s.stuid not in ( select hp.stuid from has_pet hp join pets p on hp.petid = p.petid where p.pettype = 'cat' )
#   fix2: select s.major, s.age from student s left join has_pet hp on s.stuid = hp.stuid left join pets p on hp.petid = p.petid group by s.stuid, s.major, s.age having count(case when p.pettype = 'cat' then 1 end) = 0
#   gold: select major, age from student where stuid not in (select t1.stuid from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'cat')
#   EM=11/63 EA=58/63 VS=62/63
#
# [64/100] Find the id of students who do not have a cat pet.
#   -> select student.stuid from student left join has_pet on student.stuid = has_pet.stuid left join pets on has_pet.petid = pets.petid group by student.stuid having count(case when pets.pettype = 'cat' then 1 end) = 0
#   gold: select stuid from student except select t1.stuid from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'cat'
#   EM=11/64 EA=59/64 VS=63/64
#
# [65/100] What are the ids of the students who do not own cats as pets?
#   -> select stuid from student except select student.stuid from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where pets.pettype = 'cat'
#   gold: select stuid from student except select t1.stuid from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'cat'
#   EM=11/65 EA=60/65 VS=64/65
#
# [66/100] Find the first name and age of students who have a dog but do not have a cat as a pet.
#   -> select student.fname, student.age from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where pets.pettype = 'dog' except select student.fname, student.age from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where pets.pettype = 'cat'
#   fix1: select s.fname, s.age from student s where exists ( select 1 from has_pet hp join pets p on hp.petid = p.petid where hp.stuid = s.stuid and p.pettype = 'dog' ) and not exists ( select 1 from has_pet hp join pets p on hp.petid = p.petid where hp.stuid = s.stuid and p.pettype = 'cat' )
#   fix2: select s.fname, s.age from student s where exists ( select 1 from has_pet hp_dog join pets p_dog on hp_dog.petid = p_dog.petid where hp_dog.stuid = s.stuid and p_dog.pettype = 'dog' ) and not exists ( select 1 from has_pet hp_cat join pets p_cat on hp_cat.petid = p_cat.petid where hp_cat.stuid = s.stuid and p_cat.pettype = 'cat' )
#   fix3: select s.fname, s.age from student s where exists ( select 1 from has_pet hp_dog join pets p_dog on hp_dog.petid = p_dog.petid where hp_dog.stuid = s.stuid and p_dog.pettype = 'dog' ) and not exists ( select 1 from has_pet hp_cat join pets p_cat on hp_cat.petid = p_cat.petid where hp_cat.stuid = s.stuid and p_cat.pettype = 'cat' )
#   gold: select t1.fname, t1.age from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'dog' and t1.stuid not in (select t1.stuid from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'cat')
#   EM=11/66 EA=60/66 VS=65/66
#
# [67/100] What is the first name of every student who has a dog but does not have a cat?
#   -> select student.fname from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where pets.pettype = 'dog' except select student.fname from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where pets.pettype = 'cat'
#   fix1: select s.fname from student s where s.stuid in ( select distinct hp.stuid from has_pet hp join pets p on hp.petid = p.petid where p.pettype = 'dog' ) and s.stuid not in ( select distinct hp.stuid from has_pet hp join pets p on hp.petid = p.petid where p.pettype = 'cat' )
#   fix2: select s.fname from student s where s.stuid in (select hp.stuid from has_pet hp join pets p on hp.petid = p.petid where p.pettype = 'dog') and s.stuid not in (select hp.stuid from has_pet hp join pets p on hp.petid = p.petid where p.pettype = 'cat')
#   fix3: select s.fname from student s where s.stuid in (select hp.stuid from has_pet hp join pets p on hp.petid = p.petid where p.pettype = 'dog') and s.stuid not in (select hp.stuid from has_pet hp join pets p on hp.petid = p.petid where p.pettype = 'cat')
#   gold: select t1.fname, t1.age from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'dog' and t1.stuid not in (select t1.stuid from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'cat')
#   EM=11/67 EA=60/67 VS=66/67
#
# [68/100] Find the type and weight of the youngest pet.
#   -> select pets.pettype, pets.weight from pets join has_pet on pets.petid = has_pet.petid where pets.pet_age = (select min(pet_age) from pets)
#   gold: select pettype, weight from pets order by pet_age limit 1
#   EM=11/68 EA=61/68 VS=67/68
#
# [69/100] What type of pet is the youngest animal, and how much does it weigh?
#   -> select pets.pettype, pets.weight from pets join has_pet on pets.petid = has_pet.petid join student on has_pet.stuid = student.stuid where pets.pet_age = (select min(pet_age) from pets) order by pets.pet_age asc limit 1
#   gold: select pettype, weight from pets order by pet_age limit 1
#   EM=11/69 EA=62/69 VS=68/69
#
# [70/100] Find the id and weight of all pets whose age is older than 1.
#   -> select pets.petid, pets.weight from pets where pets.pet_age > 1
#   gold: select petid, weight from pets where pet_age > 1
#   EM=11/70 EA=63/70 VS=69/70
#
# [71/100] What is the id and weight of every pet who is older than 1?
#   -> select pets.petid, pets.weight from pets where pets.pet_age > 1
#   gold: select petid, weight from pets where pet_age > 1
#   EM=11/71 EA=64/71 VS=70/71
#
# [72/100] Find the average and maximum age for each type of pet.
#   -> select pets.pettype, avg(pets.pet_age) as avg_age, max(pets.pet_age) as max_age from pets join has_pet on pets.petid = has_pet.petid join student on has_pet.stuid = student.stuid group by pets.pettype
#   gold: select avg(pet_age), max(pet_age), pettype from pets group by pettype
#   EM=11/72 EA=65/72 VS=71/72
#
# [73/100] What is the average and maximum age for each pet type?
#   -> select pettype, avg(pet_age) as avg_age, max(pet_age) as max_age from pets group by pettype
#   gold: select avg(pet_age), max(pet_age), pettype from pets group by pettype
#   EM=11/73 EA=66/73 VS=72/73
#
# [74/100] Find the average weight for each pet type.
#   -> select pets.pettype, avg(pets.weight) from pets group by pets.pettype
#   gold: select avg(weight), pettype from pets group by pettype
#   EM=11/74 EA=67/74 VS=73/74
#
# [75/100] What is the average weight for each type of pet?
#   -> select pets.pettype, avg(pets.weight) from pets group by pets.pettype
#   gold: select avg(weight), pettype from pets group by pettype
#   EM=11/75 EA=68/75 VS=74/75
#
# [76/100] Find the first name and age of students who have a pet.
#   -> select student.fname, student.age from student join has_pet on student.stuid = has_pet.stuid where has_pet.petid is not null
#   fix1: select student.fname, student.age from student join has_pet on student.stuid = has_pet.stuid
#   fix2: select distinct student.fname, student.age from student join has_pet on student.stuid = has_pet.stuid
#   gold: select distinct t1.fname, t1.age from student as t1 join has_pet as t2 on t1.stuid = t2.stuid
#   EM=11/76 EA=69/76 VS=75/76
#
# [77/100] What are the different first names and ages of the students who do have pets?
#   -> select distinct student.fname, student.age from student join has_pet on student.stuid = has_pet.stuid where has_pet.petid is not null
#   gold: select distinct t1.fname, t1.age from student as t1 join has_pet as t2 on t1.stuid = t2.stuid
#   EM=11/77 EA=70/77 VS=76/77
#
# [78/100] Find the id of the pet owned by student whose last name is ‘Smith’.
#   -> select pets.petid from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where student.lname = 'smith'
#   gold: select t2.petid from student as t1 join has_pet as t2 on t1.stuid = t2.stuid where t1.lname = 'smith'
#   EM=11/78 EA=71/78 VS=77/78
#
# [79/100] What is the id of the pet owned by the student whose last name is 'Smith'?
#   -> select pets.petid from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where student.lname = 'smith'
#   gold: select t2.petid from student as t1 join has_pet as t2 on t1.stuid = t2.stuid where t1.lname = 'smith'
#   EM=11/79 EA=72/79 VS=78/79
#
# [80/100] Find the number of pets for each student who has any pet and student id.
#   -> select student.stuid, count(has_pet.petid) as num_pets from student join has_pet on student.stuid = has_pet.stuid group by student.stuid having count(has_pet.petid) > 0
#   gold: select count(*), t1.stuid from student as t1 join has_pet as t2 on t1.stuid = t2.stuid group by t1.stuid
#   EM=11/80 EA=73/80 VS=79/80
#
# [81/100] For students who have pets , how many pets does each student have ? list their ids instead of names .
#   -> select student.stuid, count(pets.petid) as pet_count from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid group by student.stuid
#   gold: select count(*), t1.stuid from student as t1 join has_pet as t2 on t1.stuid = t2.stuid group by t1.stuid
#   EM=11/81 EA=74/81 VS=80/81
#
# [82/100] Find the first name and gender of student who have more than one pet.
#   -> select student.fname, student.sex from student join has_pet on student.stuid = has_pet.stuid group by student.stuid, student.fname, student.sex having count(has_pet.petid) > 1
#   gold: select t1.fname, t1.sex from student as t1 join has_pet as t2 on t1.stuid = t2.stuid group by t1.stuid having count(*) > 1
#   EM=11/82 EA=75/82 VS=81/82
#
# [83/100] What is the first name and gender of the all the students who have more than one pet?
#   -> select student.fname, student.sex from student join has_pet on student.stuid = has_pet.stuid group by student.stuid, student.fname, student.sex having count(has_pet.petid) > 1
#   gold: select t1.fname, t1.sex from student as t1 join has_pet as t2 on t1.stuid = t2.stuid group by t1.stuid having count(*) > 1
#   EM=11/83 EA=76/83 VS=82/83
#
# [84/100] Find the last name of the student who has a cat that is age 3.
#   -> select student.lname from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where pets.pettype = 'cat' and pets.pet_age = 3 order by student.lname limit 1
#   gold: select t1.lname from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pet_age = 3 and t3.pettype = 'cat'
#   EM=11/84 EA=77/84 VS=83/84
#
# [85/100] What is the last name of the student who has a cat that is 3 years old?
#   -> select student.lname from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where pets.pet_age = 3 limit 1
#   gold: select t1.lname from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pet_age = 3 and t3.pettype = 'cat'
#   EM=11/85 EA=78/85 VS=84/85
#
# [86/100] Find the average age of students who do not have any pet .
#   -> select avg(student.age) from student left join has_pet on student.stuid = has_pet.stuid where has_pet.stuid is null
#   gold: select avg(age) from student where stuid not in (select stuid from has_pet)
#   EM=11/86 EA=79/86 VS=85/86
#
# [87/100] What is the average age for all students who do not own any pets ?
#   -> select avg(student.age) from student where student.stuid not in (select distinct stuid from has_pet)
#   gold: select avg(age) from student where stuid not in (select stuid from has_pet)
#   EM=11/87 EA=80/87 VS=86/87
#
# [88/100] How many continents are there?
#   -> select count(distinct continents.continent) from continents
#   gold: select count(*) from continents
#   EM=11/88 EA=81/88 VS=87/88
#
# [89/100] What is the number of continents?
#   -> select count(distinct continents.continent) from continents
#   gold: select count(*) from continents
#   EM=11/89 EA=82/89 VS=88/89
#
# [90/100] How many countries does each continent have? List the continent id, continent name and the number of countries.
#   -> select continents.contid, continents.continent, count(countries.countryid) from continents join countries on continents.contid = countries.continent group by continents.contid, continents.continent
#   gold: select t1.contid, t1.continent, count(*) from continents as t1 join countries as t2 on t1.contid = t2.continent group by t1.contid
#   EM=11/90 EA=83/90 VS=89/90
#
# [91/100] For each continent, list its id, name, and how many countries it has?
#   -> select continents.contid, continents.continent, count(countries.countryid) from continents join countries on continents.contid = countries.continent group by continents.contid, continents.continent
#   gold: select t1.contid, t1.continent, count(*) from continents as t1 join countries as t2 on t1.contid = t2.continent group by t1.contid
#   EM=11/91 EA=84/91 VS=90/91
#
# [92/100] How many countries are listed?
#   -> select count(distinct countryid) from countries
#   gold: select count(*) from countries
#   EM=11/92 EA=85/92 VS=91/92
#
# [93/100] How many countries exist?
#   -> select count(distinct countryid) from countries
#   gold: select count(*) from countries
#   EM=11/93 EA=86/93 VS=92/93
#
# [94/100] How many models does each car maker produce? List maker full name, id and the number.
#   -> select car_makers.fullname, car_makers.id, count(model_list.modelid) as number_of_models from car_makers join model_list on car_makers.id = model_list.maker group by car_makers.fullname, car_makers.id
#   gold: select t1.fullname, t1.id, count(*) from car_makers as t1 join model_list as t2 on t1.id = t2.maker group by t1.id
#   EM=11/94 EA=87/94 VS=93/94
#
# [95/100] What is the full name of each car maker, along with its id and how many models it produces?
#   -> select car_makers.id, car_makers.fullname, count(model_list.modelid) as model_count from car_makers join model_list on car_makers.maker = model_list.maker group by car_makers.id, car_makers.fullname
#   fix1: select car_makers.maker, car_makers.fullname, count(model_list.modelid) as model_count from car_makers join model_list on car_makers.maker = model_list.maker group by car_makers.maker, car_makers.fullname
#   fix2: select car_makers.id, car_makers.fullname, count(model_list.modelid) as model_count from car_makers join model_list on car_makers.maker = model_list.maker group by car_makers.id, car_makers.fullname
#   fix3: select car_makers.id, car_makers.fullname, count(model_list.modelid) as model_count from car_makers join model_list on car_makers.id = model_list.maker group by car_makers.id, car_makers.fullname
#   gold: select t1.fullname, t1.id, count(*) from car_makers as t1 join model_list as t2 on t1.id = t2.maker group by t1.id
#   EM=11/95 EA=88/95 VS=94/95
#
# [96/100] Which model of the car has the minimum horsepower?
#   -> select car_names.model from cars_data join car_names on car_names.makeid = cars_data.id where cars_data.horsepower = (select min(horsepower) from cars_data)
#   fix1: select car_names.model from cars_data join car_names on car_names.makeid = cars_data.id where cars_data.horsepower = (select min(horsepower) from cars_data)
#   fix2: select car_names.model from cars_data join car_names on cars_data.id = car_names.makeid where cars_data.horsepower = (select min(horsepower) from cars_data)
#   fix3: select car_names.model from cars_data join car_names on car_names.makeid = cars_data.id where cars_data.horsepower = (select min(horsepower) from cars_data)
#   gold: select t1.model from car_names as t1 join cars_data as t2 on t1.makeid = t2.id order by t2.horsepower asc limit 1
#   EM=11/96 EA=88/96 VS=95/96
#
# [97/100] What is the model of the car with the smallest amount of horsepower?
#   -> select car_names.model from cars_data join car_names on cars_data.id = car_names.makeid where cars_data.horsepower = (select min(horsepower) from cars_data)
#   fix1: select car_names.model from cars_data join car_names on cars_data.id = car_names.makeid where cars_data.horsepower = (select min(horsepower) from cars_data)
#   fix2: select car_names.model from cars_data join car_names on cars_data.id = car_names.makeid where cars_data.horsepower = (select min(horsepower) from cars_data)
#   fix3: select car_names.model from car_names join cars_data on car_names.makeid = cars_data.id where cars_data.horsepower = (select min(horsepower) from cars_data)
#   gold: select t1.model from car_names as t1 join cars_data as t2 on t1.makeid = t2.id order by t2.horsepower asc limit 1
#   EM=11/97 EA=88/97 VS=96/97
#
# [98/100] Find the model of the car whose weight is below the average weight.
#   -> select model_list.model from cars_data join car_names on cars_data.id = car_names.makeid join model_list on car_names.model = model_list.modelid where cars_data.weight < (select avg(weight) from cars_data)
#   fix1: select model_list.model from cars_data join car_names on cars_data.id = car_names.makeid join model_list on car_names.model = model_list.modelid where cars_data.weight < (select avg(weight) from cars_data)
#   fix2: select model_list.model from cars_data join car_names on cars_data.id = car_names.makeid join model_list on car_names.model = model_list.model where cars_data.weight < (select avg(weight) from cars_data)
#   fix3: select model_list.model from cars_data join car_names on cars_data.id = car_names.makeid join model_list on car_names.model = model_list.model where cars_data.weight < (select avg(weight) from cars_data)
#   gold: select t1.model from car_names as t1 join cars_data as t2 on t1.makeid = t2.id where t2.weight < (select avg(weight) from cars_data)
#   EM=11/98 EA=88/98 VS=97/98
#
# [99/100] What is the model for the car with a weight smaller than the average?
#   -> select model_list.model from model_list join car_names on model_list.modelid = car_names.model join cars_data on car_names.makeid = cars_data.id where cars_data.weight < (select avg(weight) from cars_data)
#   fix1: select distinct model_list.model from cars_data join car_names on cars_data.id = car_names.makeid join model_list on car_names.model = model_list.model where cars_data.weight < (select avg(weight) from cars_data)
#   fix2: select distinct model_list.model from cars_data join car_names on cars_data.id = car_names.makeid join model_list on car_names.model = model_list.model where cars_data.weight < (select avg(weight) from cars_data)
#   fix3: select distinct model_list.model from cars_data join car_names on cars_data.id = car_names.makeid join model_list on car_names.model = model_list.modelid where cars_data.weight < (select avg(weight) from cars_data)
#   gold: select t1.model from car_names as t1 join cars_data as t2 on t1.makeid = t2.id where t2.weight < (select avg(weight) from cars_data)
#   EM=11/99 EA=88/99 VS=98/99
#
# [100/100] Find the name of the makers that produced some cars in the year of 1970?
#   -> select distinct car_makers.maker from car_makers join model_list on car_makers.id = model_list.maker join car_names on model_list.model = car_names.model join cars_data on car_names.makeid = cars_data.id where cars_data.year = 1970
#   gold: select distinct t1.maker from car_makers as t1 join model_list as t2 on t1.id = t2.maker join car_names as t3 on t2.model = t3.model join cars_data as t4 on t3.makeid = t4.id where t4.year = '1970'
#   EM=11/100 EA=89/100 VS=99/100
#
# === sot_full === {"total": 100, "em": 11, "vs": 99, "ea": 89, "em%": 0.11, "vs%": 0.99, "ea%": 0.89}

# %%
r2 = run(gen_sot, "no_correction", correct=False)
# Out:
# [1/100] How many singers do we have?
#   -> select count(distinct singer.singer_id) from singer
#   gold: select count(*) from singer
#   EM=0/1 EA=1/1 VS=1/1
#
# [2/100] What is the total number of singers?
#   -> select count(distinct singer.singer_id) from singer
#   gold: select count(*) from singer
#   EM=0/2 EA=2/2 VS=2/2
#
# [3/100] Show name, country, age for all singers ordered by age from the oldest to the youngest.
#   -> select name, country, age from singer order by age desc
#   gold: select name, country, age from singer order by age desc
#   EM=1/3 EA=3/3 VS=3/3
#
# [4/100] What are the names, countries, and ages for every singer in descending order of age?
#   -> select name, country, age from singer order by age desc
#   gold: select name, country, age from singer order by age desc
#   EM=2/4 EA=4/4 VS=4/4
#
# [5/100] What is the average, minimum, and maximum age of all singers from France?
#   -> select avg(singer.age), min(singer.age), max(singer.age) from singer where singer.country = 'france'
#   gold: select avg(age), min(age), max(age) from singer where country = 'france'
#   EM=2/5 EA=5/5 VS=5/5
#
# [6/100] What is the average, minimum, and maximum age for all French singers?
#   -> select avg(age), min(age), max(age) from singer where country = 'french'
#   gold: select avg(age), min(age), max(age) from singer where country = 'france'
#   EM=2/6 EA=6/6 VS=6/6
#
# [7/100] Show the name and the release year of the song by the youngest singer.
#   -> select s.name, s.song_release_year from singer s where s.age = (select min(age) from singer)
#   gold: select song_name, song_release_year from singer order by age limit 1
#   EM=2/7 EA=6/7 VS=7/7
#
# [8/100] What are the names and release years for all the songs of the youngest singer?
#   -> select name, song_name, song_release_year from singer where age = (select min(age) from singer)
#   gold: select song_name, song_release_year from singer order by age limit 1
#   EM=2/8 EA=6/8 VS=8/8
#
# [9/100] What are all distinct countries where singers above age 20 are from?
#   -> select distinct singer.country from singer where singer.age > 20
#   gold: select distinct country from singer where age > 20
#   EM=2/9 EA=7/9 VS=9/9
#
# [10/100] What are  the different countries with singers above age 20?
#   -> select distinct singer.country from singer where singer.age > 20
#   gold: select distinct country from singer where age > 20
#   EM=2/10 EA=8/10 VS=10/10
#
# [11/100] Show all countries and the number of singers in each country.
#   -> select singer.country, count(singer.singer_id) from singer group by singer.country
#   gold: select country, count(*) from singer group by country
#   EM=2/11 EA=9/11 VS=11/11
#
# [12/100] How many singers are from each country?
#   -> select singer.country, count(singer.singer_id) from singer group by singer.country
#   gold: select country, count(*) from singer group by country
#   EM=2/12 EA=10/12 VS=12/12
#
# [13/100] List all song names by singers above the average age.
#   -> select song_name from singer where age > (select avg(age) from singer)
#   gold: select song_name from singer where age > (select avg(age) from singer)
#   EM=3/13 EA=11/13 VS=13/13
#
# [14/100] What are all the song names by singers who are older than average?
#   -> select singer.name, singer.song_name from singer where singer.age > (select avg(age) from singer)
#   gold: select song_name from singer where age > (select avg(age) from singer)
#   EM=3/14 EA=11/14 VS=14/14
#
# [15/100] Show location and name for all stadiums with a capacity between 5000 and 10000.
#   -> select stadium.location, stadium.name from stadium where stadium.capacity between 5000 and 10000
#   gold: select location, name from stadium where capacity between 5000 and 10000
#   EM=3/15 EA=12/15 VS=15/15
#
# [16/100] What are the locations and names of all stations with capacity between 5000 and 10000?
#   -> select stadium.location, stadium.name from stadium where stadium.capacity between 5000 and 10000
#   gold: select location, name from stadium where capacity between 5000 and 10000
#   EM=3/16 EA=13/16 VS=16/16
#
# [17/100] What is the maximum capacity and the average of all stadiums ?
#   -> select max(capacity), avg(average) from stadium
#   gold: select max(capacity), average from stadium
#   EM=3/17 EA=13/17 VS=17/17
#
# [18/100] What is the average and maximum capacities for all stadiums ?
#   -> select avg(stadium.capacity), max(stadium.capacity) from stadium
#   gold: select avg(capacity), max(capacity) from stadium
#   EM=3/18 EA=14/18 VS=18/18
#
# [19/100] What is the name and capacity for the stadium with highest average attendance?
#   -> select name, capacity from stadium order by average desc limit 1
#   gold: select name, capacity from stadium order by average desc limit 1
#   EM=4/19 EA=15/19 VS=19/19
#
# [20/100] What is the name and capacity for the stadium with the highest average attendance?
#   -> select stadium.name, stadium.capacity from stadium join concert on stadium.stadium_id = concert.stadium_id group by stadium.stadium_id, stadium.name, stadium.capacity order by avg(stadium.average) desc limit 1
#   gold: select name, capacity from stadium order by average desc limit 1
#   EM=4/20 EA=16/20 VS=20/20
#
# [21/100] How many concerts are there in year 2014 or 2015?
#   -> select count(concert.concert_id) from concert where concert.year in (2014, 2015)
#   gold: select count(*) from concert where year = 2014 or year = 2015
#   EM=4/21 EA=17/21 VS=21/21
#
# [22/100] How many concerts occurred in 2014 or 2015?
#   -> select count(concert.concert_id) from concert where concert.year in (2014, 2015)
#   gold: select count(*) from concert where year = 2014 or year = 2015
#   EM=4/22 EA=18/22 VS=22/22
#
# [23/100] Show the stadium name and the number of concerts in each stadium.
#   -> select stadium.name, count(concert.concert_id) from stadium join concert on stadium.stadium_id = concert.stadium_id group by stadium.stadium_id, stadium.name
#   gold: select t2.name, count(*) from concert as t1 join stadium as t2 on t1.stadium_id = t2.stadium_id group by t1.stadium_id
#   EM=4/23 EA=19/23 VS=23/23
#
# [24/100] For each stadium, how many concerts play there?
#   -> select stadium.name, count(concert.concert_id) from stadium join concert on stadium.stadium_id = concert.stadium_id group by stadium.name
#   gold: select t2.name, count(*) from concert as t1 join stadium as t2 on t1.stadium_id = t2.stadium_id group by t1.stadium_id
#   EM=4/24 EA=20/24 VS=24/24
#
# [25/100] Show the stadium name and capacity with most number of concerts in year 2014 or after.
#   -> select stadium.name, stadium.capacity from stadium join concert on stadium.stadium_id = concert.stadium_id where concert.year >= 2014 group by stadium.stadium_id, stadium.name, stadium.capacity order by count(concert.concert_id) desc limit 1
#   gold: select t2.name, t2.capacity from concert as t1 join stadium as t2 on t1.stadium_id = t2.stadium_id where t1.year >= 2014 group by t2.stadium_id order by count(*) desc limit 1
#   EM=4/25 EA=21/25 VS=25/25
#
# [26/100] What is the name and capacity of the stadium with the most concerts after 2013 ?
#   -> select stadium.name, stadium.capacity, count(concert.concert_id) from stadium join concert on stadium.stadium_id = concert.stadium_id where concert.year > 2013 group by stadium.stadium_id, stadium.name, stadium.capacity order by count(concert.concert_id) desc limit 1
#   gold: select t2.name, t2.capacity from concert as t1 join stadium as t2 on t1.stadium_id = t2.stadium_id where t1.year > 2013 group by t2.stadium_id order by count(*) desc limit 1
#   EM=4/26 EA=21/26 VS=26/26
#
# [27/100] Which year has most number of concerts?
#   -> select concert.year, count(concert.concert_id) as concert_count from concert group by concert.year order by concert_count desc limit 1
#   gold: select year from concert group by year order by count(*) desc limit 1
#   EM=4/27 EA=21/27 VS=27/27
#
# [28/100] What is the year that had the most concerts?
#   -> select concert.year, count(concert.concert_id) as concert_count from concert group by concert.year order by concert_count desc limit 1
#   gold: select year from concert group by year order by count(*) desc limit 1
#   EM=4/28 EA=21/28 VS=28/28
#
# [29/100] Show the stadium names without any concert.
#   -> select stadium.name from stadium left join concert on stadium.stadium_id = concert.stadium_id where concert.concert_id is null
#   gold: select name from stadium where stadium_id not in (select stadium_id from concert)
#   EM=4/29 EA=22/29 VS=29/29
#
# [30/100] What are the names of the stadiums without any concerts?
#   -> select stadium.name from stadium left join concert on stadium.stadium_id = concert.stadium_id where concert.concert_id is null
#   gold: select name from stadium where stadium_id not in (select stadium_id from concert)
#   EM=4/30 EA=23/30 VS=30/30
#
# [31/100] Show countries where a singer above age 40 and a singer below 30 are from.
#   -> select distinct s1.country from singer s1 join singer s2 on s1.country = s2.country where s1.age > 40 and s2.age < 30
#   gold: select country from singer where age > 40 intersect select country from singer where age < 30
#   EM=4/31 EA=24/31 VS=31/31
#
# [32/100] Show names for all stadiums except for stadiums having a concert in year 2014.
#   -> select name from stadium except select stadium.name from stadium join concert on stadium.stadium_id = concert.stadium_id where concert.year = 2014
#   gold: select name from stadium except select t2.name from concert as t1 join stadium as t2 on t1.stadium_id = t2.stadium_id where t1.year = 2014
#   EM=4/32 EA=25/32 VS=32/32
#
# [33/100] What are the names of all stadiums that did not have a concert in 2014?
#   -> select name from stadium where stadium_id not in (select stadium_id from concert where year = 2014)
#   gold: select name from stadium except select t2.name from concert as t1 join stadium as t2 on t1.stadium_id = t2.stadium_id where t1.year = 2014
#   EM=4/33 EA=26/33 VS=33/33
#
# [34/100] Show the name and theme for all concerts and the number of singers in each concert.
#   -> select concert.concert_name, concert.theme, count(singer_in_concert.singer_id) as singer_count from concert join singer_in_concert on concert.concert_id = singer_in_concert.concert_id group by concert.concert_id, concert.concert_name, concert.theme
#   gold: select t2.concert_name, t2.theme, count(*) from singer_in_concert as t1 join concert as t2 on t1.concert_id = t2.concert_id group by t2.concert_id
#   EM=4/34 EA=27/34 VS=34/34
#
# [35/100] What are the names , themes , and number of singers for every concert ?
#   -> select concert.concert_name, concert.theme, count(singer_in_concert.singer_id) as number_of_singers from concert join singer_in_concert on concert.concert_id = singer_in_concert.concert_id group by concert.concert_id, concert.concert_name, concert.theme
#   gold: select t2.concert_name, t2.theme, count(*) from singer_in_concert as t1 join concert as t2 on t1.concert_id = t2.concert_id group by t2.concert_id
#   EM=4/35 EA=28/35 VS=35/35
#
# [36/100] List singer names and number of concerts for each singer.
#   -> select singer.name, count(concert.concert_id) as number_of_concerts from singer join singer_in_concert on singer.singer_id = singer_in_concert.singer_id join concert on singer_in_concert.concert_id = concert.concert_id group by singer.singer_id, singer.name
#   gold: select t2.name, count(*) from singer_in_concert as t1 join singer as t2 on t1.singer_id = t2.singer_id group by t2.singer_id
#   EM=4/36 EA=29/36 VS=36/36
#
# [37/100] What are the names of the singers and number of concerts for each person?
#   -> select singer.name, count(singer_in_concert.concert_id) as number_of_concerts from singer join singer_in_concert on singer.singer_id = singer_in_concert.singer_id group by singer.singer_id, singer.name
#   gold: select t2.name, count(*) from singer_in_concert as t1 join singer as t2 on t1.singer_id = t2.singer_id group by t2.singer_id
#   EM=4/37 EA=30/37 VS=37/37
#
# [38/100] List all singer names in concerts in year 2014.
#   -> select distinct singer.name from singer join singer_in_concert on singer.singer_id = singer_in_concert.singer_id join concert on singer_in_concert.concert_id = concert.concert_id where concert.year = 2014
#   gold: select t2.name from singer_in_concert as t1 join singer as t2 on t1.singer_id = t2.singer_id join concert as t3 on t1.concert_id = t3.concert_id where t3.year = 2014
#   EM=4/38 EA=30/38 VS=38/38
#
# [39/100] What are the names of the singers who performed in a concert in 2014?
#   -> select singer.name from singer_in_concert join singer on singer_in_concert.singer_id = singer.singer_id join concert on singer_in_concert.concert_id = concert.concert_id where concert.year = 2014
#   gold: select t2.name from singer_in_concert as t1 join singer as t2 on t1.singer_id = t2.singer_id join concert as t3 on t1.concert_id = t3.concert_id where t3.year = 2014
#   EM=4/39 EA=31/39 VS=39/39
#
# [40/100] what is the name and nation of the singer who have a song having 'Hey' in its name?
#   -> select singer.name, singer.country from singer where singer.song_name like '%hey%'
#   gold: select name, country from singer where song_name like '%hey%'
#   EM=4/40 EA=32/40 VS=40/40
#
# [41/100] What is the name and country of origin of every singer who has a song with the word 'Hey' in its title?
#   -> select name, country from singer where song_name like '%hey%'
#   gold: select name, country from singer where song_name like '%hey%'
#   EM=5/41 EA=33/41 VS=41/41
#
# [42/100] Find the name and location of the stadiums which some concerts happened in the years of both 2014 and 2015.
#   -> select stadium.name, stadium.location from stadium join concert on stadium.stadium_id = concert.stadium_id where concert.year = 2014 intersect select stadium.name, stadium.location from stadium join concert on stadium.stadium_id = concert.stadium_id where concert.year = 2015
#   gold: select t2.name, t2.location from concert as t1 join stadium as t2 on t1.stadium_id = t2.stadium_id where t1.year = 2014 intersect select t2.name, t2.location from concert as t1 join stadium as t2 on t1.stadium_id = t2.stadium_id where t1.year = 2015
#   EM=5/42 EA=34/42 VS=42/42
#
# [43/100] What are the names and locations of the stadiums that had concerts that occurred in both 2014 and 2015?
#   -> select s.name, s.location from stadium s where s.stadium_id in ( select stadium_id from concert where year = 2014 intersect select stadium_id from concert where year = 2015 ) group by s.stadium_id, s.name, s.location
#   gold: select t2.name, t2.location from concert as t1 join stadium as t2 on t1.stadium_id = t2.stadium_id where t1.year = 2014 intersect select t2.name, t2.location from concert as t1 join stadium as t2 on t1.stadium_id = t2.stadium_id where t1.year = 2015
#   EM=5/43 EA=35/43 VS=43/43
#
# [44/100] Find the number of concerts happened in the stadium with the highest capacity .
#   -> select count(concert.concert_id) from stadium join concert on stadium.stadium_id = concert.stadium_id where stadium.capacity = (select max(capacity) from stadium)
#   gold: select count(*) from concert where stadium_id = (select stadium_id from stadium order by capacity desc limit 1)
#   EM=5/44 EA=36/44 VS=44/44
#
# [45/100] What are the number of concerts that occurred in the stadium with the largest capacity ?
#   -> select count(concert.concert_id) from concert join stadium on concert.stadium_id = stadium.stadium_id where stadium.capacity = (select max(capacity) from stadium)
#   gold: select count(*) from concert where stadium_id = (select stadium_id from stadium order by capacity desc limit 1)
#   EM=5/45 EA=37/45 VS=45/45
#
# [46/100] Find the number of pets whose weight is heavier than 10.
#   -> select count(pets.petid) from pets where pets.weight > 10
#   gold: select count(*) from pets where weight > 10
#   EM=5/46 EA=38/46 VS=46/46
#
# [47/100] How many pets have a greater weight than 10?
#   -> select count(distinct pets.petid) from pets join has_pet on pets.petid = has_pet.petid where pets.weight > 10
#   gold: select count(*) from pets where weight > 10
#   EM=5/47 EA=39/47 VS=47/47
#
# [48/100] Find the weight of the youngest dog.
#   -> select pets.weight from pets join has_pet on pets.petid = has_pet.petid where pets.pettype = 'dog' order by pets.pet_age asc limit 1
#   gold: select weight from pets order by pet_age limit 1
#   EM=5/48 EA=40/48 VS=48/48
#
# [49/100] How much does the youngest dog weigh?
#   -> select pets.weight from pets join has_pet on pets.petid = has_pet.petid where pets.pettype = 'dog' order by pets.pet_age asc limit 1
#   gold: select weight from pets order by pet_age limit 1
#   EM=5/49 EA=41/49 VS=49/49
#
# [50/100] Find the maximum weight for each type of pet. List the maximum weight and pet type.
#   -> select pettype, max(weight) as max_weight from pets group by pettype
#   gold: select max(weight), pettype from pets group by pettype
#   EM=5/50 EA=42/50 VS=50/50
#
# [51/100] List the maximum weight and type for each type of pet.
#   -> select pets.pettype, max(pets.weight) as max_weight from pets group by pets.pettype
#   gold: select max(weight), pettype from pets group by pettype
#   EM=5/51 EA=43/51 VS=51/51
#
# [52/100] Find number of pets owned by students who are older than 20.
#   -> select count(pets.petid) from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where student.age > 20
#   gold: select count(*) from student as t1 join has_pet as t2 on t1.stuid = t2.stuid where t1.age > 20
#   EM=5/52 EA=44/52 VS=52/52
#
# [53/100] How many pets are owned by students that have an age greater than 20?
#   -> select count(distinct has_pet.petid) from student join has_pet on student.stuid = has_pet.stuid where student.age > 20
#   gold: select count(*) from student as t1 join has_pet as t2 on t1.stuid = t2.stuid where t1.age > 20
#   EM=5/53 EA=45/53 VS=53/53
#
# [54/100] Find the number of dog pets that are raised by female students (with sex F).
#   -> select count(pets.petid) from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where pets.pettype = 'dog' and student.sex = 'f'
#   gold: select count(*) from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t2.petid = t3.petid where t1.sex = 'f' and t3.pettype = 'dog'
#   EM=5/54 EA=46/54 VS=54/54
#
# [55/100] How many dog pets are raised by female students?
#   -> select count(pets.petid) from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where pets.pettype = 'dog' and student.sex = 'female'
#   gold: select count(*) from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t2.petid = t3.petid where t1.sex = 'f' and t3.pettype = 'dog'
#   EM=5/55 EA=47/55 VS=55/55
#
# [56/100] Find the number of distinct type of pets.
#   -> select count(distinct pettype) from pets
#   gold: select count(distinct pettype) from pets
#   EM=6/56 EA=48/56 VS=56/56
#
# [57/100] How many different types of pet are there?
#   -> select count(distinct pets.pettype) from pets
#   gold: select count(distinct pettype) from pets
#   EM=6/57 EA=49/57 VS=57/57
#
# [58/100] Find the first name of students who have cat or dog pet.
#   -> select distinct student.fname from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where pets.pettype in ('cat', 'dog')
#   gold: select distinct t1.fname from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'cat' or t3.pettype = 'dog'
#   EM=6/58 EA=50/58 VS=58/58
#
# [59/100] What are the first names of every student who has a cat or dog as a pet?
#   -> select distinct student.fname from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where pets.pettype in ('cat', 'dog')
#   gold: select distinct t1.fname from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'cat' or t3.pettype = 'dog'
#   EM=6/59 EA=51/59 VS=59/59
#
# [60/100] Find the first name of students who have both cat and dog pets .
#   -> select student.fname from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where pets.pettype = 'cat' intersect select student.fname from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where pets.pettype = 'dog'
#   gold: select t1.fname from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'cat' intersect select t1.fname from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'dog'
#   EM=6/60 EA=52/60 VS=60/60
#
# [61/100] What are the students' first names who have both cats and dogs as pets?
#   -> select student.fname from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where pets.pettype in ('cat', 'dog') group by student.stuid, student.fname having count(distinct pets.pettype) = 2
#   gold: select t1.fname from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'cat' intersect select t1.fname from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'dog'
#   EM=6/61 EA=53/61 VS=61/61
#
# [62/100] Find the major and age of students who do not have a cat pet.
#   -> select student.major, student.age from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where pets.pettype != 'cat' except select student.major, student.age from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where pets.pettype = 'cat'
#   gold: select major, age from student where stuid not in (select t1.stuid from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'cat')
#   EM=6/62 EA=53/62 VS=62/62
#
# [63/100] What major is every student who does not own a cat as a pet, and also how old are they?
#   -> select student.major, student.age from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where pets.pettype != 'cat' except select student.major, student.age from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where pets.pettype = 'cat'
#   gold: select major, age from student where stuid not in (select t1.stuid from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'cat')
#   EM=6/63 EA=53/63 VS=63/63
#
# [64/100] Find the id of students who do not have a cat pet.
#   -> select stuid from student except select student.stuid from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where pets.pettype = 'cat'
#   gold: select stuid from student except select t1.stuid from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'cat'
#   EM=6/64 EA=54/64 VS=64/64
#
# [65/100] What are the ids of the students who do not own cats as pets?
#   -> select stuid from student except select student.stuid from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where pets.pettype = 'cat'
#   gold: select stuid from student except select t1.stuid from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'cat'
#   EM=6/65 EA=55/65 VS=65/65
#
# [66/100] Find the first name and age of students who have a dog but do not have a cat as a pet.
#   -> select student.fname, student.age from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where pets.pettype = 'dog' except select student.fname, student.age from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where pets.pettype = 'cat'
#   gold: select t1.fname, t1.age from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'dog' and t1.stuid not in (select t1.stuid from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'cat')
#   EM=6/66 EA=55/66 VS=66/66
#
# [67/100] What is the first name of every student who has a dog but does not have a cat?
#   -> select student.fname from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where pets.pettype = 'dog' except select student.fname from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where pets.pettype = 'cat'
#   gold: select t1.fname, t1.age from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'dog' and t1.stuid not in (select t1.stuid from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'cat')
#   EM=6/67 EA=55/67 VS=67/67
#
# [68/100] Find the type and weight of the youngest pet.
#   -> select pets.pettype, pets.weight from pets join has_pet on pets.petid = has_pet.petid order by pets.pet_age asc limit 1
#   gold: select pettype, weight from pets order by pet_age limit 1
#   EM=6/68 EA=56/68 VS=68/68
#
# [69/100] What type of pet is the youngest animal, and how much does it weigh?
#   -> select pettype, weight from pets order by pet_age asc limit 1
#   gold: select pettype, weight from pets order by pet_age limit 1
#   EM=6/69 EA=57/69 VS=69/69
#
# [70/100] Find the id and weight of all pets whose age is older than 1.
#   -> select pets.petid, pets.weight from pets where pets.pet_age > 1
#   gold: select petid, weight from pets where pet_age > 1
#   EM=6/70 EA=58/70 VS=70/70
#
# [71/100] What is the id and weight of every pet who is older than 1?
#   -> select pets.petid, pets.weight from pets where pets.pet_age > 1
#   gold: select petid, weight from pets where pet_age > 1
#   EM=6/71 EA=59/71 VS=71/71
#
# [72/100] Find the average and maximum age for each type of pet.
#   -> select pets.pettype, avg(pets.pet_age) as average_age, max(pets.pet_age) as maximum_age from pets group by pets.pettype
#   gold: select avg(pet_age), max(pet_age), pettype from pets group by pettype
#   EM=6/72 EA=60/72 VS=72/72
#
# [73/100] What is the average and maximum age for each pet type?
#   -> select pets.pettype, avg(pets.pet_age) as average_age, max(pets.pet_age) as max_age from pets group by pets.pettype
#   gold: select avg(pet_age), max(pet_age), pettype from pets group by pettype
#   EM=6/73 EA=61/73 VS=73/73
#
# [74/100] Find the average weight for each pet type.
#   -> select pettype, avg(weight) as average_weight from pets group by pettype
#   gold: select avg(weight), pettype from pets group by pettype
#   EM=6/74 EA=62/74 VS=74/74
#
# [75/100] What is the average weight for each type of pet?
#   -> select pets.pettype, avg(pets.weight) from pets group by pets.pettype
#   gold: select avg(weight), pettype from pets group by pettype
#   EM=6/75 EA=63/75 VS=75/75
#
# [76/100] Find the first name and age of students who have a pet.
#   -> select student.fname, student.age from student join has_pet on student.stuid = has_pet.stuid
#   gold: select distinct t1.fname, t1.age from student as t1 join has_pet as t2 on t1.stuid = t2.stuid
#   EM=6/76 EA=63/76 VS=76/76
#
# [77/100] What are the different first names and ages of the students who do have pets?
#   -> select distinct student.fname, student.age from student join has_pet on student.stuid = has_pet.stuid where has_pet.petid is not null
#   gold: select distinct t1.fname, t1.age from student as t1 join has_pet as t2 on t1.stuid = t2.stuid
#   EM=6/77 EA=64/77 VS=77/77
#
# [78/100] Find the id of the pet owned by student whose last name is ‘Smith’.
#   -> select pets.petid from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where student.lname = 'smith'
#   gold: select t2.petid from student as t1 join has_pet as t2 on t1.stuid = t2.stuid where t1.lname = 'smith'
#   EM=6/78 EA=65/78 VS=78/78
#
# [79/100] What is the id of the pet owned by the student whose last name is 'Smith'?
#   -> select pets.petid from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where student.lname = 'smith'
#   gold: select t2.petid from student as t1 join has_pet as t2 on t1.stuid = t2.stuid where t1.lname = 'smith'
#   EM=6/79 EA=66/79 VS=79/79
#
# [80/100] Find the number of pets for each student who has any pet and student id.
#   -> select student.stuid, count(has_pet.petid) as num_pets from student join has_pet on student.stuid = has_pet.stuid group by student.stuid having count(has_pet.petid) > 0
#   gold: select count(*), t1.stuid from student as t1 join has_pet as t2 on t1.stuid = t2.stuid group by t1.stuid
#   EM=6/80 EA=67/80 VS=80/80
#
# [81/100] For students who have pets , how many pets does each student have ? list their ids instead of names .
#   -> select student.stuid, count(pets.petid) as pet_count from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid group by student.stuid order by student.stuid
#   gold: select count(*), t1.stuid from student as t1 join has_pet as t2 on t1.stuid = t2.stuid group by t1.stuid
#   EM=6/81 EA=68/81 VS=81/81
#
# [82/100] Find the first name and gender of student who have more than one pet.
#   -> select student.fname, student.sex from student join has_pet on student.stuid = has_pet.stuid group by student.stuid, student.fname, student.sex having count(has_pet.petid) > 1
#   gold: select t1.fname, t1.sex from student as t1 join has_pet as t2 on t1.stuid = t2.stuid group by t1.stuid having count(*) > 1
#   EM=6/82 EA=69/82 VS=82/82
#
# [83/100] What is the first name and gender of the all the students who have more than one pet?
#   -> select student.fname, student.sex from student join has_pet on student.stuid = has_pet.stuid group by student.stuid, student.fname, student.sex having count(has_pet.petid) > 1
#   gold: select t1.fname, t1.sex from student as t1 join has_pet as t2 on t1.stuid = t2.stuid group by t1.stuid having count(*) > 1
#   EM=6/83 EA=70/83 VS=83/83
#
# [84/100] Find the last name of the student who has a cat that is age 3.
#   -> select student.lname from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where pets.pet_age = 3
#   gold: select t1.lname from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pet_age = 3 and t3.pettype = 'cat'
#   EM=6/84 EA=71/84 VS=84/84
#
# [85/100] What is the last name of the student who has a cat that is 3 years old?
#   -> select student.lname from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where pets.pet_age = 3 limit 1
#   gold: select t1.lname from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pet_age = 3 and t3.pettype = 'cat'
#   EM=6/85 EA=72/85 VS=85/85
#
# [86/100] Find the average age of students who do not have any pet .
#   -> select avg(student.age) from student where student.stuid not in (select stuid from has_pet)
#   gold: select avg(age) from student where stuid not in (select stuid from has_pet)
#   EM=6/86 EA=73/86 VS=86/86
#
# [87/100] What is the average age for all students who do not own any pets ?
#   -> select avg(student.age) from student where student.stuid not in (select distinct stuid from has_pet)
#   gold: select avg(age) from student where stuid not in (select stuid from has_pet)
#   EM=6/87 EA=74/87 VS=87/87
#
# [88/100] How many continents are there?
#   -> select count(distinct continents.continent) from continents
#   gold: select count(*) from continents
#   EM=6/88 EA=75/88 VS=88/88
#
# [89/100] What is the number of continents?
#   -> select count(distinct continents.continent) from continents
#   gold: select count(*) from continents
#   EM=6/89 EA=76/89 VS=89/89
#
# [90/100] How many countries does each continent have? List the continent id, continent name and the number of countries.
#   -> select continents.contid, continents.continent, count(countries.countryid) from continents join countries on continents.contid = countries.continent group by continents.contid, continents.continent
#   gold: select t1.contid, t1.continent, count(*) from continents as t1 join countries as t2 on t1.contid = t2.continent group by t1.contid
#   EM=6/90 EA=77/90 VS=90/90
#
# [91/100] For each continent, list its id, name, and how many countries it has?
#   -> select continents.contid, continents.continent, count(countries.countryid) from continents join countries on continents.contid = countries.continent group by continents.contid, continents.continent
#   gold: select t1.contid, t1.continent, count(*) from continents as t1 join countries as t2 on t1.contid = t2.continent group by t1.contid
#   EM=6/91 EA=78/91 VS=91/91
#
# [92/100] How many countries are listed?
#   -> select count(distinct countryid) from countries
#   gold: select count(*) from countries
#   EM=6/92 EA=79/92 VS=92/92
#
# [93/100] How many countries exist?
#   -> select count(distinct countryid) from countries
#   gold: select count(*) from countries
#   EM=6/93 EA=80/93 VS=93/93
#
# [94/100] How many models does each car maker produce? List maker full name, id and the number.
#   -> select car_makers.fullname, car_makers.id, count(model_list.modelid) as model_count from car_makers join model_list on car_makers.id = model_list.maker group by car_makers.fullname, car_makers.id
#   gold: select t1.fullname, t1.id, count(*) from car_makers as t1 join model_list as t2 on t1.id = t2.maker group by t1.id
#   EM=6/94 EA=81/94 VS=94/94
#
# [95/100] What is the full name of each car maker, along with its id and how many models it produces?
#   -> select car_makers.id, car_makers.fullname, count(model_list.modelid) as model_count from car_makers join model_list on car_makers.id = model_list.maker group by car_makers.id, car_makers.fullname
#   gold: select t1.fullname, t1.id, count(*) from car_makers as t1 join model_list as t2 on t1.id = t2.maker group by t1.id
#   EM=6/95 EA=82/95 VS=95/95
#
# [96/100] Which model of the car has the minimum horsepower?
#   -> select car_names.model from cars_data join car_names on cars_data.id = car_names.makeid join model_list on car_names.model = model_list.model where cars_data.horsepower = (select min(horsepower) from cars_data)
#   gold: select t1.model from car_names as t1 join cars_data as t2 on t1.makeid = t2.id order by t2.horsepower asc limit 1
#   EM=6/96 EA=82/96 VS=96/96
#
# [97/100] What is the model of the car with the smallest amount of horsepower?
#   -> select model_list.model from cars_data join car_names on cars_data.id = car_names.makeid join model_list on car_names.model = model_list.model where cars_data.horsepower is not null order by cars_data.horsepower asc limit 1
#   gold: select t1.model from car_names as t1 join cars_data as t2 on t1.makeid = t2.id order by t2.horsepower asc limit 1
#   EM=6/97 EA=83/97 VS=97/97
#
# [98/100] Find the model of the car whose weight is below the average weight.
#   -> select car_names.model from car_names join cars_data on car_names.makeid = cars_data.id where cars_data.weight < (select avg(weight) from cars_data)
#   gold: select t1.model from car_names as t1 join cars_data as t2 on t1.makeid = t2.id where t2.weight < (select avg(weight) from cars_data)
#   EM=6/98 EA=84/98 VS=98/98
#
# [99/100] What is the model for the car with a weight smaller than the average?
#   -> select model_list.model from model_list join car_names on model_list.model = car_names.model join cars_data on car_names.makeid = cars_data.id where cars_data.weight < (select avg(weight) from cars_data)
#   gold: select t1.model from car_names as t1 join cars_data as t2 on t1.makeid = t2.id where t2.weight < (select avg(weight) from cars_data)
#   EM=6/99 EA=84/99 VS=99/99
#
# [100/100] Find the name of the makers that produced some cars in the year of 1970?
#   -> select distinct car_makers.maker from car_makers join model_list on car_makers.id = model_list.maker join car_names on model_list.model = car_names.model join cars_data on car_names.makeid = cars_data.id where cars_data.year = 1970
#   gold: select distinct t1.maker from car_makers as t1 join model_list as t2 on t1.id = t2.maker join car_names as t3 on t2.model = t3.model join cars_data as t4 on t3.makeid = t4.id where t4.year = '1970'
#   EM=6/100 EA=85/100 VS=100/100
#
# === no_correction === {"total": 100, "em": 6, "vs": 100, "ea": 85, "em%": 0.06, "vs%": 1.0, "ea%": 0.85}

# %%
r3 = run(gen_nosub, "no_subproblem")
# Out:
# [1/100] How many singers do we have?
#   -> select count(distinct singer_id) from singer
#   gold: select count(*) from singer
#   EM=0/1 EA=1/1 VS=1/1
#
# [2/100] What is the total number of singers?
#   -> select count(singer.singer_id) from singer
#   gold: select count(*) from singer
#   EM=0/2 EA=2/2 VS=2/2
#
# [3/100] Show name, country, age for all singers ordered by age from the oldest to the youngest.
#   -> select name, country, age from singer order by age desc
#   gold: select name, country, age from singer order by age desc
#   EM=1/3 EA=3/3 VS=3/3
#
# [4/100] What are the names, countries, and ages for every singer in descending order of age?
#   -> select name, country, age from singer order by age desc
#   gold: select name, country, age from singer order by age desc
#   EM=2/4 EA=4/4 VS=4/4
#
# [5/100] What is the average, minimum, and maximum age of all singers from France?
#   -> select avg(singer.age) as average_age, min(singer.age) as minimum_age, max(singer.age) as maximum_age from singer where singer.country = 'france'
#   gold: select avg(age), min(age), max(age) from singer where country = 'france'
#   EM=2/5 EA=5/5 VS=5/5
#
# [6/100] What is the average, minimum, and maximum age for all French singers?
#   -> select avg(singer.age), min(singer.age), max(singer.age) from singer where singer.country = 'french'
#   gold: select avg(age), min(age), max(age) from singer where country = 'france'
#   EM=2/6 EA=6/6 VS=6/6
#
# [7/100] Show the name and the release year of the song by the youngest singer.
#   -> select name, song_release_year from singer where age = (select min(age) from singer)
#   fix1: select song_name, song_release_year from singer where age = (select min(age) from singer)
#   gold: select song_name, song_release_year from singer order by age limit 1
#   EM=2/7 EA=7/7 VS=7/7
#
# [8/100] What are the names and release years for all the songs of the youngest singer?
#   -> select name, song_name, song_release_year from singer where age = (select min(age) from singer) order by song_release_year
#   fix1: select name, song_release_year from singer where age = (select min(age) from singer) order by song_release_year
#   fix2: select song_name, song_release_year from singer where age = (select min(age) from singer) order by song_release_year
#   gold: select song_name, song_release_year from singer order by age limit 1
#   EM=2/8 EA=8/8 VS=8/8
#
# [9/100] What are all distinct countries where singers above age 20 are from?
#   -> select distinct singer.country from singer where singer.age > 20
#   gold: select distinct country from singer where age > 20
#   EM=2/9 EA=9/9 VS=9/9
#
# [10/100] What are  the different countries with singers above age 20?
#   -> select distinct singer.country from singer join singer_in_concert on singer.singer_id = singer_in_concert.singer_id where singer.age > 20
#   fix1: select distinct country from singer where age > 20
#   gold: select distinct country from singer where age > 20
#   EM=3/10 EA=10/10 VS=10/10
#
# [11/100] Show all countries and the number of singers in each country.
#   -> select singer.country, count(singer.singer_id) from singer left join singer_in_concert on singer.singer_id = singer_in_concert.singer_id group by singer.country
#   fix1: select country, count(singer_id) from singer group by country
#   gold: select country, count(*) from singer group by country
#   EM=3/11 EA=11/11 VS=11/11
#
# [12/100] How many singers are from each country?
#   -> select singer.country, count(singer.singer_id) from singer group by singer.country
#   gold: select country, count(*) from singer group by country
#   EM=3/12 EA=12/12 VS=12/12
#
# [13/100] List all song names by singers above the average age.
#   -> select singer.name, concert.concert_name from singer join singer_in_concert on singer.singer_id = singer_in_concert.singer_id join concert on singer_in_concert.concert_id = concert.concert_id where singer.age > (select avg(age) from singer)
#   fix1: select 'query cannot be answered: no song table exists in the provided schema' as error
#   fix2: select 'query cannot be answered: no table linking singers to songs exists in the provided schema' as error
#   fix3: select name from singer where age > (select avg(age) from singer)
#   gold: select song_name from singer where age > (select avg(age) from singer)
#   EM=3/13 EA=12/13 VS=13/13
#
# [14/100] What are all the song names by singers who are older than average?
#   -> select s.name, s.song_name from singer s join singer_in_concert sic on s.singer_id = sic.singer_id where s.age > (select avg(age) from singer)
#   fix1: select s.name, s.song_name from singer s where s.age > (select avg(age) from singer)
#   fix2: select song_name from singer where age > (select avg(age) from singer)
#   gold: select song_name from singer where age > (select avg(age) from singer)
#   EM=4/14 EA=13/14 VS=14/14
#
# [15/100] Show location and name for all stadiums with a capacity between 5000 and 10000.
#   -> select stadium.location, stadium.name from stadium where stadium.capacity between 5000 and 10000
#   gold: select location, name from stadium where capacity between 5000 and 10000
#   EM=4/15 EA=14/15 VS=15/15
#
# [16/100] What are the locations and names of all stations with capacity between 5000 and 10000?
#   -> select stadium.location, stadium.name, stadium.capacity from stadium where stadium.capacity between 5000 and 10000
#   gold: select location, name from stadium where capacity between 5000 and 10000
#   EM=4/16 EA=15/16 VS=16/16
#
# [17/100] What is the maximum capacity and the average of all stadiums ?
#   -> select max(capacity) as max_capacity, avg(average) as avg_average from stadium
#   fix1: select max(capacity) as max_capacity, avg(capacity) as avg_capacity from stadium
#   fix2: select max(capacity) as max_capacity, avg(average) as avg_average from stadium
#   fix3: select max(capacity) as max_capacity, avg(capacity) as avg_average from stadium
#   gold: select max(capacity), average from stadium
#   EM=4/17 EA=15/17 VS=17/17
#
# [18/100] What is the average and maximum capacities for all stadiums ?
#   -> select avg(capacity) as average_capacity, max(capacity) as maximum_capacity from stadium
#   gold: select avg(capacity), max(capacity) from stadium
#   EM=4/18 EA=16/18 VS=18/18
#
# [19/100] What is the name and capacity for the stadium with highest average attendance?
#   -> select name, capacity from stadium order by average desc limit 1
#   gold: select name, capacity from stadium order by average desc limit 1
#   EM=5/19 EA=17/19 VS=19/19
#
# [20/100] What is the name and capacity for the stadium with the highest average attendance?
#   -> select stadium.name, stadium.capacity, avg(stadium.average) as avg_attendance from stadium join concert on stadium.stadium_id = concert.stadium_id join singer_in_concert on concert.concert_id = singer_in_concert.concert_id join singer on singer_in_concert.singer_id = singer.singer_id group by stadium.stadium_id, stadium.name, stadium.capacity order by avg_attendance desc limit 1
#   fix1: select name, capacity from stadium order by average desc limit 1
#   gold: select name, capacity from stadium order by average desc limit 1
#   EM=6/20 EA=18/20 VS=20/20
#
# [21/100] How many concerts are there in year 2014 or 2015?
#   -> select count(concert.concert_id) from concert where concert.year in (2014, 2015)
#   gold: select count(*) from concert where year = 2014 or year = 2015
#   EM=6/21 EA=19/21 VS=21/21
#
# [22/100] How many concerts occurred in 2014 or 2015?
#   -> select count(concert.concert_id) from concert where concert.year in (2014, 2015)
#   gold: select count(*) from concert where year = 2014 or year = 2015
#   EM=6/22 EA=20/22 VS=22/22
#
# [23/100] Show the stadium name and the number of concerts in each stadium.
#   -> select stadium.name, count(concert.concert_id) from stadium left join concert on stadium.stadium_id = concert.stadium_id group by stadium.stadium_id, stadium.name
#   fix1: select stadium.name, count(concert.concert_id) from stadium left join concert on stadium.stadium_id = concert.stadium_id group by stadium.stadium_id
#   fix2: select stadium.name, count(concert.concert_id) from stadium left join concert on stadium.stadium_id = concert.stadium_id group by stadium.stadium_id, stadium.name
#   fix3: select stadium.name, count(concert.concert_id) from stadium left join concert on stadium.stadium_id = concert.stadium_id group by stadium.stadium_id
#   gold: select t2.name, count(*) from concert as t1 join stadium as t2 on t1.stadium_id = t2.stadium_id group by t1.stadium_id
#   EM=6/23 EA=20/23 VS=23/23
#
# [24/100] For each stadium, how many concerts play there?
#   -> select stadium.name, count(concert.concert_id) from stadium left join concert on stadium.stadium_id = concert.stadium_id group by stadium.stadium_id, stadium.name
#   fix1: select stadium.name, count(concert.concert_id) from stadium left join concert on stadium.stadium_id = concert.stadium_id group by stadium.stadium_id, stadium.name
#   fix2: select stadium.name, count(concert.concert_id) from stadium left join concert on stadium.stadium_id = concert.stadium_id group by stadium.stadium_id, stadium.name
#   fix3: select stadium.name, count(distinct concert.concert_id) from stadium left join concert on stadium.stadium_id = concert.stadium_id group by stadium.stadium_id, stadium.name
#   gold: select t2.name, count(*) from concert as t1 join stadium as t2 on t1.stadium_id = t2.stadium_id group by t1.stadium_id
#   EM=6/24 EA=20/24 VS=24/24
#
# [25/100] Show the stadium name and capacity with most number of concerts in year 2014 or after.
#   -> select stadium.name, stadium.capacity from concert join stadium on concert.stadium_id = stadium.stadium_id where concert.year >= 2014 group by concert.stadium_id, stadium.name, stadium.capacity order by count(concert.concert_id) desc limit 1
#   gold: select t2.name, t2.capacity from concert as t1 join stadium as t2 on t1.stadium_id = t2.stadium_id where t1.year >= 2014 group by t2.stadium_id order by count(*) desc limit 1
#   EM=6/25 EA=21/25 VS=25/25
#
# [26/100] What is the name and capacity of the stadium with the most concerts after 2013 ?
#   -> select stadium.name, stadium.capacity from concert join stadium on concert.stadium_id = stadium.stadium_id where concert.year > 2013 group by concert.stadium_id, stadium.name, stadium.capacity order by count(concert.concert_id) desc limit 1
#   gold: select t2.name, t2.capacity from concert as t1 join stadium as t2 on t1.stadium_id = t2.stadium_id where t1.year > 2013 group by t2.stadium_id order by count(*) desc limit 1
#   EM=6/26 EA=22/26 VS=26/26
#
# [27/100] Which year has most number of concerts?
#   -> select year, count(concert_id) as concert_count from concert group by year order by concert_count desc limit 1
#   fix1: select year, count(concert_id) as concert_count from concert group by year having count(concert_id) = ( select max(cnt) from ( select count(concert_id) as cnt from concert group by year ) as counts )
#   fix2: select year, count(concert_id) as concert_count from concert group by year having count(concert_id) = ( select max(cnt) from ( select count(concert_id) as cnt from concert group by year ) as counts )
#   fix3: select year, count(concert_id) as concert_count from concert group by year having count(concert_id) = ( select max(cnt) from ( select count(concert_id) as cnt from concert group by year ) as counts ) order by year
#   gold: select year from concert group by year order by count(*) desc limit 1
#   EM=6/27 EA=22/27 VS=27/27
#
# [28/100] What is the year that had the most concerts?
#   -> select year from concert group by year order by count(concert_id) desc limit 1
#   gold: select year from concert group by year order by count(*) desc limit 1
#   EM=6/28 EA=23/28 VS=28/28
#
# [29/100] Show the stadium names without any concert.
#   -> select stadium.name from stadium left join concert on stadium.stadium_id = concert.stadium_id where concert.concert_id is null
#   gold: select name from stadium where stadium_id not in (select stadium_id from concert)
#   EM=6/29 EA=24/29 VS=29/29
#
# [30/100] What are the names of the stadiums without any concerts?
#   -> select stadium.name from stadium left join concert on stadium.stadium_id = concert.stadium_id where concert.concert_id is null
#   gold: select name from stadium where stadium_id not in (select stadium_id from concert)
#   EM=6/30 EA=25/30 VS=30/30
#
# [31/100] Show countries where a singer above age 40 and a singer below 30 are from.
#   -> select singer.country from singer join singer_in_concert on singer.singer_id = singer_in_concert.singer_id join concert on singer_in_concert.concert_id = concert.concert_id where singer.age > 40 intersect select singer.country from singer where singer.age < 30
#   gold: select country from singer where age > 40 intersect select country from singer where age < 30
#   EM=6/31 EA=26/31 VS=31/31
#
# [32/100] Show names for all stadiums except for stadiums having a concert in year 2014.
#   -> select stadium.name from stadium left join concert on stadium.stadium_id = concert.stadium_id and concert.year = 2014 where concert.concert_id is null
#   gold: select name from stadium except select t2.name from concert as t1 join stadium as t2 on t1.stadium_id = t2.stadium_id where t1.year = 2014
#   EM=6/32 EA=27/32 VS=32/32
#
# [33/100] What are the names of all stadiums that did not have a concert in 2014?
#   -> select stadium.name from stadium left join concert on stadium.stadium_id = concert.stadium_id and concert.year = 2014 where concert.concert_id is null
#   gold: select name from stadium except select t2.name from concert as t1 join stadium as t2 on t1.stadium_id = t2.stadium_id where t1.year = 2014
#   EM=6/33 EA=28/33 VS=33/33
#
# [34/100] Show the name and theme for all concerts and the number of singers in each concert.
#   -> select concert.concert_name, concert.theme, count(singer.singer_id) from concert left join singer_in_concert on concert.concert_id = singer_in_concert.concert_id left join singer on singer_in_concert.singer_id = singer.singer_id group by concert.concert_id, concert.concert_name, concert.theme
#   gold: select t2.concert_name, t2.theme, count(*) from singer_in_concert as t1 join concert as t2 on t1.concert_id = t2.concert_id group by t2.concert_id
#   EM=6/34 EA=29/34 VS=34/34
#
# [35/100] What are the names , themes , and number of singers for every concert ?
#   -> select concert.concert_name, concert.theme, count(singer_in_concert.singer_id) from concert join singer_in_concert on concert.concert_id = singer_in_concert.concert_id group by concert.concert_id, concert.concert_name, concert.theme
#   gold: select t2.concert_name, t2.theme, count(*) from singer_in_concert as t1 join concert as t2 on t1.concert_id = t2.concert_id group by t2.concert_id
#   EM=6/35 EA=30/35 VS=35/35
#
# [36/100] List singer names and number of concerts for each singer.
#   -> select singer.name, count(singer_in_concert.concert_id) as number_of_concerts from singer join singer_in_concert on singer.singer_id = singer_in_concert.singer_id join concert on singer_in_concert.concert_id = concert.concert_id group by singer.singer_id, singer.name
#   gold: select t2.name, count(*) from singer_in_concert as t1 join singer as t2 on t1.singer_id = t2.singer_id group by t2.singer_id
#   EM=6/36 EA=31/36 VS=36/36
#
# [37/100] What are the names of the singers and number of concerts for each person?
#   -> select singer.name, count(concert.concert_id) from singer join singer_in_concert on singer.singer_id = singer_in_concert.singer_id join concert on singer_in_concert.concert_id = concert.concert_id group by singer.singer_id, singer.name
#   gold: select t2.name, count(*) from singer_in_concert as t1 join singer as t2 on t1.singer_id = t2.singer_id group by t2.singer_id
#   EM=6/37 EA=32/37 VS=37/37
#
# [38/100] List all singer names in concerts in year 2014.
#   -> select singer.name from singer_in_concert join singer on singer_in_concert.singer_id = singer.singer_id join concert on singer_in_concert.concert_id = concert.concert_id where concert.year = 2014
#   gold: select t2.name from singer_in_concert as t1 join singer as t2 on t1.singer_id = t2.singer_id join concert as t3 on t1.concert_id = t3.concert_id where t3.year = 2014
#   EM=6/38 EA=33/38 VS=38/38
#
# [39/100] What are the names of the singers who performed in a concert in 2014?
#   -> select singer.name from concert join singer_in_concert on concert.concert_id = singer_in_concert.concert_id join singer on singer_in_concert.singer_id = singer.singer_id where concert.year = 2014
#   gold: select t2.name from singer_in_concert as t1 join singer as t2 on t1.singer_id = t2.singer_id join concert as t3 on t1.concert_id = t3.concert_id where t3.year = 2014
#   EM=6/39 EA=34/39 VS=39/39
#
# [40/100] what is the name and nation of the singer who have a song having 'Hey' in its name?
#   -> select singer.name, singer.country from singer join singer_in_concert on singer.singer_id = singer_in_concert.singer_id join concert on singer_in_concert.concert_id = concert.concert_id where singer.song_name like '%hey%'
#   fix1: select name, country from singer where song_name like '%hey%'
#   gold: select name, country from singer where song_name like '%hey%'
#   EM=7/40 EA=35/40 VS=40/40
#
# [41/100] What is the name and country of origin of every singer who has a song with the word 'Hey' in its title?
#   -> select singer.name, singer.country from singer join singer_in_concert on singer.singer_id = singer_in_concert.singer_id where singer.song_name like '%hey%'
#   fix1: select name, country from singer where song_name like '%hey%'
#   gold: select name, country from singer where song_name like '%hey%'
#   EM=8/41 EA=36/41 VS=41/41
#
# [42/100] Find the name and location of the stadiums which some concerts happened in the years of both 2014 and 2015.
#   -> select distinct s.name, s.location from stadium s join concert c2014 on s.stadium_id = c2014.stadium_id and c2014.year = 2014 join concert c2015 on s.stadium_id = c2015.stadium_id and c2015.year = 2015
#   gold: select t2.name, t2.location from concert as t1 join stadium as t2 on t1.stadium_id = t2.stadium_id where t1.year = 2014 intersect select t2.name, t2.location from concert as t1 join stadium as t2 on t1.stadium_id = t2.stadium_id where t1.year = 2015
#   EM=8/42 EA=37/42 VS=42/42
#
# [43/100] What are the names and locations of the stadiums that had concerts that occurred in both 2014 and 2015?
#   -> select stadium.name, stadium.location from stadium where stadium.stadium_id in ( select distinct stadium.stadium_id from concert join stadium on concert.stadium_id = stadium.stadium_id where concert.year = 2014 intersect select distinct stadium.stadium_id from concert join stadium on concert.stadium_id = stadium.stadium_id where concert.year = 2015 )
#   gold: select t2.name, t2.location from concert as t1 join stadium as t2 on t1.stadium_id = t2.stadium_id where t1.year = 2014 intersect select t2.name, t2.location from concert as t1 join stadium as t2 on t1.stadium_id = t2.stadium_id where t1.year = 2015
#   EM=8/43 EA=38/43 VS=43/43
#
# [44/100] Find the number of concerts happened in the stadium with the highest capacity .
#   -> select count(c.concert_id) from concert c join stadium s on c.stadium_id = s.stadium_id where s.capacity = (select max(capacity) from stadium)
#   gold: select count(*) from concert where stadium_id = (select stadium_id from stadium order by capacity desc limit 1)
#   EM=8/44 EA=39/44 VS=44/44
#
# [45/100] What are the number of concerts that occurred in the stadium with the largest capacity ?
#   -> select count(concert.concert_id) from stadium join concert on stadium.stadium_id = concert.stadium_id where stadium.capacity = (select max(capacity) from stadium)
#   gold: select count(*) from concert where stadium_id = (select stadium_id from stadium order by capacity desc limit 1)
#   EM=8/45 EA=40/45 VS=45/45
#
# [46/100] Find the number of pets whose weight is heavier than 10.
#   -> select count(pets.petid) from pets where pets.weight > 10
#   gold: select count(*) from pets where weight > 10
#   EM=8/46 EA=41/46 VS=46/46
#
# [47/100] How many pets have a greater weight than 10?
#   -> select count(pets.petid) from pets where pets.weight > 10
#   gold: select count(*) from pets where weight > 10
#   EM=8/47 EA=42/47 VS=47/47
#
# [48/100] Find the weight of the youngest dog.
#   -> select pets.weight from pets join has_pet on pets.petid = has_pet.petid join student on has_pet.stuid = student.stuid where pets.pet_type = 'dog' order by pets.pet_age asc limit 1
#   fix1: select pets.weight from pets order by pets.pet_age asc limit 1
#   gold: select weight from pets order by pet_age limit 1
#   EM=8/48 EA=43/48 VS=48/48
#
# [49/100] How much does the youngest dog weigh?
#   -> select pets.weight from pets join has_pet on pets.petid = has_pet.petid join student on has_pet.stuid = student.stuid where pets.pettype = 'dog' order by pets.pet_age asc limit 1
#   gold: select weight from pets order by pet_age limit 1
#   EM=8/49 EA=44/49 VS=49/49
#
# [50/100] Find the maximum weight for each type of pet. List the maximum weight and pet type.
#   -> select pets.pettype, max(pets.weight) as maxweight from pets join has_pet on pets.petid = has_pet.petid join student on has_pet.stuid = student.stuid group by pets.pettype
#   gold: select max(weight), pettype from pets group by pettype
#   EM=8/50 EA=45/50 VS=50/50
#
# [51/100] List the maximum weight and type for each type of pet.
#   -> select pettype, max(weight) as maximum_weight from petid group by pettype
#   fix1: select pettype, max(weight) as maximum_weight from pet group by pettype
#   fix2: select pettype, max(weight) as maximum_weight from petid group by pettype
#   fix3: select pettype, max(weight) as maximum_weight from pet group by pettype
#   gold: select max(weight), pettype from pets group by pettype
#   EM=8/51 EA=45/51 VS=50/51
#
# [52/100] Find number of pets owned by students who are older than 20.
#   -> select count(pets.petid) from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where student.age > 20
#   gold: select count(*) from student as t1 join has_pet as t2 on t1.stuid = t2.stuid where t1.age > 20
#   EM=8/52 EA=46/52 VS=51/52
#
# [53/100] How many pets are owned by students that have an age greater than 20?
#   -> select count(*) from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where student.age > 20
#   gold: select count(*) from student as t1 join has_pet as t2 on t1.stuid = t2.stuid where t1.age > 20
#   EM=8/53 EA=47/53 VS=52/53
#
# [54/100] Find the number of dog pets that are raised by female students (with sex F).
#   -> select count(pets.petid) from pets join has_pet on pets.petid = has_pet.petid join student on has_pet.stuid = student.stuid where pets.pettype = 'dog' and student.sex = 'f'
#   gold: select count(*) from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t2.petid = t3.petid where t1.sex = 'f' and t3.pettype = 'dog'
#   EM=8/54 EA=48/54 VS=53/54
#
# [55/100] How many dog pets are raised by female students?
#   -> select count(distinct student.stuid) from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where student.sex = 'female' and pets.pettype = 'dog'
#   gold: select count(*) from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t2.petid = t3.petid where t1.sex = 'f' and t3.pettype = 'dog'
#   EM=8/55 EA=49/55 VS=54/55
#
# [56/100] Find the number of distinct type of pets.
#   -> select count(distinct pettype) from pets
#   gold: select count(distinct pettype) from pets
#   EM=9/56 EA=50/56 VS=55/56
#
# [57/100] How many different types of pet are there?
#   -> select count(distinct pettype) from pets
#   gold: select count(distinct pettype) from pets
#   EM=10/57 EA=51/57 VS=56/57
#
# [58/100] Find the first name of students who have cat or dog pet.
#   -> select distinct student.fname from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where pets.pettype in ('cat', 'dog')
#   gold: select distinct t1.fname from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'cat' or t3.pettype = 'dog'
#   EM=10/58 EA=52/58 VS=57/58
#
# [59/100] What are the first names of every student who has a cat or dog as a pet?
#   -> select distinct student.fname from pets join has_pet on pets.petid = has_pet.petid join student on has_pet.stuid = student.stuid where pets.pettype in ('cat', 'dog')
#   gold: select distinct t1.fname from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'cat' or t3.pettype = 'dog'
#   EM=10/59 EA=53/59 VS=58/59
#
# [60/100] Find the first name of students who have both cat and dog pets .
#   -> select student.fname from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where pets.pettype = 'cat' intersect select student.fname from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where pets.pettype = 'dog'
#   gold: select t1.fname from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'cat' intersect select t1.fname from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'dog'
#   EM=10/60 EA=54/60 VS=59/60
#
# [61/100] What are the students' first names who have both cats and dogs as pets?
#   -> select student.fname from has_pet join pets on has_pet.petid = pets.petid join student on has_pet.stuid = student.stuid where pets.pettype in ('cat', 'dog') group by student.stuid, student.fname having count(distinct case when pets.pettype = 'cat' then 1 end) > 0 and count(distinct case when pets.pettype = 'dog' then 1 end) > 0
#   gold: select t1.fname from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'cat' intersect select t1.fname from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'dog'
#   EM=10/61 EA=55/61 VS=60/61
#
# [62/100] Find the major and age of students who do not have a cat pet.
#   -> select student.major, student.age from student where student.stuid not in (select student.stuid from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where pets.pettype = 'cat')
#   gold: select major, age from student where stuid not in (select t1.stuid from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'cat')
#   EM=10/62 EA=56/62 VS=61/62
#
# [63/100] What major is every student who does not own a cat as a pet, and also how old are they?
#   -> select student.major, student.age from student left join has_pet on student.stuid = has_pet.stuid left join pets on has_pet.petid = pets.petid and pets.pettype = 'cat' where pets.petid is null
#   fix1: select student.major, student.age from student where student.stuid not in (select has_pet.stuid from has_pet join pets on has_pet.petid = pets.petid where pets.pettype = 'cat')
#   gold: select major, age from student where stuid not in (select t1.stuid from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'cat')
#   EM=10/63 EA=57/63 VS=62/63
#
# [64/100] Find the id of students who do not have a cat pet.
#   -> select student.stuid from student left join has_pet on student.stuid = has_pet.stuid left join pets on has_pet.petid = pets.petid and pets.pettype = 'cat' where pets.petid is null
#   fix1: select student.stuid from student left join has_pet on student.stuid = has_pet.stuid left join pets on has_pet.petid = pets.petid and pets.pettype = 'cat' where pets.petid is null
#   fix2: select s.stuid from student s where not exists ( select 1 from has_pet hp join pets p on hp.petid = p.petid where hp.stuid = s.stuid and p.pettype = 'cat' )
#   gold: select stuid from student except select t1.stuid from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'cat'
#   EM=10/64 EA=58/64 VS=63/64
#
# [65/100] What are the ids of the students who do not own cats as pets?
#   -> select stuid from student where stuid not in (select distinct has_pet.stuid from pets join has_pet on pets.petid = has_pet.petid where pets.pettype = 'cat')
#   gold: select stuid from student except select t1.stuid from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'cat'
#   EM=10/65 EA=59/65 VS=64/65
#
# [66/100] Find the first name and age of students who have a dog but do not have a cat as a pet.
#   -> select student.fname, student.age from student join has_pet on student.stuid = has_pet.stuid join pets as pets_dog on has_pet.petid = pets_dog.petid and pets_dog.pettype = 'dog' left join has_pet as has_pet_cat on student.stuid = has_pet_cat.stuid left join pets as pets_cat on has_pet_cat.petid = pets_cat.petid and pets_cat.pettype = 'cat' where pets_cat.petid is null
#   fix1: select distinct s.fname, s.age from student s join has_pet hp on s.stuid = hp.stuid join pets p on hp.petid = p.petid and p.pettype = 'dog' where not exists ( select 1 from has_pet hp_cat join pets p_cat on hp_cat.petid = p_cat.petid where hp_cat.stuid = s.stuid and p_cat.pettype = 'cat' )
#   fix2: select s.fname, s.age from student s where exists (select 1 from has_pet hp join pets p on hp.petid = p.petid where hp.stuid = s.stuid and p.pettype = 'dog') and not exists (select 1 from has_pet hp join pets p on hp.petid = p.petid where hp.stuid = s.stuid and p.pettype = 'cat')
#   fix3: select s.fname, s.age from student s where exists ( select 1 from has_pet hp join pets p on hp.petid = p.petid where hp.stuid = s.stuid and p.pettype = 'dog' ) and not exists ( select 1 from has_pet hp join pets p on hp.petid = p.petid where hp.stuid = s.stuid and p.pettype = 'cat' )
#   gold: select t1.fname, t1.age from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'dog' and t1.stuid not in (select t1.stuid from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'cat')
#   EM=10/66 EA=59/66 VS=65/66
#
# [67/100] What is the first name of every student who has a dog but does not have a cat?
#   -> select student.fname from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where pets.pettype = 'dog' and student.stuid not in (select has_pet.stuid from has_pet join pets on has_pet.petid = pets.petid where pets.pettype = 'cat')
#   fix1: select s.fname from student s where s.stuid in ( select distinct hp.stuid from has_pet hp join pets p on hp.petid = p.petid where p.pettype = 'dog' ) and s.stuid not in ( select distinct hp.stuid from has_pet hp join pets p on hp.petid = p.petid where p.pettype = 'cat' )
#   fix2: select s.fname from student s where s.stuid in ( select distinct hp.stuid from has_pet hp join pets p on hp.petid = p.petid where p.pettype = 'dog' ) and s.stuid not in ( select distinct hp.stuid from has_pet hp join pets p on hp.petid = p.petid where p.pettype = 'cat' )
#   fix3: select s.fname from student s where s.stuid in ( select hp.stuid from has_pet hp join pets p on hp.petid = p.petid where p.pettype = 'dog' except select hp.stuid from has_pet hp join pets p on hp.petid = p.petid where p.pettype = 'cat' )
#   gold: select t1.fname, t1.age from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'dog' and t1.stuid not in (select t1.stuid from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'cat')
#   EM=10/67 EA=59/67 VS=66/67
#
# [68/100] Find the type and weight of the youngest pet.
#   -> select pettype, weight from pets order by pet_age asc limit 1
#   gold: select pettype, weight from pets order by pet_age limit 1
#   EM=10/68 EA=60/68 VS=67/68
#
# [69/100] What type of pet is the youngest animal, and how much does it weigh?
#   -> select pets.pettype, pets.weight from pets join has_pet on pets.petid = has_pet.petid join student on has_pet.stuid = student.stuid order by pets.pet_age asc limit 1
#   gold: select pettype, weight from pets order by pet_age limit 1
#   EM=10/69 EA=61/69 VS=68/69
#
# [70/100] Find the id and weight of all pets whose age is older than 1.
#   -> select pets.petid, pets.weight from pets join has_pet on pets.petid = has_pet.petid join student on has_pet.stuid = student.stuid where pets.pet_age > 1
#   gold: select petid, weight from pets where pet_age > 1
#   EM=10/70 EA=62/70 VS=69/70
#
# [71/100] What is the id and weight of every pet who is older than 1?
#   -> select pets.petid, pets.weight from pets join has_pet on pets.petid = has_pet.petid join student on has_pet.stuid = student.stuid where pets.pet_age > 1
#   gold: select petid, weight from pets where pet_age > 1
#   EM=10/71 EA=63/71 VS=70/71
#
# [72/100] Find the average and maximum age for each type of pet.
#   -> select pets.pettype, avg(student.age) as avgage, max(student.age) as maxage from pets join has_pet on pets.petid = has_pet.petid join student on has_pet.stuid = student.stuid group by pets.pettype
#   fix1: select pets.pettype, avg(pets.pet_age) as avgage, max(pets.pet_age) as maxage from pets join has_pet on pets.petid = has_pet.petid join student on has_pet.stuid = student.stuid group by pets.pettype
#   gold: select avg(pet_age), max(pet_age), pettype from pets group by pettype
#   EM=10/72 EA=64/72 VS=71/72
#
# [73/100] What is the average and maximum age for each pet type?
#   -> select pets.pettype, avg(pets.pet_age) as avgage, max(pets.pet_age) as maxage from pets join has_pet on pets.petid = has_pet.petid join student on has_pet.stuid = student.stuid group by pets.pettype
#   gold: select avg(pet_age), max(pet_age), pettype from pets group by pettype
#   EM=10/73 EA=65/73 VS=72/73
#
# [74/100] Find the average weight for each pet type.
#   -> select pets.pettype, avg(pets.weight) from pets join has_pet on pets.petid = has_pet.petid group by pets.pettype
#   gold: select avg(weight), pettype from pets group by pettype
#   EM=10/74 EA=66/74 VS=73/74
#
# [75/100] What is the average weight for each type of pet?
#   -> select pets.pettype, avg(pets.weight) from pets join has_pet on pets.petid = has_pet.petid group by pets.pettype
#   gold: select avg(weight), pettype from pets group by pettype
#   EM=10/75 EA=67/75 VS=74/75
#
# [76/100] Find the first name and age of students who have a pet.
#   -> select student.fname, student.age from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid
#   fix1: select student.fname, student.age from student where exists (select 1 from has_pet where has_pet.stuid = student.stuid)
#   gold: select distinct t1.fname, t1.age from student as t1 join has_pet as t2 on t1.stuid = t2.stuid
#   EM=10/76 EA=68/76 VS=75/76
#
# [77/100] What are the different first names and ages of the students who do have pets?
#   -> select distinct student.fname, student.age from student join has_pet on student.stuid = has_pet.stuid
#   gold: select distinct t1.fname, t1.age from student as t1 join has_pet as t2 on t1.stuid = t2.stuid
#   EM=10/77 EA=69/77 VS=76/77
#
# [78/100] Find the id of the pet owned by student whose last name is ‘Smith’.
#   -> select pets.petid from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where student.lname = 'smith'
#   gold: select t2.petid from student as t1 join has_pet as t2 on t1.stuid = t2.stuid where t1.lname = 'smith'
#   EM=10/78 EA=70/78 VS=77/78
#
# [79/100] What is the id of the pet owned by the student whose last name is 'Smith'?
#   -> select pets.petid from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where student.lname = 'smith'
#   gold: select t2.petid from student as t1 join has_pet as t2 on t1.stuid = t2.stuid where t1.lname = 'smith'
#   EM=10/79 EA=71/79 VS=78/79
#
# [80/100] Find the number of pets for each student who has any pet and student id.
#   -> select student.stuid, count(pets.petid) from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid group by student.stuid
#   gold: select count(*), t1.stuid from student as t1 join has_pet as t2 on t1.stuid = t2.stuid group by t1.stuid
#   EM=10/80 EA=72/80 VS=79/80
#
# [81/100] For students who have pets , how many pets does each student have ? list their ids instead of names .
#   -> select has_pet.stuid, count(pets.petid) from has_pet join student on has_pet.stuid = student.stuid join pets on has_pet.petid = pets.petid group by has_pet.stuid
#   gold: select count(*), t1.stuid from student as t1 join has_pet as t2 on t1.stuid = t2.stuid group by t1.stuid
#   EM=10/81 EA=73/81 VS=80/81
#
# [82/100] Find the first name and gender of student who have more than one pet.
#   -> select student.fname, student.sex from has_pet join student on has_pet.stuid = student.stuid group by has_pet.stuid, student.fname, student.sex having count(has_pet.petid) > 1
#   gold: select t1.fname, t1.sex from student as t1 join has_pet as t2 on t1.stuid = t2.stuid group by t1.stuid having count(*) > 1
#   EM=10/82 EA=74/82 VS=81/82
#
# [83/100] What is the first name and gender of the all the students who have more than one pet?
#   -> select student.fname, student.sex from has_pet join student on has_pet.stuid = student.stuid group by has_pet.stuid having count(has_pet.petid) > 1
#   gold: select t1.fname, t1.sex from student as t1 join has_pet as t2 on t1.stuid = t2.stuid group by t1.stuid having count(*) > 1
#   EM=10/83 EA=75/83 VS=82/83
#
# [84/100] Find the last name of the student who has a cat that is age 3.
#   -> select student.lname from pets join has_pet on pets.petid = has_pet.petid join student on has_pet.stuid = student.stuid where pets.pettype = 'cat' and pets.pet_age = 3
#   gold: select t1.lname from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pet_age = 3 and t3.pettype = 'cat'
#   EM=10/84 EA=76/84 VS=83/84
#
# [85/100] What is the last name of the student who has a cat that is 3 years old?
#   -> select student.lname from pets join has_pet on pets.petid = has_pet.petid join student on has_pet.stuid = student.stuid where pets.pet_age = 3
#   gold: select t1.lname from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pet_age = 3 and t3.pettype = 'cat'
#   EM=10/85 EA=77/85 VS=84/85
#
# [86/100] Find the average age of students who do not have any pet .
#   -> select avg(student.age) from student left join has_pet on student.stuid = has_pet.stuid where has_pet.stuid is null
#   gold: select avg(age) from student where stuid not in (select stuid from has_pet)
#   EM=10/86 EA=78/86 VS=85/86
#
# [87/100] What is the average age for all students who do not own any pets ?
#   -> select avg(student.age) from student left join has_pet on student.stuid = has_pet.stuid where has_pet.stuid is null
#   gold: select avg(age) from student where stuid not in (select stuid from has_pet)
#   EM=10/87 EA=79/87 VS=86/87
#
# [88/100] How many continents are there?
#   -> select count(distinct continent) from continents
#   gold: select count(*) from continents
#   EM=10/88 EA=80/88 VS=87/88
#
# [89/100] What is the number of continents?
#   -> select count(distinct continents.continent) from continents
#   gold: select count(*) from continents
#   EM=10/89 EA=81/89 VS=88/89
#
# [90/100] How many countries does each continent have? List the continent id, continent name and the number of countries.
#   -> select continents.contid, continents.continent, count(countries.countryid) from continents join countries on continents.contid = countries.continent group by continents.contid, continents.continent
#   gold: select t1.contid, t1.continent, count(*) from continents as t1 join countries as t2 on t1.contid = t2.continent group by t1.contid
#   EM=10/90 EA=82/90 VS=89/90
#
# [91/100] For each continent, list its id, name, and how many countries it has?
#   -> select continents.contid, continents.continent, count(countries.countryid) from continents left join countries on continents.contid = countries.continent group by continents.contid, continents.continent
#   gold: select t1.contid, t1.continent, count(*) from continents as t1 join countries as t2 on t1.contid = t2.continent group by t1.contid
#   EM=10/91 EA=83/91 VS=90/91
#
# [92/100] How many countries are listed?
#   -> select count(distinct countryid) from countries
#   gold: select count(*) from countries
#   EM=10/92 EA=84/92 VS=91/92
#
# [93/100] How many countries exist?
#   -> select count(distinct countryid) from countries
#   gold: select count(*) from countries
#   EM=10/93 EA=85/93 VS=92/93
#
# [94/100] How many models does each car maker produce? List maker full name, id and the number.
#   -> select car_makers.fullname, car_makers.id, count(model_list.modelid) from car_makers join model_list on car_makers.id = model_list.maker group by car_makers.id, car_makers.fullname
#   gold: select t1.fullname, t1.id, count(*) from car_makers as t1 join model_list as t2 on t1.id = t2.maker group by t1.id
#   EM=10/94 EA=86/94 VS=93/94
#
# [95/100] What is the full name of each car maker, along with its id and how many models it produces?
#   -> select car_makers.id, car_makers.fullname, count(model_list.modelid) from car_makers join model_list on car_makers.id = model_list.maker group by car_makers.id, car_makers.fullname
#   gold: select t1.fullname, t1.id, count(*) from car_makers as t1 join model_list as t2 on t1.id = t2.maker group by t1.id
#   EM=10/95 EA=87/95 VS=94/95
#
# [96/100] Which model of the car has the minimum horsepower?
#   -> select model_list.model, cars_data.horsepower from cars_data join car_names on cars_data.id = car_names.makeid join model_list on car_names.model = model_list.model order by cars_data.horsepower asc limit 1
#   fix1: select model_list.model, min(cars_data.horsepower) as min_horsepower from cars_data join car_names on cars_data.id = car_names.makeid join model_list on car_names.model = model_list.model group by model_list.model order by min_horsepower asc limit 1
#   fix2: select model_list.model from cars_data join car_names on cars_data.id = car_names.makeid join model_list on car_names.model = model_list.model where cars_data.horsepower = (select min(horsepower) from cars_data)
#   fix3: select model_list.model from cars_data join car_names on cars_data.id = car_names.makeid join model_list on car_names.model = model_list.model where cars_data.horsepower = (select min(horsepower) from cars_data)
#   gold: select t1.model from car_names as t1 join cars_data as t2 on t1.makeid = t2.id order by t2.horsepower asc limit 1
#   EM=10/96 EA=87/96 VS=95/96
#
# [97/100] What is the model of the car with the smallest amount of horsepower?
#   -> select model_list.model from cars_data join car_names on cars_data.id = car_names.makeid join model_list on car_names.model = model_list.model order by cars_data.horsepower asc limit 1
#   gold: select t1.model from car_names as t1 join cars_data as t2 on t1.makeid = t2.id order by t2.horsepower asc limit 1
#   EM=10/97 EA=88/97 VS=96/97
#
# [98/100] Find the model of the car whose weight is below the average weight.
#   -> select car_names.model from cars_data join car_names on cars_data.id = car_names.makeid where cars_data.weight < (select avg(weight) from cars_data)
#   gold: select t1.model from car_names as t1 join cars_data as t2 on t1.makeid = t2.id where t2.weight < (select avg(weight) from cars_data)
#   EM=10/98 EA=89/98 VS=97/98
#
# [99/100] What is the model for the car with a weight smaller than the average?
#   -> select model_list.model from cars_data join car_names on cars_data.id = car_names.makeid join model_list on car_names.model = model_list.model where cars_data.weight < (select avg(weight) from cars_data)
#   fix1: select model_list.model from cars_data join car_names on car_names.makeid = cars_data.id join model_list on car_names.model = model_list.model where cars_data.weight < (select avg(weight) from cars_data)
#   fix2: select model_list.model from cars_data join car_names on cars_data.id = car_names.makeid join model_list on car_names.model = model_list.model where cars_data.weight < (select avg(weight) from cars_data)
#   fix3: select model_list.model from cars_data join car_names on car_names.makeid = cars_data.id join model_list on car_names.model = model_list.model where cars_data.weight < (select avg(weight) from cars_data)
#   gold: select t1.model from car_names as t1 join cars_data as t2 on t1.makeid = t2.id where t2.weight < (select avg(weight) from cars_data)
#   EM=10/99 EA=89/99 VS=98/99
#
# [100/100] Find the name of the makers that produced some cars in the year of 1970?
#   -> select distinct car_makers.maker from cars_data join car_names on cars_data.id = car_names.makeid join model_list on car_names.model = model_list.model join car_makers on model_list.maker = car_makers.id where cars_data.year = 1970
#   gold: select distinct t1.maker from car_makers as t1 join model_list as t2 on t1.id = t2.maker join car_names as t3 on t2.model = t3.model join cars_data as t4 on t3.makeid = t4.id where t4.year = '1970'
#   EM=10/100 EA=90/100 VS=99/100
#
# === no_subproblem === {"total": 100, "em": 10, "vs": 99, "ea": 90, "em%": 0.1, "vs%": 0.99, "ea%": 0.9}

# %%
r4 = run(gen_noschema, "no_schemalink")
# Out:
# [1/100] How many singers do we have?
#   -> select count(distinct singer_id) from singer
#   gold: select count(*) from singer
#   EM=0/1 EA=1/1 VS=1/1
#
# [2/100] What is the total number of singers?
#   -> select count(*) from singer
#   gold: select count(*) from singer
#   EM=1/2 EA=2/2 VS=2/2
#
# [3/100] Show name, country, age for all singers ordered by age from the oldest to the youngest.
#   -> select s.name, s.country, s.age from singer s order by s.age desc
#   gold: select name, country, age from singer order by age desc
#   EM=1/3 EA=3/3 VS=3/3
#
# [4/100] What are the names, countries, and ages for every singer in descending order of age?
#   -> select name, country, age from singer order by age desc
#   gold: select name, country, age from singer order by age desc
#   EM=2/4 EA=4/4 VS=4/4
#
# [5/100] What is the average, minimum, and maximum age of all singers from France?
#   -> select avg(singer.age), min(singer.age), max(singer.age) from singer where singer.country = 'france'
#   gold: select avg(age), min(age), max(age) from singer where country = 'france'
#   EM=2/5 EA=5/5 VS=5/5
#
# [6/100] What is the average, minimum, and maximum age for all French singers?
#   -> select avg(singer.age), min(singer.age), max(singer.age) from singer where singer.country = 'french'
#   gold: select avg(age), min(age), max(age) from singer where country = 'france'
#   EM=2/6 EA=6/6 VS=6/6
#
# [7/100] Show the name and the release year of the song by the youngest singer.
#   -> select name, song_release_year from singer where age = (select min(age) from singer)
#   fix1: select song_name, song_release_year from singer where age = (select min(age) from singer)
#   gold: select song_name, song_release_year from singer order by age limit 1
#   EM=2/7 EA=7/7 VS=7/7
#
# [8/100] What are the names and release years for all the songs of the youngest singer?
#   -> select s.name, s.song_name, s.song_release_year from singer s where s.age = (select min(age) from singer)
#   fix1: select s.song_name, s.song_release_year from singer s where s.age = (select min(age) from singer)
#   gold: select song_name, song_release_year from singer order by age limit 1
#   EM=2/8 EA=8/8 VS=8/8
#
# [9/100] What are all distinct countries where singers above age 20 are from?
#   -> select distinct singer.country from singer where singer.age > 20
#   gold: select distinct country from singer where age > 20
#   EM=2/9 EA=9/9 VS=9/9
#
# [10/100] What are  the different countries with singers above age 20?
#   -> select distinct country from singer where age > 20
#   gold: select distinct country from singer where age > 20
#   EM=3/10 EA=10/10 VS=10/10
#
# [11/100] Show all countries and the number of singers in each country.
#   -> select country, count(singer_id) from singer group by country
#   gold: select country, count(*) from singer group by country
#   EM=3/11 EA=11/11 VS=11/11
#
# [12/100] How many singers are from each country?
#   -> select country, count(singer_id) from singer group by country
#   gold: select country, count(*) from singer group by country
#   EM=3/12 EA=12/12 VS=12/12
#
# [13/100] List all song names by singers above the average age.
#   -> select song_name from singer where age > (select avg(age) from singer)
#   gold: select song_name from singer where age > (select avg(age) from singer)
#   EM=4/13 EA=13/13 VS=13/13
#
# [14/100] What are all the song names by singers who are older than average?
#   -> select s.name, s.song_name from singer s where s.age > (select avg(age) from singer)
#   fix1: select distinct s.song_name from singer s where s.age > (select avg(age) from singer)
#   gold: select song_name from singer where age > (select avg(age) from singer)
#   EM=4/14 EA=14/14 VS=14/14
#
# [15/100] Show location and name for all stadiums with a capacity between 5000 and 10000.
#   -> select location, name from stadium where capacity between 5000 and 10000
#   gold: select location, name from stadium where capacity between 5000 and 10000
#   EM=5/15 EA=15/15 VS=15/15
#
# [16/100] What are the locations and names of all stations with capacity between 5000 and 10000?
#   -> select location, name from stadium where capacity between 5000 and 10000
#   gold: select location, name from stadium where capacity between 5000 and 10000
#   EM=6/16 EA=16/16 VS=16/16
#
# [17/100] What is the maximum capacity and the average of all stadiums ?
#   -> select max(capacity), avg(average) from stadium
#   fix1: select max(capacity), avg(capacity) from stadium
#   fix2: select max(capacity) as max_capacity, avg(capacity) as average_capacity from stadium
#   fix3: select max(capacity) as max_capacity, avg(average) as average_of_stadiums from stadium
#   gold: select max(capacity), average from stadium
#   EM=6/17 EA=16/17 VS=17/17
#
# [18/100] What is the average and maximum capacities for all stadiums ?
#   -> select avg(capacity) as average_capacity, max(capacity) as maximum_capacity from stadium
#   gold: select avg(capacity), max(capacity) from stadium
#   EM=6/18 EA=17/18 VS=18/18
#
# [19/100] What is the name and capacity for the stadium with highest average attendance?
#   -> select stadium.name, stadium.capacity from stadium join concert on stadium.stadium_id = concert.stadium_id group by stadium.stadium_id, stadium.name, stadium.capacity order by avg(stadium.average) desc limit 1
#   gold: select name, capacity from stadium order by average desc limit 1
#   EM=6/19 EA=18/19 VS=19/19
#
# [20/100] What is the name and capacity for the stadium with the highest average attendance?
#   -> select stadium.name, stadium.capacity from stadium join concert on stadium.stadium_id = concert.stadium_id group by stadium.stadium_id, stadium.name, stadium.capacity having avg(concert.average) = (select max(avg_att) from (select avg(average) as avg_att from concert group by stadium_id) as sub) order by avg(concert.average) desc limit 1
#   fix1: select name, capacity from stadium where average = (select max(average) from stadium)
#   gold: select name, capacity from stadium order by average desc limit 1
#   EM=6/20 EA=19/20 VS=20/20
#
# [21/100] How many concerts are there in year 2014 or 2015?
#   -> select count(distinct concert_id) from concert where year in (2014, 2015)
#   gold: select count(*) from concert where year = 2014 or year = 2015
#   EM=6/21 EA=20/21 VS=21/21
#
# [22/100] How many concerts occurred in 2014 or 2015?
#   -> select count(*) from concert where year in (2014, 2015)
#   gold: select count(*) from concert where year = 2014 or year = 2015
#   EM=6/22 EA=21/22 VS=22/22
#
# [23/100] Show the stadium name and the number of concerts in each stadium.
#   -> select stadium.name, count(concert.concert_id) from stadium join concert on stadium.stadium_id = concert.stadium_id group by stadium.name
#   gold: select t2.name, count(*) from concert as t1 join stadium as t2 on t1.stadium_id = t2.stadium_id group by t1.stadium_id
#   EM=6/23 EA=22/23 VS=23/23
#
# [24/100] For each stadium, how many concerts play there?
#   -> select stadium.name, count(concert.concert_id) from stadium join concert on stadium.stadium_id = concert.stadium_id group by stadium.name
#   gold: select t2.name, count(*) from concert as t1 join stadium as t2 on t1.stadium_id = t2.stadium_id group by t1.stadium_id
#   EM=6/24 EA=23/24 VS=24/24
#
# [25/100] Show the stadium name and capacity with most number of concerts in year 2014 or after.
#   -> select stadium.name, stadium.capacity from stadium join concert on stadium.stadium_id = concert.stadium_id where concert.year >= 2014 group by stadium.stadium_id, stadium.name, stadium.capacity order by count(concert.concert_id) desc limit 1
#   gold: select t2.name, t2.capacity from concert as t1 join stadium as t2 on t1.stadium_id = t2.stadium_id where t1.year >= 2014 group by t2.stadium_id order by count(*) desc limit 1
#   EM=6/25 EA=24/25 VS=25/25
#
# [26/100] What is the name and capacity of the stadium with the most concerts after 2013 ?
#   -> select stadium.name, stadium.capacity from concert join stadium on concert.stadium_id = stadium.stadium_id where concert.year > 2013 group by stadium.stadium_id, stadium.name, stadium.capacity order by count(concert.concert_id) desc limit 1
#   gold: select t2.name, t2.capacity from concert as t1 join stadium as t2 on t1.stadium_id = t2.stadium_id where t1.year > 2013 group by t2.stadium_id order by count(*) desc limit 1
#   EM=6/26 EA=25/26 VS=26/26
#
# [27/100] Which year has most number of concerts?
#   -> select year, count(concert_id) as concert_count from concert group by year order by concert_count desc limit 1
#   fix1: select year, count(concert_id) as concert_count from concert group by year having count(concert_id) = (select max(cnt) from (select count(concert_id) as cnt from concert group by year) as counts)
#   fix2: select year, count(concert_id) as concert_count from concert group by year order by concert_count desc limit 1
#   fix3: select c.year, count(distinct sic.concert_id) as concert_count from singer_in_concert sic join concert c on sic.concert_id = c.concert_id group by c.year order by concert_count desc limit 1
#   gold: select year from concert group by year order by count(*) desc limit 1
#   EM=6/27 EA=25/27 VS=27/27
#
# [28/100] What is the year that had the most concerts?
#   -> select concert.year, count(concert.concert_id) as concert_count from concert group by concert.year order by concert_count desc limit 1
#   fix1: select year from concert group by year order by count(concert_id) desc limit 1
#   gold: select year from concert group by year order by count(*) desc limit 1
#   EM=6/28 EA=26/28 VS=28/28
#
# [29/100] Show the stadium names without any concert.
#   -> select stadium.name from stadium left join concert on stadium.stadium_id = concert.stadium_id where concert.concert_id is null
#   gold: select name from stadium where stadium_id not in (select stadium_id from concert)
#   EM=6/29 EA=27/29 VS=29/29
#
# [30/100] What are the names of the stadiums without any concerts?
#   -> select stadium.name from stadium left join concert on stadium.stadium_id = concert.stadium_id where concert.concert_id is null
#   gold: select name from stadium where stadium_id not in (select stadium_id from concert)
#   EM=6/30 EA=28/30 VS=30/30
#
# [31/100] Show countries where a singer above age 40 and a singer below 30 are from.
#   -> select distinct country from singer where age > 40 intersect select distinct country from singer where age < 30
#   gold: select country from singer where age > 40 intersect select country from singer where age < 30
#   EM=6/31 EA=29/31 VS=31/31
#
# [32/100] Show names for all stadiums except for stadiums having a concert in year 2014.
#   -> select stadium.name from stadium where stadium.stadium_id not in (select stadium_id from concert where year = 2014)
#   gold: select name from stadium except select t2.name from concert as t1 join stadium as t2 on t1.stadium_id = t2.stadium_id where t1.year = 2014
#   EM=6/32 EA=30/32 VS=32/32
#
# [33/100] What are the names of all stadiums that did not have a concert in 2014?
#   -> select distinct s.name from stadium s left join concert c on s.stadium_id = c.stadium_id and c.year = 2014 where c.concert_id is null
#   gold: select name from stadium except select t2.name from concert as t1 join stadium as t2 on t1.stadium_id = t2.stadium_id where t1.year = 2014
#   EM=6/33 EA=31/33 VS=33/33
#
# [34/100] Show the name and theme for all concerts and the number of singers in each concert.
#   -> select concert.concert_name, concert.theme, count(singer_in_concert.singer_id) as singer_count from concert join singer_in_concert on concert.concert_id = singer_in_concert.concert_id group by concert.concert_id, concert.concert_name, concert.theme
#   gold: select t2.concert_name, t2.theme, count(*) from singer_in_concert as t1 join concert as t2 on t1.concert_id = t2.concert_id group by t2.concert_id
#   EM=6/34 EA=32/34 VS=34/34
#
# [35/100] What are the names , themes , and number of singers for every concert ?
#   -> select concert.concert_name, concert.theme, count(singer_in_concert.singer_id) as number_of_singers from concert join singer_in_concert on concert.concert_id = singer_in_concert.concert_id group by concert.concert_id, concert.concert_name, concert.theme
#   gold: select t2.concert_name, t2.theme, count(*) from singer_in_concert as t1 join concert as t2 on t1.concert_id = t2.concert_id group by t2.concert_id
#   EM=6/35 EA=33/35 VS=35/35
#
# [36/100] List singer names and number of concerts for each singer.
#   -> select singer.name, count(singer_in_concert.concert_id) as number_of_concerts from singer_in_concert join singer on singer_in_concert.singer_id = singer.singer_id group by singer.singer_id, singer.name
#   gold: select t2.name, count(*) from singer_in_concert as t1 join singer as t2 on t1.singer_id = t2.singer_id group by t2.singer_id
#   EM=6/36 EA=34/36 VS=36/36
#
# [37/100] What are the names of the singers and number of concerts for each person?
#   -> select s.name, count(sic.concert_id) as number_of_concerts from singer s join singer_in_concert sic on s.singer_id = sic.singer_id group by s.singer_id, s.name
#   gold: select t2.name, count(*) from singer_in_concert as t1 join singer as t2 on t1.singer_id = t2.singer_id group by t2.singer_id
#   EM=6/37 EA=35/37 VS=37/37
#
# [38/100] List all singer names in concerts in year 2014.
#   -> select distinct singer.name from singer_in_concert join singer on singer_in_concert.singer_id = singer.singer_id join concert on singer_in_concert.concert_id = concert.concert_id where concert.year = 2014
#   fix1: select distinct singer.name from singer_in_concert join singer on singer_in_concert.singer_id = singer.singer_id join concert on singer_in_concert.concert_id = concert.concert_id where concert.year = 2014
#   fix2: select distinct singer.name from singer_in_concert join singer on singer_in_concert.singer_id = singer.singer_id join concert on singer_in_concert.concert_id = concert.concert_id where concert.year = 2014
#   fix3: select distinct singer.name from singer_in_concert join singer on singer_in_concert.singer_id = singer.singer_id join concert on singer_in_concert.concert_id = concert.concert_id where concert.year = 2014
#   gold: select t2.name from singer_in_concert as t1 join singer as t2 on t1.singer_id = t2.singer_id join concert as t3 on t1.concert_id = t3.concert_id where t3.year = 2014
#   EM=6/38 EA=35/38 VS=38/38
#
# [39/100] What are the names of the singers who performed in a concert in 2014?
#   -> select distinct singer.name from singer_in_concert join singer on singer_in_concert.singer_id = singer.singer_id join concert on singer_in_concert.concert_id = concert.concert_id where concert.year = 2014
#   fix1: select distinct singer.name from singer_in_concert join singer on singer_in_concert.singer_id = singer.singer_id join concert on singer_in_concert.concert_id = concert.concert_id where concert.year = 2014
#   fix2: select distinct singer.name from singer_in_concert join singer on singer_in_concert.singer_id = singer.singer_id join concert on singer_in_concert.concert_id = concert.concert_id where concert.year = 2014
#   fix3: select distinct singer.name from singer_in_concert join singer on singer_in_concert.singer_id = singer.singer_id join concert on singer_in_concert.concert_id = concert.concert_id where concert.year = 2014
#   gold: select t2.name from singer_in_concert as t1 join singer as t2 on t1.singer_id = t2.singer_id join concert as t3 on t1.concert_id = t3.concert_id where t3.year = 2014
#   EM=6/39 EA=35/39 VS=39/39
#
# [40/100] what is the name and nation of the singer who have a song having 'Hey' in its name?
#   -> select name, country from singer where song_name like '%hey%'
#   gold: select name, country from singer where song_name like '%hey%'
#   EM=7/40 EA=36/40 VS=40/40
#
# [41/100] What is the name and country of origin of every singer who has a song with the word 'Hey' in its title?
#   -> select name, country from singer where song_name like '%hey%'
#   gold: select name, country from singer where song_name like '%hey%'
#   EM=8/41 EA=37/41 VS=41/41
#
# [42/100] Find the name and location of the stadiums which some concerts happened in the years of both 2014 and 2015.
#   -> select s.name, s.location from stadium s join concert c on s.stadium_id = c.stadium_id where c.year = 2014 intersect select s.name, s.location from stadium s join concert c on s.stadium_id = c.stadium_id where c.year = 2015
#   gold: select t2.name, t2.location from concert as t1 join stadium as t2 on t1.stadium_id = t2.stadium_id where t1.year = 2014 intersect select t2.name, t2.location from concert as t1 join stadium as t2 on t1.stadium_id = t2.stadium_id where t1.year = 2015
#   EM=8/42 EA=38/42 VS=42/42
#
# [43/100] What are the names and locations of the stadiums that had concerts that occurred in both 2014 and 2015?
#   -> select s.name, s.location from stadium s join concert c on s.stadium_id = c.stadium_id group by s.stadium_id, s.name, s.location having count(distinct c.year) = 2 and sum(case when c.year = 2014 then 1 else 0 end) > 0 and sum(case when c.year = 2015 then 1 else 0 end) > 0
#   gold: select t2.name, t2.location from concert as t1 join stadium as t2 on t1.stadium_id = t2.stadium_id where t1.year = 2014 intersect select t2.name, t2.location from concert as t1 join stadium as t2 on t1.stadium_id = t2.stadium_id where t1.year = 2015
#   EM=8/43 EA=39/43 VS=43/43
#
# [44/100] Find the number of concerts happened in the stadium with the highest capacity .
#   -> select count(concert.concert_id) from concert join stadium on concert.stadium_id = stadium.stadium_id where stadium.capacity = (select max(capacity) from stadium)
#   gold: select count(*) from concert where stadium_id = (select stadium_id from stadium order by capacity desc limit 1)
#   EM=8/44 EA=40/44 VS=44/44
#
# [45/100] What are the number of concerts that occurred in the stadium with the largest capacity ?
#   -> select count(c.concert_id) from concert c join stadium s on c.stadium_id = s.stadium_id where s.capacity = (select max(capacity) from stadium)
#   gold: select count(*) from concert where stadium_id = (select stadium_id from stadium order by capacity desc limit 1)
#   EM=8/45 EA=41/45 VS=45/45
#
# [46/100] Find the number of pets whose weight is heavier than 10.
#   -> select count(pets.petid) from pets where pets.weight > 10
#   gold: select count(*) from pets where weight > 10
#   EM=8/46 EA=42/46 VS=46/46
#
# [47/100] How many pets have a greater weight than 10?
#   -> select count(pets.petid) from pets where pets.weight > 10
#   gold: select count(*) from pets where weight > 10
#   EM=8/47 EA=43/47 VS=47/47
#
# [48/100] Find the weight of the youngest dog.
#   -> select pets.weight from pets join has_pet on pets.petid = has_pet.petid where pets.pettype = 'dog' order by pets.pet_age asc limit 1
#   gold: select weight from pets order by pet_age limit 1
#   EM=8/48 EA=44/48 VS=48/48
#
# [49/100] How much does the youngest dog weigh?
#   -> select pets.weight from pets join has_pet on pets.petid = has_pet.petid where pets.pettype = 'dog' order by pets.pet_age asc limit 1
#   gold: select weight from pets order by pet_age limit 1
#   EM=8/49 EA=45/49 VS=49/49
#
# [50/100] Find the maximum weight for each type of pet. List the maximum weight and pet type.
#   -> select pettype, max(weight) as max_weight from pets group by pettype
#   gold: select max(weight), pettype from pets group by pettype
#   EM=8/50 EA=46/50 VS=50/50
#
# [51/100] List the maximum weight and type for each type of pet.
#   -> select pettype, max(weight) as max_weight from pets group by pettype
#   gold: select max(weight), pettype from pets group by pettype
#   EM=8/51 EA=47/51 VS=51/51
#
# [52/100] Find number of pets owned by students who are older than 20.
#   -> select count(has_pet.petid) from student join has_pet on student.stuid = has_pet.stuid where student.age > 20
#   gold: select count(*) from student as t1 join has_pet as t2 on t1.stuid = t2.stuid where t1.age > 20
#   EM=8/52 EA=48/52 VS=52/52
#
# [53/100] How many pets are owned by students that have an age greater than 20?
#   -> select count(distinct pets.petid) from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where student.age > 20
#   gold: select count(*) from student as t1 join has_pet as t2 on t1.stuid = t2.stuid where t1.age > 20
#   EM=8/53 EA=49/53 VS=53/53
#
# [54/100] Find the number of dog pets that are raised by female students (with sex F).
#   -> select count(pets.petid) from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where pets.pettype = 'dog' and student.sex = 'f'
#   gold: select count(*) from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t2.petid = t3.petid where t1.sex = 'f' and t3.pettype = 'dog'
#   EM=8/54 EA=50/54 VS=54/54
#
# [55/100] How many dog pets are raised by female students?
#   -> select count(distinct pets.petid) from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where student.sex = 'f' and pets.pettype = 'dog'
#   gold: select count(*) from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t2.petid = t3.petid where t1.sex = 'f' and t3.pettype = 'dog'
#   EM=8/55 EA=51/55 VS=55/55
#
# [56/100] Find the number of distinct type of pets.
#   -> select count(distinct pettype) from pets
#   gold: select count(distinct pettype) from pets
#   EM=9/56 EA=52/56 VS=56/56
#
# [57/100] How many different types of pet are there?
#   -> select count(distinct pettype) from pets
#   gold: select count(distinct pettype) from pets
#   EM=10/57 EA=53/57 VS=57/57
#
# [58/100] Find the first name of students who have cat or dog pet.
#   -> select distinct student.fname from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where pets.pettype in ('cat', 'dog')
#   gold: select distinct t1.fname from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'cat' or t3.pettype = 'dog'
#   EM=10/58 EA=54/58 VS=58/58
#
# [59/100] What are the first names of every student who has a cat or dog as a pet?
#   -> select distinct student.fname from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where pets.pettype in ('cat', 'dog')
#   gold: select distinct t1.fname from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'cat' or t3.pettype = 'dog'
#   EM=10/59 EA=55/59 VS=59/59
#
# [60/100] Find the first name of students who have both cat and dog pets .
#   -> select student.fname from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where pets.pettype = 'cat' intersect select student.fname from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where pets.pettype = 'dog'
#   gold: select t1.fname from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'cat' intersect select t1.fname from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'dog'
#   EM=10/60 EA=56/60 VS=60/60
#
# [61/100] What are the students' first names who have both cats and dogs as pets?
#   -> select student.fname from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where pets.pettype = 'cat' intersect select student.fname from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where pets.pettype = 'dog'
#   gold: select t1.fname from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'cat' intersect select t1.fname from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'dog'
#   EM=10/61 EA=57/61 VS=61/61
#
# [62/100] Find the major and age of students who do not have a cat pet.
#   -> select student.major, student.age from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where pets.pettype = 'cat' except select student.major, student.age from student where student.stuid in (select has_pet.stuid from has_pet join pets on has_pet.petid = pets.petid where pets.pettype = 'cat')
#   fix1: select distinct s.major, s.age from student s where s.stuid not in ( select hp.stuid from has_pet hp join pets p on hp.petid = p.petid where p.pettype = 'cat' )
#   fix2: select distinct s.major, s.age from student s where not exists ( select 1 from has_pet hp join pets p on hp.petid = p.petid where hp.stuid = s.stuid and p.pettype = 'cat' )
#   fix3: select distinct s.major, s.age from student s where not exists ( select 1 from has_pet hp join pets p on hp.petid = p.petid where hp.stuid = s.stuid and p.pettype = 'cat' )
#   gold: select major, age from student where stuid not in (select t1.stuid from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'cat')
#   EM=10/62 EA=57/62 VS=62/62
#
# [63/100] What major is every student who does not own a cat as a pet, and also how old are they?
#   -> select distinct s.stuid, s.major, s.age from student s join has_pet hp on s.stuid = hp.stuid join pets p on hp.petid = p.petid where p.pettype != 'cat'
#   fix1: select distinct s.stuid, s.major, s.age from student s where s.stuid not in ( select hp.stuid from has_pet hp join pets p on hp.petid = p.petid where p.pettype = 'cat' )
#   fix2: select distinct s.major, s.age from student s where s.stuid not in (select hp.stuid from has_pet hp join pets p on hp.petid = p.petid where p.pettype = 'cat')
#   fix3: select distinct s.major, s.age from student s left join has_pet hp on s.stuid = hp.stuid left join pets p on hp.petid = p.petid and p.pettype = 'cat' where p.petid is null
#   gold: select major, age from student where stuid not in (select t1.stuid from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'cat')
#   EM=10/63 EA=57/63 VS=63/63
#
# [64/100] Find the id of students who do not have a cat pet.
#   -> select student.stuid from student left join has_pet on student.stuid = has_pet.stuid left join pets on has_pet.petid = pets.petid where pets.pettype = 'cat' or pets.pettype is null group by student.stuid having count(case when pets.pettype = 'cat' then 1 end) = 0
#   fix1: select student.stuid from student left join has_pet on student.stuid = has_pet.stuid left join pets on has_pet.petid = pets.petid group by student.stuid having sum(case when pets.pettype = 'cat' then 1 else 0 end) = 0
#   gold: select stuid from student except select t1.stuid from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'cat'
#   EM=10/64 EA=58/64 VS=64/64
#
# [65/100] What are the ids of the students who do not own cats as pets?
#   -> select stuid from student except select student.stuid from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where pets.pettype = 'cat'
#   gold: select stuid from student except select t1.stuid from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'cat'
#   EM=10/65 EA=59/65 VS=65/65
#
# [66/100] Find the first name and age of students who have a dog but do not have a cat as a pet.
#   -> select student.fname, student.age from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where pets.pettype = 'dog' except select student.fname, student.age from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where pets.pettype = 'cat'
#   fix1: select s.fname, s.age from student s where s.stuid in ( select distinct hp.stuid from has_pet hp join pets p on hp.petid = p.petid where p.pettype = 'dog' ) and s.stuid not in ( select distinct hp.stuid from has_pet hp join pets p on hp.petid = p.petid where p.pettype = 'cat' )
#   fix2: select s.fname, s.age from student s where s.stuid in ( select hp.stuid from has_pet hp join pets p on hp.petid = p.petid where p.pettype = 'dog' ) and not exists ( select 1 from has_pet hp2 join pets p2 on hp2.petid = p2.petid where hp2.stuid = s.stuid and p2.pettype = 'cat' )
#   fix3: select s.fname, s.age from student s where exists (select 1 from has_pet hp join pets p on hp.petid = p.petid where hp.stuid = s.stuid and p.pettype = 'dog') and not exists (select 1 from has_pet hp2 join pets p2 on hp2.petid = p2.petid where hp2.stuid = s.stuid and p2.pettype = 'cat')
#   gold: select t1.fname, t1.age from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'dog' and t1.stuid not in (select t1.stuid from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'cat')
#   EM=10/66 EA=59/66 VS=66/66
#
# [67/100] What is the first name of every student who has a dog but does not have a cat?
#   -> select student.fname from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where pets.pettype = 'dog' except select student.fname from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where pets.pettype = 'cat'
#   fix1: select distinct s.fname from student s where exists ( select 1 from has_pet hp join pets p on hp.petid = p.petid where hp.stuid = s.stuid and p.pettype = 'dog' ) and not exists ( select 1 from has_pet hp join pets p on hp.petid = p.petid where hp.stuid = s.stuid and p.pettype = 'cat' )
#   fix2: select s.fname from student s where exists (select 1 from has_pet hp join pets p on hp.petid = p.petid where hp.stuid = s.stuid and p.pettype = 'dog') and not exists (select 1 from has_pet hp join pets p on hp.petid = p.petid where hp.stuid = s.stuid and p.pettype = 'cat')
#   fix3: select s.fname from student s where exists (select 1 from has_pet hp1 join pets p1 on hp1.petid = p1.petid where hp1.stuid = s.stuid and p1.pettype = 'dog') and not exists (select 1 from has_pet hp2 join pets p2 on hp2.petid = p2.petid where hp2.stuid = s.stuid and p2.pettype = 'cat')
#   gold: select t1.fname, t1.age from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'dog' and t1.stuid not in (select t1.stuid from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'cat')
#   EM=10/67 EA=59/67 VS=67/67
#
# [68/100] Find the type and weight of the youngest pet.
#   -> select pets.pettype, pets.weight from pets join has_pet on pets.petid = has_pet.petid join student on has_pet.stuid = student.stuid where pets.pet_age = (select min(pet_age) from pets)
#   gold: select pettype, weight from pets order by pet_age limit 1
#   EM=10/68 EA=60/68 VS=68/68
#
# [69/100] What type of pet is the youngest animal, and how much does it weigh?
#   -> select pets.pettype, pets.weight from pets join has_pet on pets.petid = has_pet.petid join student on has_pet.stuid = student.stuid where pets.pet_age = (select min(pet_age) from pets)
#   gold: select pettype, weight from pets order by pet_age limit 1
#   EM=10/69 EA=61/69 VS=69/69
#
# [70/100] Find the id and weight of all pets whose age is older than 1.
#   -> select petid, weight from pets where pet_age > 1
#   gold: select petid, weight from pets where pet_age > 1
#   EM=11/70 EA=62/70 VS=70/70
#
# [71/100] What is the id and weight of every pet who is older than 1?
#   -> select petid, weight from pets where pet_age > 1
#   gold: select petid, weight from pets where pet_age > 1
#   EM=12/71 EA=63/71 VS=71/71
#
# [72/100] Find the average and maximum age for each type of pet.
#   -> select pettype, avg(pet_age) as avg_age, max(pet_age) as max_age from pets group by pettype
#   gold: select avg(pet_age), max(pet_age), pettype from pets group by pettype
#   EM=12/72 EA=64/72 VS=72/72
#
# [73/100] What is the average and maximum age for each pet type?
#   -> select pets.pettype, avg(pets.pet_age) as average_age, max(pets.pet_age) as maximum_age from pets group by pets.pettype
#   gold: select avg(pet_age), max(pet_age), pettype from pets group by pettype
#   EM=12/73 EA=65/73 VS=73/73
#
# [74/100] Find the average weight for each pet type.
#   -> select pettype, avg(weight) from pets group by pettype
#   gold: select avg(weight), pettype from pets group by pettype
#   EM=12/74 EA=66/74 VS=74/74
#
# [75/100] What is the average weight for each type of pet?
#   -> select pettype, avg(weight) as average_weight from pets group by pettype
#   gold: select avg(weight), pettype from pets group by pettype
#   EM=12/75 EA=67/75 VS=75/75
#
# [76/100] Find the first name and age of students who have a pet.
#   -> select student.fname, student.age from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid
#   fix1: select distinct student.fname, student.age from student join has_pet on student.stuid = has_pet.stuid
#   gold: select distinct t1.fname, t1.age from student as t1 join has_pet as t2 on t1.stuid = t2.stuid
#   EM=12/76 EA=68/76 VS=76/76
#
# [77/100] What are the different first names and ages of the students who do have pets?
#   -> select distinct student.fname, student.age from student join has_pet on student.stuid = has_pet.stuid where has_pet.petid is not null
#   gold: select distinct t1.fname, t1.age from student as t1 join has_pet as t2 on t1.stuid = t2.stuid
#   EM=12/77 EA=69/77 VS=77/77
#
# [78/100] Find the id of the pet owned by student whose last name is ‘Smith’.
#   -> select pets.petid from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where student.lname = 'smith'
#   gold: select t2.petid from student as t1 join has_pet as t2 on t1.stuid = t2.stuid where t1.lname = 'smith'
#   EM=12/78 EA=70/78 VS=78/78
#
# [79/100] What is the id of the pet owned by the student whose last name is 'Smith'?
#   -> select pets.petid from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where student.lname = 'smith'
#   gold: select t2.petid from student as t1 join has_pet as t2 on t1.stuid = t2.stuid where t1.lname = 'smith'
#   EM=12/79 EA=71/79 VS=79/79
#
# [80/100] Find the number of pets for each student who has any pet and student id.
#   -> select student.stuid, count(has_pet.petid) as num_pets from student join has_pet on student.stuid = has_pet.stuid group by student.stuid having count(has_pet.petid) > 0
#   gold: select count(*), t1.stuid from student as t1 join has_pet as t2 on t1.stuid = t2.stuid group by t1.stuid
#   EM=12/80 EA=72/80 VS=80/80
#
# [81/100] For students who have pets , how many pets does each student have ? list their ids instead of names .
#   -> select student.stuid, count(pets.petid) as pet_count from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid group by student.stuid
#   gold: select count(*), t1.stuid from student as t1 join has_pet as t2 on t1.stuid = t2.stuid group by t1.stuid
#   EM=12/81 EA=73/81 VS=81/81
#
# [82/100] Find the first name and gender of student who have more than one pet.
#   -> select student.fname, student.sex from student join has_pet on student.stuid = has_pet.stuid group by student.stuid, student.fname, student.sex having count(has_pet.petid) > 1
#   gold: select t1.fname, t1.sex from student as t1 join has_pet as t2 on t1.stuid = t2.stuid group by t1.stuid having count(*) > 1
#   EM=12/82 EA=74/82 VS=82/82
#
# [83/100] What is the first name and gender of the all the students who have more than one pet?
#   -> select student.fname, student.sex from student join has_pet on student.stuid = has_pet.stuid group by student.stuid, student.fname, student.sex having count(has_pet.petid) > 1
#   gold: select t1.fname, t1.sex from student as t1 join has_pet as t2 on t1.stuid = t2.stuid group by t1.stuid having count(*) > 1
#   EM=12/83 EA=75/83 VS=83/83
#
# [84/100] Find the last name of the student who has a cat that is age 3.
#   -> select student.lname from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where pets.pettype = 'cat' and pets.pet_age = 3
#   gold: select t1.lname from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pet_age = 3 and t3.pettype = 'cat'
#   EM=12/84 EA=76/84 VS=84/84
#
# [85/100] What is the last name of the student who has a cat that is 3 years old?
#   -> select student.lname from student join has_pet on student.stuid = has_pet.stuid join pets on has_pet.petid = pets.petid where pets.pettype = 'cat' and pets.pet_age = 3
#   gold: select t1.lname from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pet_age = 3 and t3.pettype = 'cat'
#   EM=12/85 EA=77/85 VS=85/85
#
# [86/100] Find the average age of students who do not have any pet .
#   -> select avg(student.age) from student left join has_pet on student.stuid = has_pet.stuid where has_pet.stuid is null
#   gold: select avg(age) from student where stuid not in (select stuid from has_pet)
#   EM=12/86 EA=78/86 VS=86/86
#
# [87/100] What is the average age for all students who do not own any pets ?
#   -> select avg(student.age) from student where student.stuid not in (select has_pet.stuid from has_pet)
#   gold: select avg(age) from student where stuid not in (select stuid from has_pet)
#   EM=12/87 EA=79/87 VS=87/87
#
# [88/100] How many continents are there?
#   -> select count(distinct continents.continent) from continents
#   gold: select count(*) from continents
#   EM=12/88 EA=80/88 VS=88/88
#
# [89/100] What is the number of continents?
#   -> select count(distinct continents.continent) from continents
#   gold: select count(*) from continents
#   EM=12/89 EA=81/89 VS=89/89
#
# [90/100] How many countries does each continent have? List the continent id, continent name and the number of countries.
#   -> select continents.contid, continents.continent, count(countries.countryid) from continents join countries on continents.contid = countries.continent group by continents.contid, continents.continent
#   gold: select t1.contid, t1.continent, count(*) from continents as t1 join countries as t2 on t1.contid = t2.continent group by t1.contid
#   EM=12/90 EA=82/90 VS=90/90
#
# [91/100] For each continent, list its id, name, and how many countries it has?
#   -> select c.contid, c.continent, count(co.countryid) as country_count from continents c join countries co on c.contid = co.continent group by c.contid, c.continent
#   gold: select t1.contid, t1.continent, count(*) from continents as t1 join countries as t2 on t1.contid = t2.continent group by t1.contid
#   EM=12/91 EA=83/91 VS=91/91
#
# [92/100] How many countries are listed?
#   -> select count(distinct countryid) from countries
#   gold: select count(*) from countries
#   EM=12/92 EA=84/92 VS=92/92
#
# [93/100] How many countries exist?
#   -> select count(distinct countryid) from countries
#   gold: select count(*) from countries
#   EM=12/93 EA=85/93 VS=93/93
#
# [94/100] How many models does each car maker produce? List maker full name, id and the number.
#   -> select car_makers.fullname, car_makers.id, count(model_list.modelid) as numberofmodels from car_makers join model_list on car_makers.id = model_list.maker group by car_makers.id, car_makers.fullname
#   gold: select t1.fullname, t1.id, count(*) from car_makers as t1 join model_list as t2 on t1.id = t2.maker group by t1.id
#   EM=12/94 EA=86/94 VS=94/94
#
# [95/100] What is the full name of each car maker, along with its id and how many models it produces?
#   -> select car_makers.id, car_makers.fullname, count(model_list.modelid) from car_makers join model_list on car_makers.id = model_list.maker group by car_makers.id, car_makers.fullname
#   gold: select t1.fullname, t1.id, count(*) from car_makers as t1 join model_list as t2 on t1.id = t2.maker group by t1.id
#   EM=12/95 EA=87/95 VS=95/95
#
# [96/100] Which model of the car has the minimum horsepower?
#   -> select model_list.model from cars_data join car_names on cars_data.id = car_names.makeid join model_list on car_names.model = model_list.model where cars_data.horsepower = (select min(horsepower) from cars_data)
#   fix1: select model_list.model from cars_data join car_names on cars_data.id = car_names.makeid join model_list on car_names.model = model_list.model where cars_data.horsepower = (select min(horsepower) from cars_data) limit 1
#   gold: select t1.model from car_names as t1 join cars_data as t2 on t1.makeid = t2.id order by t2.horsepower asc limit 1
#   EM=12/96 EA=88/96 VS=96/96
#
# [97/100] What is the model of the car with the smallest amount of horsepower?
#   -> select model_list.model from cars_data join car_names on cars_data.id = car_names.makeid join model_list on car_names.model = model_list.model where cars_data.horsepower = (select min(horsepower) from cars_data)
#   fix1: select model_list.model from cars_data join car_names on cars_data.id = car_names.makeid join model_list on car_names.model = model_list.modelid where cars_data.horsepower = (select min(horsepower) from cars_data)
#   fix2: select model_list.model from cars_data join car_names on cars_data.id = car_names.makeid join model_list on car_names.model = model_list.model where cars_data.horsepower = (select min(horsepower) from cars_data)
#   fix3: select model_list.model from cars_data join car_names on cars_data.id = car_names.makeid join model_list on car_names.model = model_list.model where cars_data.horsepower = (select min(horsepower) from cars_data)
#   gold: select t1.model from car_names as t1 join cars_data as t2 on t1.makeid = t2.id order by t2.horsepower asc limit 1
#   EM=12/97 EA=88/97 VS=97/97
#
# [98/100] Find the model of the car whose weight is below the average weight.
#   -> select model_list.model from cars_data join car_names on cars_data.id = car_names.makeid join model_list on car_names.model = model_list.model where cars_data.weight < (select avg(weight) from cars_data)
#   fix1: select model_list.model from model_list join car_names on model_list.model = car_names.model join cars_data on car_names.makeid = cars_data.id group by model_list.modelid, model_list.model having avg(cars_data.weight) < (select avg(weight) from cars_data)
#   fix2: select distinct model_list.model from model_list join car_names on model_list.model = car_names.model join cars_data on car_names.makeid = cars_data.id where cars_data.weight < (select avg(weight) from cars_data)
#   fix3: select model_list.model from model_list join car_names on model_list.model = car_names.model join cars_data on car_names.makeid = cars_data.id where cars_data.weight < (select avg(weight) from cars_data)
#   gold: select t1.model from car_names as t1 join cars_data as t2 on t1.makeid = t2.id where t2.weight < (select avg(weight) from cars_data)
#   EM=12/98 EA=88/98 VS=98/98
#
# [99/100] What is the model for the car with a weight smaller than the average?
#   -> select distinct model_list.model from cars_data join car_names on cars_data.id = car_names.makeid join model_list on car_names.model = model_list.model where cars_data.weight < (select avg(weight) from cars_data)
#   fix1: select distinct model_list.model from cars_data join car_names on cars_data.id = car_names.makeid join model_list on car_names.model = model_list.model where cars_data.weight < (select avg(weight) from cars_data)
#   fix2: select distinct model_list.model from cars_data join car_names on cars_data.id = car_names.makeid join model_list on model_list.modelid = car_names.model where cars_data.weight < (select avg(weight) from cars_data)
#   fix3: select distinct model_list.model from cars_data join car_names on cars_data.id = car_names.makeid join model_list on model_list.model = car_names.model where cars_data.weight < (select avg(weight) from cars_data)
#   gold: select t1.model from car_names as t1 join cars_data as t2 on t1.makeid = t2.id where t2.weight < (select avg(weight) from cars_data)
#   EM=12/99 EA=88/99 VS=99/99
#
# [100/100] Find the name of the makers that produced some cars in the year of 1970?
#   -> select distinct car_makers.maker from car_makers join model_list on car_makers.id = model_list.maker join car_names on model_list.model = car_names.model join cars_data on car_names.makeid = cars_data.id where cars_data.year = 1970
#   gold: select distinct t1.maker from car_makers as t1 join model_list as t2 on t1.id = t2.maker join car_names as t3 on t2.model = t3.model join cars_data as t4 on t3.makeid = t4.id where t4.year = '1970'
#   EM=12/100 EA=89/100 VS=100/100
#
# === no_schemalink === {"total": 100, "em": 12, "vs": 100, "ea": 89, "em%": 0.12, "vs%": 1.0, "ea%": 0.89}

# %%
r5 = run(gen_direct, "baseline", correct=False)
# Out:
# [1/100] How many singers do we have?
#   -> select count(*) from singer
#   gold: select count(*) from singer
#   EM=1/1 EA=1/1 VS=1/1
#
# [2/100] What is the total number of singers?
#   -> select count(*) from singer
#   gold: select count(*) from singer
#   EM=2/2 EA=2/2 VS=2/2
#
# [3/100] Show name, country, age for all singers ordered by age from the oldest to the youngest.
#   -> select name, country, age from singer order by age desc
#   gold: select name, country, age from singer order by age desc
#   EM=3/3 EA=3/3 VS=3/3
#
# [4/100] What are the names, countries, and ages for every singer in descending order of age?
#   -> select name, country, age from singer order by age desc
#   gold: select name, country, age from singer order by age desc
#   EM=4/4 EA=4/4 VS=4/4
#
# [5/100] What is the average, minimum, and maximum age of all singers from France?
#   -> select avg(age) as average_age, min(age) as minimum_age, max(age) as maximum_age from singer where country = 'france'
#   gold: select avg(age), min(age), max(age) from singer where country = 'france'
#   EM=4/5 EA=5/5 VS=5/5
#
# [6/100] What is the average, minimum, and maximum age for all French singers?
#   -> select avg(age) as average_age, min(age) as minimum_age, max(age) as maximum_age from singer where country = 'french'
#   gold: select avg(age), min(age), max(age) from singer where country = 'france'
#   EM=4/6 EA=6/6 VS=6/6
#
# [7/100] Show the name and the release year of the song by the youngest singer.
#   -> select s.song_name, s.song_release_year from singer s where s.age = (select min(age) from singer)
#   gold: select song_name, song_release_year from singer order by age limit 1
#   EM=4/7 EA=7/7 VS=7/7
#
# [8/100] What are the names and release years for all the songs of the youngest singer?
#   -> select s.song_name, s.song_release_year from singer s where s.age = (select min(age) from singer)
#   gold: select song_name, song_release_year from singer order by age limit 1
#   EM=4/8 EA=8/8 VS=8/8
#
# [9/100] What are all distinct countries where singers above age 20 are from?
#   -> select distinct country from singer where age > 20
#   gold: select distinct country from singer where age > 20
#   EM=5/9 EA=9/9 VS=9/9
#
# [10/100] What are  the different countries with singers above age 20?
#   -> select distinct country from singer where age > 20
#   gold: select distinct country from singer where age > 20
#   EM=6/10 EA=10/10 VS=10/10
#
# [11/100] Show all countries and the number of singers in each country.
#   -> select country, count(*) as singer_count from singer group by country
#   gold: select country, count(*) from singer group by country
#   EM=6/11 EA=11/11 VS=11/11
#
# [12/100] How many singers are from each country?
#   -> select country, count(*) as singer_count from singer group by country
#   gold: select country, count(*) from singer group by country
#   EM=6/12 EA=12/12 VS=12/12
#
# [13/100] List all song names by singers above the average age.
#   -> select distinct s.song_name from singer s where s.age > (select avg(age) from singer)
#   gold: select song_name from singer where age > (select avg(age) from singer)
#   EM=6/13 EA=13/13 VS=13/13
#
# [14/100] What are all the song names by singers who are older than average?
#   -> select distinct s.song_name from singer s where s.age > ( select avg(age) from singer where age is not null )
#   gold: select song_name from singer where age > (select avg(age) from singer)
#   EM=6/14 EA=14/14 VS=14/14
#
# [15/100] Show location and name for all stadiums with a capacity between 5000 and 10000.
#   -> select location, name from stadium where capacity between 5000 and 10000
#   gold: select location, name from stadium where capacity between 5000 and 10000
#   EM=7/15 EA=15/15 VS=15/15
#
# [16/100] What are the locations and names of all stations with capacity between 5000 and 10000?
#   -> select location, name from stadium where capacity between 5000 and 10000
#   gold: select location, name from stadium where capacity between 5000 and 10000
#   EM=8/16 EA=16/16 VS=16/16
#
# [17/100] What is the maximum capacity and the average of all stadiums ?
#   -> select max(capacity) as max_capacity, avg(capacity) as avg_capacity from stadium
#   gold: select max(capacity), average from stadium
#   EM=8/17 EA=16/17 VS=17/17
#
# [18/100] What is the average and maximum capacities for all stadiums ?
#   -> select avg(capacity) as average_capacity, max(capacity) as maximum_capacity from stadium
#   gold: select avg(capacity), max(capacity) from stadium
#   EM=8/18 EA=17/18 VS=18/18
#
# [19/100] What is the name and capacity for the stadium with highest average attendance?
#   -> select name, capacity from stadium where highest = (select max(highest) from stadium)
#   gold: select name, capacity from stadium order by average desc limit 1
#   EM=8/19 EA=18/19 VS=19/19
#
# [20/100] What is the name and capacity for the stadium with the highest average attendance?
#   -> select name, capacity from stadium where average = (select max(average) from stadium)
#   gold: select name, capacity from stadium order by average desc limit 1
#   EM=8/20 EA=19/20 VS=20/20
#
# [21/100] How many concerts are there in year 2014 or 2015?
#   -> select count(*) from concert where year in (2014, 2015)
#   gold: select count(*) from concert where year = 2014 or year = 2015
#   EM=8/21 EA=20/21 VS=21/21
#
# [22/100] How many concerts occurred in 2014 or 2015?
#   -> select count(*) from concert where year in (2014, 2015)
#   gold: select count(*) from concert where year = 2014 or year = 2015
#   EM=8/22 EA=21/22 VS=22/22
#
# [23/100] Show the stadium name and the number of concerts in each stadium.
#   -> select s.name as stadium_name, count(c.concert_id) as number_of_concerts from stadium s left join concert c on s.stadium_id = c.stadium_id group by s.stadium_id, s.name
#   gold: select t2.name, count(*) from concert as t1 join stadium as t2 on t1.stadium_id = t2.stadium_id group by t1.stadium_id
#   EM=8/23 EA=21/23 VS=23/23
#
# [24/100] For each stadium, how many concerts play there?
#   -> select s.stadium_id, s.name, count(c.concert_id) as concert_count from stadium s left join concert c on s.stadium_id = c.stadium_id group by s.stadium_id, s.name
#   gold: select t2.name, count(*) from concert as t1 join stadium as t2 on t1.stadium_id = t2.stadium_id group by t1.stadium_id
#   EM=8/24 EA=21/24 VS=24/24
#
# [25/100] Show the stadium name and capacity with most number of concerts in year 2014 or after.
#   -> select s.name, s.capacity from stadium s join concert c on s.stadium_id = c.stadium_id where c.year >= 2014 group by s.stadium_id order by count(*) desc limit 1
#   gold: select t2.name, t2.capacity from concert as t1 join stadium as t2 on t1.stadium_id = t2.stadium_id where t1.year >= 2014 group by t2.stadium_id order by count(*) desc limit 1
#   EM=8/25 EA=22/25 VS=25/25
#
# [26/100] What is the name and capacity of the stadium with the most concerts after 2013 ?
#   -> select s.name, s.capacity from stadium s join concert c on s.stadium_id = c.stadium_id where c.year > 2013 group by s.stadium_id order by count(*) desc limit 1
#   gold: select t2.name, t2.capacity from concert as t1 join stadium as t2 on t1.stadium_id = t2.stadium_id where t1.year > 2013 group by t2.stadium_id order by count(*) desc limit 1
#   EM=8/26 EA=23/26 VS=26/26
#
# [27/100] Which year has most number of concerts?
#   -> select year, count(*) as concert_count from concert group by year order by concert_count desc limit 1
#   gold: select year from concert group by year order by count(*) desc limit 1
#   EM=8/27 EA=23/27 VS=27/27
#
# [28/100] What is the year that had the most concerts?
#   -> select year from concert group by year order by count(*) desc limit 1
#   gold: select year from concert group by year order by count(*) desc limit 1
#   EM=9/28 EA=24/28 VS=28/28
#
# [29/100] Show the stadium names without any concert.
#   -> select s.name from stadium s left join concert c on s.stadium_id = c.stadium_id where c.concert_id is null
#   gold: select name from stadium where stadium_id not in (select stadium_id from concert)
#   EM=9/29 EA=25/29 VS=29/29
#
# [30/100] What are the names of the stadiums without any concerts?
#   -> select s.name from stadium s left join concert c on s.stadium_id = c.stadium_id where c.stadium_id is null
#   gold: select name from stadium where stadium_id not in (select stadium_id from concert)
#   EM=9/30 EA=26/30 VS=30/30
#
# [31/100] Show countries where a singer above age 40 and a singer below 30 are from.
#   -> select distinct s1.country from singer s1 join singer s2 on s1.country = s2.country where s1.age > 40 and s2.age < 30
#   gold: select country from singer where age > 40 intersect select country from singer where age < 30
#   EM=9/31 EA=27/31 VS=31/31
#
# [32/100] Show names for all stadiums except for stadiums having a concert in year 2014.
#   -> select s.name from stadium s where s.stadium_id not in ( select distinct c.stadium_id from concert c where c.year = 2014 )
#   gold: select name from stadium except select t2.name from concert as t1 join stadium as t2 on t1.stadium_id = t2.stadium_id where t1.year = 2014
#   EM=9/32 EA=28/32 VS=32/32
#
# [33/100] What are the names of all stadiums that did not have a concert in 2014?
#   -> select s.name from stadium s where s.stadium_id not in ( select distinct c.stadium_id from concert c where c.year = 2014 )
#   gold: select name from stadium except select t2.name from concert as t1 join stadium as t2 on t1.stadium_id = t2.stadium_id where t1.year = 2014
#   EM=9/33 EA=29/33 VS=33/33
#
# [34/100] Show the name and theme for all concerts and the number of singers in each concert.
#   -> select c.concert_name, c.theme, count(sic.singer_id) as number_of_singers from concert c left join singer_in_concert sic on c.concert_id = sic.concert_id group by c.concert_id, c.concert_name, c.theme
#   gold: select t2.concert_name, t2.theme, count(*) from singer_in_concert as t1 join concert as t2 on t1.concert_id = t2.concert_id group by t2.concert_id
#   EM=9/34 EA=30/34 VS=34/34
#
# [35/100] What are the names , themes , and number of singers for every concert ?
#   -> select c.concert_name, c.theme, count(sic.singer_id) as number_of_singers from concert c left join singer_in_concert sic on c.concert_id = sic.concert_id group by c.concert_id, c.concert_name, c.theme
#   gold: select t2.concert_name, t2.theme, count(*) from singer_in_concert as t1 join concert as t2 on t1.concert_id = t2.concert_id group by t2.concert_id
#   EM=9/35 EA=31/35 VS=35/35
#
# [36/100] List singer names and number of concerts for each singer.
#   -> select s.name, count(sic.concert_id) as number_of_concerts from singer s left join singer_in_concert sic on s.singer_id = sic.singer_id group by s.singer_id, s.name
#   gold: select t2.name, count(*) from singer_in_concert as t1 join singer as t2 on t1.singer_id = t2.singer_id group by t2.singer_id
#   EM=9/36 EA=31/36 VS=36/36
#
# [37/100] What are the names of the singers and number of concerts for each person?
#   -> select s.name, count(sic.concert_id) as number_of_concerts from singer s left join singer_in_concert sic on s.singer_id = sic.singer_id group by s.singer_id, s.name
#   gold: select t2.name, count(*) from singer_in_concert as t1 join singer as t2 on t1.singer_id = t2.singer_id group by t2.singer_id
#   EM=9/37 EA=31/37 VS=37/37
#
# [38/100] List all singer names in concerts in year 2014.
#   -> select distinct s.name from singer s join singer_in_concert sic on s.singer_id = sic.singer_id join concert c on sic.concert_id = c.concert_id where c.year = 2014
#   gold: select t2.name from singer_in_concert as t1 join singer as t2 on t1.singer_id = t2.singer_id join concert as t3 on t1.concert_id = t3.concert_id where t3.year = 2014
#   EM=9/38 EA=31/38 VS=38/38
#
# [39/100] What are the names of the singers who performed in a concert in 2014?
#   -> select distinct s.name from singer s join singer_in_concert sic on s.singer_id = sic.singer_id join concert c on sic.concert_id = c.concert_id where c.year = 2014
#   gold: select t2.name from singer_in_concert as t1 join singer as t2 on t1.singer_id = t2.singer_id join concert as t3 on t1.concert_id = t3.concert_id where t3.year = 2014
#   EM=9/39 EA=31/39 VS=39/39
#
# [40/100] what is the name and nation of the singer who have a song having 'Hey' in its name?
#   -> select name, country from singer where song_name like '%hey%'
#   gold: select name, country from singer where song_name like '%hey%'
#   EM=10/40 EA=32/40 VS=40/40
#
# [41/100] What is the name and country of origin of every singer who has a song with the word 'Hey' in its title?
#   -> select name, country from singer where song_name like '%hey%'
#   gold: select name, country from singer where song_name like '%hey%'
#   EM=11/41 EA=33/41 VS=41/41
#
# [42/100] Find the name and location of the stadiums which some concerts happened in the years of both 2014 and 2015.
#   -> select distinct s.name, s.location from stadium s join concert c on s.stadium_id = c.stadium_id where c.year = 2014 and s.stadium_id in ( select stadium_id from concert where year = 2015 )
#   gold: select t2.name, t2.location from concert as t1 join stadium as t2 on t1.stadium_id = t2.stadium_id where t1.year = 2014 intersect select t2.name, t2.location from concert as t1 join stadium as t2 on t1.stadium_id = t2.stadium_id where t1.year = 2015
#   EM=11/42 EA=34/42 VS=42/42
#
# [43/100] What are the names and locations of the stadiums that had concerts that occurred in both 2014 and 2015?
#   -> select distinct s.name, s.location from stadium s join concert c on s.stadium_id = c.stadium_id where c.year = 2014 and s.stadium_id in ( select stadium_id from concert where year = 2015 )
#   gold: select t2.name, t2.location from concert as t1 join stadium as t2 on t1.stadium_id = t2.stadium_id where t1.year = 2014 intersect select t2.name, t2.location from concert as t1 join stadium as t2 on t1.stadium_id = t2.stadium_id where t1.year = 2015
#   EM=11/43 EA=35/43 VS=43/43
#
# [44/100] Find the number of concerts happened in the stadium with the highest capacity .
#   -> select count(*) as number_of_concerts from concert c where c.stadium_id = ( select stadium_id from stadium order by capacity desc limit 1 )
#   gold: select count(*) from concert where stadium_id = (select stadium_id from stadium order by capacity desc limit 1)
#   EM=11/44 EA=36/44 VS=44/44
#
# [45/100] What are the number of concerts that occurred in the stadium with the largest capacity ?
#   -> select count(*) as number_of_concerts from concert where stadium_id = ( select stadium_id from stadium order by capacity desc limit 1 )
#   gold: select count(*) from concert where stadium_id = (select stadium_id from stadium order by capacity desc limit 1)
#   EM=11/45 EA=37/45 VS=45/45
#
# [46/100] Find the number of pets whose weight is heavier than 10.
#   -> select count(*) from pets where weight > 10
#   gold: select count(*) from pets where weight > 10
#   EM=12/46 EA=38/46 VS=46/46
#
# [47/100] How many pets have a greater weight than 10?
#   -> select count(*) from pets where weight > 10
#   gold: select count(*) from pets where weight > 10
#   EM=13/47 EA=39/47 VS=47/47
#
# [48/100] Find the weight of the youngest dog.
#   -> select weight from pets where pettype = 'dog' order by pet_age asc limit 1
#   gold: select weight from pets order by pet_age limit 1
#   EM=13/48 EA=40/48 VS=48/48
#
# [49/100] How much does the youngest dog weigh?
#   -> select weight from pets where pettype = 'dog' order by pet_age asc limit 1
#   gold: select weight from pets order by pet_age limit 1
#   EM=13/49 EA=41/49 VS=49/49
#
# [50/100] Find the maximum weight for each type of pet. List the maximum weight and pet type.
#   -> select pettype, max(weight) as max_weight from pets group by pettype
#   gold: select max(weight), pettype from pets group by pettype
#   EM=13/50 EA=42/50 VS=50/50
#
# [51/100] List the maximum weight and type for each type of pet.
#   -> select pettype, max(weight) as max_weight from pets group by pettype
#   gold: select max(weight), pettype from pets group by pettype
#   EM=13/51 EA=43/51 VS=51/51
#
# [52/100] Find number of pets owned by students who are older than 20.
#   -> select count(*) as num_pets from has_pet hp join student s on hp.stuid = s.stuid where s.age > 20
#   gold: select count(*) from student as t1 join has_pet as t2 on t1.stuid = t2.stuid where t1.age > 20
#   EM=13/52 EA=44/52 VS=52/52
#
# [53/100] How many pets are owned by students that have an age greater than 20?
#   -> select count(*) as pet_count from has_pet hp join student s on hp.stuid = s.stuid where s.age > 20
#   gold: select count(*) from student as t1 join has_pet as t2 on t1.stuid = t2.stuid where t1.age > 20
#   EM=13/53 EA=45/53 VS=53/53
#
# [54/100] Find the number of dog pets that are raised by female students (with sex F).
#   -> select count(*) as num_dog_pets from student s join has_pet hp on s.stuid = hp.stuid join pets p on hp.petid = p.petid where s.sex = 'f' and p.pettype = 'dog'
#   gold: select count(*) from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t2.petid = t3.petid where t1.sex = 'f' and t3.pettype = 'dog'
#   EM=13/54 EA=46/54 VS=54/54
#
# [55/100] How many dog pets are raised by female students?
#   -> select count(*) from pets p join has_pet hp on p.petid = hp.petid join student s on hp.stuid = s.stuid where p.pettype = 'dog' and s.sex = 'f'
#   gold: select count(*) from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t2.petid = t3.petid where t1.sex = 'f' and t3.pettype = 'dog'
#   EM=13/55 EA=47/55 VS=55/55
#
# [56/100] Find the number of distinct type of pets.
#   -> select count(distinct pettype) from pets
#   gold: select count(distinct pettype) from pets
#   EM=14/56 EA=48/56 VS=56/56
#
# [57/100] How many different types of pet are there?
#   -> select count(distinct pettype) from pets
#   gold: select count(distinct pettype) from pets
#   EM=15/57 EA=49/57 VS=57/57
#
# [58/100] Find the first name of students who have cat or dog pet.
#   -> select distinct s.fname from student s join has_pet hp on s.stuid = hp.stuid join pets p on hp.petid = p.petid where p.pettype in ('cat', 'dog')
#   gold: select distinct t1.fname from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'cat' or t3.pettype = 'dog'
#   EM=15/58 EA=50/58 VS=58/58
#
# [59/100] What are the first names of every student who has a cat or dog as a pet?
#   -> select distinct s.fname from student s join has_pet hp on s.stuid = hp.stuid join pets p on hp.petid = p.petid where p.pettype in ('cat', 'dog')
#   gold: select distinct t1.fname from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'cat' or t3.pettype = 'dog'
#   EM=15/59 EA=51/59 VS=59/59
#
# [60/100] Find the first name of students who have both cat and dog pets .
#   -> select distinct s.fname from student s join has_pet hp1 on s.stuid = hp1.stuid join pets p1 on hp1.petid = p1.petid and p1.pettype = 'cat' join has_pet hp2 on s.stuid = hp2.stuid join pets p2 on hp2.petid = p2.petid and p2.pettype = 'dog'
#   gold: select t1.fname from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'cat' intersect select t1.fname from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'dog'
#   EM=15/60 EA=52/60 VS=60/60
#
# [61/100] What are the students' first names who have both cats and dogs as pets?
#   -> select distinct s.fname from student s join has_pet hp1 on s.stuid = hp1.stuid join pets p1 on hp1.petid = p1.petid and p1.pettype = 'cat' join has_pet hp2 on s.stuid = hp2.stuid join pets p2 on hp2.petid = p2.petid and p2.pettype = 'dog'
#   gold: select t1.fname from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'cat' intersect select t1.fname from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'dog'
#   EM=15/61 EA=53/61 VS=61/61
#
# [62/100] Find the major and age of students who do not have a cat pet.
#   -> select distinct s.major, s.age from student s where s.stuid not in ( select hp.stuid from has_pet hp join pets p on hp.petid = p.petid where p.pettype = 'cat' )
#   gold: select major, age from student where stuid not in (select t1.stuid from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'cat')
#   EM=15/62 EA=53/62 VS=62/62
#
# [63/100] What major is every student who does not own a cat as a pet, and also how old are they?
#   -> select s.major, s.age from student s where s.stuid not in ( select hp.stuid from has_pet hp join pets p on hp.petid = p.petid where p.pettype = 'cat' )
#   gold: select major, age from student where stuid not in (select t1.stuid from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'cat')
#   EM=15/63 EA=54/63 VS=63/63
#
# [64/100] Find the id of students who do not have a cat pet.
#   -> select s.stuid from student s where s.stuid not in ( select hp.stuid from has_pet hp join pets p on hp.petid = p.petid where p.pettype = 'cat' )
#   gold: select stuid from student except select t1.stuid from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'cat'
#   EM=15/64 EA=55/64 VS=64/64
#
# [65/100] What are the ids of the students who do not own cats as pets?
#   -> select s.stuid from student s where s.stuid not in ( select hp.stuid from has_pet hp join pets p on hp.petid = p.petid where p.pettype = 'cat' )
#   gold: select stuid from student except select t1.stuid from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'cat'
#   EM=15/65 EA=56/65 VS=65/65
#
# [66/100] Find the first name and age of students who have a dog but do not have a cat as a pet.
#   -> select distinct s.fname, s.age from student s inner join has_pet hp on s.stuid = hp.stuid inner join pets p on hp.petid = p.petid where p.pettype = 'dog' and s.stuid not in ( select hp2.stuid from has_pet hp2 inner join pets p2 on hp2.petid = p2.petid where p2.pettype = 'cat' )
#   gold: select t1.fname, t1.age from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'dog' and t1.stuid not in (select t1.stuid from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'cat')
#   EM=15/66 EA=56/66 VS=66/66
#
# [67/100] What is the first name of every student who has a dog but does not have a cat?
#   -> select distinct s.fname from student s join has_pet hp on s.stuid = hp.stuid join pets p on hp.petid = p.petid where p.pettype = 'dog' and s.stuid not in ( select hp2.stuid from has_pet hp2 join pets p2 on hp2.petid = p2.petid where p2.pettype = 'cat' )
#   gold: select t1.fname, t1.age from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'dog' and t1.stuid not in (select t1.stuid from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pettype = 'cat')
#   EM=15/67 EA=56/67 VS=67/67
#
# [68/100] Find the type and weight of the youngest pet.
#   -> select pettype, weight from pets where pet_age = (select min(pet_age) from pets)
#   gold: select pettype, weight from pets order by pet_age limit 1
#   EM=15/68 EA=57/68 VS=68/68
#
# [69/100] What type of pet is the youngest animal, and how much does it weigh?
#   -> select pettype, weight from pets where pet_age = (select min(pet_age) from pets) limit 1
#   gold: select pettype, weight from pets order by pet_age limit 1
#   EM=15/69 EA=58/69 VS=69/69
#
# [70/100] Find the id and weight of all pets whose age is older than 1.
#   -> select petid, weight from pets where pet_age > 1
#   gold: select petid, weight from pets where pet_age > 1
#   EM=16/70 EA=59/70 VS=70/70
#
# [71/100] What is the id and weight of every pet who is older than 1?
#   -> select petid, weight from pets where pet_age > 1
#   gold: select petid, weight from pets where pet_age > 1
#   EM=17/71 EA=60/71 VS=71/71
#
# [72/100] Find the average and maximum age for each type of pet.
#   -> select p.pettype, avg(p.pet_age) as average_age, max(p.pet_age) as maximum_age from pets p group by p.pettype
#   gold: select avg(pet_age), max(pet_age), pettype from pets group by pettype
#   EM=17/72 EA=61/72 VS=72/72
#
# [73/100] What is the average and maximum age for each pet type?
#   -> select p.pettype, avg(p.pet_age) as average_age, max(p.pet_age) as maximum_age from pets p group by p.pettype
#   gold: select avg(pet_age), max(pet_age), pettype from pets group by pettype
#   EM=17/73 EA=62/73 VS=73/73
#
# [74/100] Find the average weight for each pet type.
#   -> select pettype, avg(weight) as average_weight from pets group by pettype
#   gold: select avg(weight), pettype from pets group by pettype
#   EM=17/74 EA=63/74 VS=74/74
#
# [75/100] What is the average weight for each type of pet?
#   -> select pettype, avg(weight) as average_weight from pets group by pettype
#   gold: select avg(weight), pettype from pets group by pettype
#   EM=17/75 EA=64/75 VS=75/75
#
# [76/100] Find the first name and age of students who have a pet.
#   -> select distinct s.fname, s.age from student s inner join has_pet hp on s.stuid = hp.stuid
#   gold: select distinct t1.fname, t1.age from student as t1 join has_pet as t2 on t1.stuid = t2.stuid
#   EM=17/76 EA=65/76 VS=76/76
#
# [77/100] What are the different first names and ages of the students who do have pets?
#   -> select distinct s.fname, s.age from student s inner join has_pet hp on s.stuid = hp.stuid
#   gold: select distinct t1.fname, t1.age from student as t1 join has_pet as t2 on t1.stuid = t2.stuid
#   EM=17/77 EA=66/77 VS=77/77
#
# [78/100] Find the id of the pet owned by student whose last name is ‘Smith’.
#   -> select has_pet.petid from student join has_pet on student.stuid = has_pet.stuid where student.lname = 'smith'
#   gold: select t2.petid from student as t1 join has_pet as t2 on t1.stuid = t2.stuid where t1.lname = 'smith'
#   EM=17/78 EA=67/78 VS=78/78
#
# [79/100] What is the id of the pet owned by the student whose last name is 'Smith'?
#   -> select has_pet.petid from student join has_pet on student.stuid = has_pet.stuid where student.lname = 'smith'
#   gold: select t2.petid from student as t1 join has_pet as t2 on t1.stuid = t2.stuid where t1.lname = 'smith'
#   EM=17/79 EA=68/79 VS=79/79
#
# [80/100] Find the number of pets for each student who has any pet and student id.
#   -> select s.stuid, count(hp.petid) as num_pets from student s inner join has_pet hp on s.stuid = hp.stuid group by s.stuid having count(hp.petid) > 0
#   gold: select count(*), t1.stuid from student as t1 join has_pet as t2 on t1.stuid = t2.stuid group by t1.stuid
#   EM=17/80 EA=69/80 VS=80/80
#
# [81/100] For students who have pets , how many pets does each student have ? list their ids instead of names .
#   -> select h.stuid, count(h.petid) as num_pets from has_pet h group by h.stuid
#   gold: select count(*), t1.stuid from student as t1 join has_pet as t2 on t1.stuid = t2.stuid group by t1.stuid
#   EM=17/81 EA=70/81 VS=81/81
#
# [82/100] Find the first name and gender of student who have more than one pet.
#   -> select s.fname, s.sex from student s join has_pet hp on s.stuid = hp.stuid group by s.stuid having count(hp.petid) > 1
#   gold: select t1.fname, t1.sex from student as t1 join has_pet as t2 on t1.stuid = t2.stuid group by t1.stuid having count(*) > 1
#   EM=17/82 EA=71/82 VS=82/82
#
# [83/100] What is the first name and gender of the all the students who have more than one pet?
#   -> select s.fname, s.sex from student s join has_pet hp on s.stuid = hp.stuid group by s.stuid having count(hp.petid) > 1
#   gold: select t1.fname, t1.sex from student as t1 join has_pet as t2 on t1.stuid = t2.stuid group by t1.stuid having count(*) > 1
#   EM=17/83 EA=72/83 VS=83/83
#
# [84/100] Find the last name of the student who has a cat that is age 3.
#   -> select s.lname from student s join has_pet hp on s.stuid = hp.stuid join pets p on hp.petid = p.petid where p.pettype = 'cat' and p.pet_age = 3
#   gold: select t1.lname from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pet_age = 3 and t3.pettype = 'cat'
#   EM=17/84 EA=73/84 VS=84/84
#
# [85/100] What is the last name of the student who has a cat that is 3 years old?
#   -> select s.lname from student s join has_pet hp on s.stuid = hp.stuid join pets p on hp.petid = p.petid where p.pettype = 'cat' and p.pet_age = 3
#   gold: select t1.lname from student as t1 join has_pet as t2 on t1.stuid = t2.stuid join pets as t3 on t3.petid = t2.petid where t3.pet_age = 3 and t3.pettype = 'cat'
#   EM=17/85 EA=74/85 VS=85/85
#
# [86/100] Find the average age of students who do not have any pet .
#   -> select avg(age) as average_age from student where stuid not in ( select distinct stuid from has_pet )
#   gold: select avg(age) from student where stuid not in (select stuid from has_pet)
#   EM=17/86 EA=75/86 VS=86/86
#
# [87/100] What is the average age for all students who do not own any pets ?
#   -> select avg(s.age) as average_age from student s left join has_pet hp on s.stuid = hp.stuid where hp.stuid is null
#   gold: select avg(age) from student where stuid not in (select stuid from has_pet)
#   EM=17/87 EA=76/87 VS=87/87
#
# [88/100] How many continents are there?
#   -> select count(*) from continents
#   gold: select count(*) from continents
#   EM=18/88 EA=77/88 VS=88/88
#
# [89/100] What is the number of continents?
#   -> select count(*) from continents
#   gold: select count(*) from continents
#   EM=19/89 EA=78/89 VS=89/89
#
# [90/100] How many countries does each continent have? List the continent id, continent name and the number of countries.
#   -> select c.contid as continent_id, c.continent as continent_name, count(co.countryid) as number_of_countries from continents c left join countries co on c.contid = co.continent group by c.contid, c.continent order by c.contid
#   gold: select t1.contid, t1.continent, count(*) from continents as t1 join countries as t2 on t1.contid = t2.continent group by t1.contid
#   EM=19/90 EA=79/90 VS=90/90
#
# [91/100] For each continent, list its id, name, and how many countries it has?
#   -> select c.contid, c.continent, count(co.countryid) as countrycount from continents c left join countries co on c.contid = co.continent group by c.contid, c.continent
#   gold: select t1.contid, t1.continent, count(*) from continents as t1 join countries as t2 on t1.contid = t2.continent group by t1.contid
#   EM=19/91 EA=80/91 VS=91/91
#
# [92/100] How many countries are listed?
#   -> select count(*) from countries
#   gold: select count(*) from countries
#   EM=20/92 EA=81/92 VS=92/92
#
# [93/100] How many countries exist?
#   -> select count(*) from countries
#   gold: select count(*) from countries
#   EM=21/93 EA=82/93 VS=93/93
#
# [94/100] How many models does each car maker produce? List maker full name, id and the number.
#   -> select cm.id, cm.fullname, count(distinct ml.modelid) as numberofmodels from car_makers cm left join model_list ml on cm.id = ml.maker group by cm.id, cm.fullname order by cm.id
#   gold: select t1.fullname, t1.id, count(*) from car_makers as t1 join model_list as t2 on t1.id = t2.maker group by t1.id
#   EM=21/94 EA=83/94 VS=94/94
#
# [95/100] What is the full name of each car maker, along with its id and how many models it produces?
#   -> select cm.id, cm.fullname, count(distinct ml.modelid) as modelcount from car_makers cm left join model_list ml on cm.id = ml.maker group by cm.id, cm.fullname order by cm.id
#   gold: select t1.fullname, t1.id, count(*) from car_makers as t1 join model_list as t2 on t1.id = t2.maker group by t1.id
#   EM=21/95 EA=84/95 VS=95/95
#
# [96/100] Which model of the car has the minimum horsepower?
#   -> select ml.model from model_list ml join car_names cn on ml.model = cn.model join cars_data cd on cn.makeid = cd.id where cd.horsepower = (select min(horsepower) from cars_data where horsepower is not null) limit 1
#   gold: select t1.model from car_names as t1 join cars_data as t2 on t1.makeid = t2.id order by t2.horsepower asc limit 1
#   EM=21/96 EA=85/96 VS=96/96
#
# [97/100] What is the model of the car with the smallest amount of horsepower?
#   -> select ml.model from cars_data cd join car_names cn on cd.id = cn.makeid join model_list ml on cn.model = ml.model where cd.horsepower = (select min(horsepower) from cars_data where horsepower is not null) limit 1
#   gold: select t1.model from car_names as t1 join cars_data as t2 on t1.makeid = t2.id order by t2.horsepower asc limit 1
#   EM=21/97 EA=86/97 VS=97/97
#
# [98/100] Find the model of the car whose weight is below the average weight.
#   -> select distinct ml.model from model_list ml join car_names cn on ml.model = cn.model join cars_data cd on cn.makeid = cd.id where cd.weight < (select avg(weight) from cars_data)
#   gold: select t1.model from car_names as t1 join cars_data as t2 on t1.makeid = t2.id where t2.weight < (select avg(weight) from cars_data)
#   EM=21/98 EA=86/98 VS=98/98
#
# [99/100] What is the model for the car with a weight smaller than the average?
#   -> select distinct ml.model from model_list ml join car_names cn on ml.model = cn.model join cars_data cd on cn.makeid = cd.id where cd.weight < (select avg(weight) from cars_data)
#   gold: select t1.model from car_names as t1 join cars_data as t2 on t1.makeid = t2.id where t2.weight < (select avg(weight) from cars_data)
#   EM=21/99 EA=86/99 VS=99/99
#
# [100/100] Find the name of the makers that produced some cars in the year of 1970?
#   -> select distinct cm.maker from car_makers cm join model_list ml on cm.id = ml.maker join car_names cn on ml.model = cn.model join cars_data cd on cn.makeid = cd.id where cd.year = 1970
#   gold: select distinct t1.maker from car_makers as t1 join model_list as t2 on t1.id = t2.maker join car_names as t3 on t2.model = t3.model join cars_data as t4 on t3.makeid = t4.id where t4.year = '1970'
#   EM=21/100 EA=87/100 VS=100/100
#
# === baseline === {"total": 100, "em": 21, "vs": 100, "ea": 87, "em%": 0.21, "vs%": 1.0, "ea%": 0.87}

# %%
print()
print("="*55)
print(f"{'config':<28} {'EA':>8} {'EM':>8} {'Valid':>8}")
print("-"*55)
for name, r in [("Full SoT", r1),
                ("w/o correction", r2),
                ("w/o subproblem", r3),
                ("w/o schema linking", r4),
                ("baseline", r5)]:
    print(f"{name:<28} {r['ea%']:>7.1%} {r['em%']:>7.1%} {r['vs%']:>7.1%}")
print("="*55)
# Out:
# =======================================================
# config                             EA       EM    Valid
# -------------------------------------------------------
# Full SoT                       89.0%   11.0%   99.0%
# w/o correction                 85.0%    6.0%  100.0%
# w/o subproblem                 90.0%   10.0%   99.0%
# w/o schema linking             89.0%   12.0%  100.0%
# baseline                       87.0%   21.0%  100.0%
# =======================================================
